# %%
import pyEX
# %env IEX_TOKEN=pk_02f114f931ba4b05978c6a05b390146e

c = pyEX.Client()
# c = pyEX.Client(version='sandbox')
# Out:
# env: IEX_TOKEN=pk_02f114f931ba4b05978c6a05b390146e

# %% [markdown]
# # Symbols data

# %%
c.symbolsDF().head()
# Out:
#        currency       date exchange                 iexId  isEnabled  \
# symbol
# A           USD 2019-06-13      NYS  IEX_46574843354B2D52       True
# AA          USD 2019-06-13      NYS  IEX_4238333734532D52       True
# AAAU        USD 2019-06-13      PSE  IEX_474B433136332D52       True
# AABA        USD 2019-06-13      NAS  IEX_4E5434354A302D52       True
# AAC         USD 2019-06-13      NYS  IEX_4843364642592D52       True
#
#                                 name region type
# symbol
# A          Agilent Technologies Inc.     US   cs
# AA                       Alcoa Corp.     US   cs
# AAAU    Perth Mint Physical Gold ETF     US   et
# AABA                     Altaba Inc.     US  cef
# AAC                AAC Holdings Inc.     US   cs

# %% [markdown]
# ## Symbols

# %%
c.symbols()[:5]
# Out:
# [{'symbol': 'A',
#   'exchange': 'NYS',
#   'name': 'Agilent Technologies Inc.',
#   'date': '2019-06-13',
#   'type': 'cs',
#   'iexId': 'IEX_46574843354B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True},
#  {'symbol': 'AA',
#   'exchange': 'NYS',
#   'name': 'Alcoa Corp.',
#   'date': '2019-06-13',
#   'type': 'cs',
#   'iexId': 'IEX_4238333734532D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True},
#  {'symbol': 'AAAU',
#   'exchange': 'PSE',
#   'name': 'Perth Mint Physical Gold ETF',
#   'date': '2019-06-13',
#   'type': 'et',
#   'iexId': 'IEX_474B433136332D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True},
#  {'symbol': 'AABA',
#   'exchange': 'NAS',
#   'name': 'Altaba Inc.',
#   'date': '2019-06-13',
#   'type': 'cef',
#   'iexId': 'IEX_4E5434354A302D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True},
#  {'symbol': 'AAC',
#   'exchange': 'NYS',
#   'name': 'AAC Holdings Inc.',
#   'date': '2019-06-13',
#   'type': 'cs',
#   'iexId': 'IEX_4843364642592D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True}]

# %%
c.symbolsDF().head()
# Out:
#        currency       date exchange                 iexId  isEnabled  \
# symbol
# A           USD 2019-06-13      NYS  IEX_46574843354B2D52       True
# AA          USD 2019-06-13      NYS  IEX_4238333734532D52       True
# AAAU        USD 2019-06-13      PSE  IEX_474B433136332D52       True
# AABA        USD 2019-06-13      NAS  IEX_4E5434354A302D52       True
# AAC         USD 2019-06-13      NYS  IEX_4843364642592D52       True
#
#                                 name region type
# symbol
# A          Agilent Technologies Inc.     US   cs
# AA                       Alcoa Corp.     US   cs
# AAAU    Perth Mint Physical Gold ETF     US   et
# AABA                     Altaba Inc.     US  cef
# AAC                AAC Holdings Inc.     US   cs

# %%
c.symbolsList()[:5]
# Out:
# ['A', 'AA', 'AAAU', 'AABA', 'AAC']

# %% [markdown]
# ## IEX Symbols

# %%
c.iexSymbols()[:5]
# Out:
# [{'symbol': 'A', 'date': '2019-05-07', 'isEnabled': True},
#  {'symbol': 'AA', 'date': '2019-05-07', 'isEnabled': True},
#  {'symbol': 'AAAU', 'date': '2019-05-07', 'isEnabled': True},
#  {'symbol': 'AABA', 'date': '2019-05-07', 'isEnabled': True},
#  {'symbol': 'AAC', 'date': '2019-05-07', 'isEnabled': True}]

# %%
c.iexSymbolsDF().head()
# Out:
#              date  isEnabled
# symbol
# A      2019-05-07       True
# AA     2019-05-07       True
# AAAU   2019-05-07       True
# AABA   2019-05-07       True
# AAC    2019-05-07       True

# %%
c.iexSymbolsList()[:10]
# Out:
# ['A', 'AA', 'AAAU', 'AABA', 'AAC', 'AADR', 'AAL', 'AAMC', 'AAME', 'AAN']

# %% [markdown]
# ## International Symbols

# %%
c.internationalSymbols()[:5]
# Out:
# [{'symbol': 'A',
#   'exchange': 'NYS',
#   'name': 'Agilent Technologies Inc.',
#   'date': '2019-05-07',
#   'type': 'cs',
#   'iexId': 'IEX_46574843354B2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True},
#  {'symbol': 'AA',
#   'exchange': 'NYS',
#   'name': 'Alcoa Corp.',
#   'date': '2019-05-07',
#   'type': 'cs',
#   'iexId': 'IEX_4238333734532D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True},
#  {'symbol': 'AAAAX',
#   'exchange': 'NAS',
#   'name': 'DWS Alternative Asset Allocation Fund Class A',
#   'date': '2019-05-07',
#   'type': 'oef',
#   'iexId': 'IEX_4258444437432D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True},
#  {'symbol': 'AAADX',
#   'exchange': 'NAS',
#   'name': 'Aberdeen Income Builder Fund - Class A',
#   'date': '2019-05-07',
#   'type': 'oef',
#   'iexId': 'IEX_5153364A51302D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True},
#  {'symbol': 'AAAG',
#   'exchange': 'OTC',
#   'name': 'AAA Century Group USA Inc.',
#   'date': '2019-05-07',
#   'type': 'cs',
#   'iexId': 'IEX_4A534652444A2D52',
#   'region': 'US',
#   'currency': 'USD',
#   'isEnabled': True}]

# %%
c.internationalSymbolsDF().head()
# Out:
#        currency       date exchange                 iexId  isEnabled  \
# symbol
# A           USD 2019-05-07      NYS  IEX_46574843354B2D52       True
# AA          USD 2019-05-07      NYS  IEX_4238333734532D52       True
# AAAAX       USD 2019-05-07      NAS  IEX_4258444437432D52       True
# AAADX       USD 2019-05-07      NAS  IEX_5153364A51302D52       True
# AAAG        USD 2019-05-07      OTC  IEX_4A534652444A2D52       True
#
#                                                  name region type
# symbol
# A                           Agilent Technologies Inc.     US   cs
# AA                                        Alcoa Corp.     US   cs
# AAAAX   DWS Alternative Asset Allocation Fund Class A     US  oef
# AAADX          Aberdeen Income Builder Fund - Class A     US  oef
# AAAG                       AAA Century Group USA Inc.     US   cs

# %%
c.internationalSymbolsList()[:5]
# Out:
# ['A', 'AA', 'AAAAX', 'AAADX', 'AAAG']

# %% [markdown]
# ## FX Symbols

# %%
c.fxSymbols()
# Out:
# {'currencies': [{'code': 'EUR', 'name': 'Euro'},
#   {'code': 'USD', 'name': 'U.S. Dollar'},
#   {'code': 'GBP', 'name': 'British Pound'},
#   {'code': 'AUD', 'name': 'Australian Dollar'},
#   {'code': 'JPY', 'name': 'Japanese Yen'},
#   {'code': 'CNY', 'name': 'Chinese Yuan Renminbi'},
#   {'code': 'CAD', 'name': 'Canadian Dollar'},
#   {'code': 'CHF', 'name': 'Swiss Franc'},
#   {'code': 'ARS', 'name': 'Argentine Peso'},
#   {'code': 'BGN', 'name': 'Bulgarian Lev'},
#   {'code': 'BRL', 'name': 'Brazilian Real'},
#   {'code': 'CLP', 'name': 'Chilean Peso'},
#   {'code': 'COP', 'name': 'Colombian Peso'},
#   {'code': 'CZK', 'name': 'Czech Koruna'},
#   {'code': 'DKK', 'name': 'Danish Krone'},
#   {'code': 'HKD', 'name': 'Hong Kong Dollar'},
#   {'code': 'HUF', 'name': 'Hungarian Forint'},
#   {'code': 'IDR', 'name': 'Indonesian Rupiah'},
#   {'code': 'ILS', 'name': 'Israeli New Shekel'},
#   {'code': 'INR', 'name': 'Indian Rupee'},
#   {'code': 'KRW', 'name': 'Korean Won'},
#   {'code': 'KZT', 'name': 'Kazakhstan Tenge'},
#   {'code': 'MXN', 'name': 'Mexican Peso'},
#   {'code': 'MYR', 'name': 'Malaysian Ringgit'},
#   {'code': 'NOK', 'name': 'Norwegian Krone'},
#   {'code': 'NZD', 'name': 'New Zealand Dollar'},
#   {'code': 'PEN', 'name': 'Peruvian Nuevo Sol'},
#   {'code': 'PHP', 'name': 'Philippine Peso'},
#   {'code': 'PLN', 'name': 'Polish Zloty'},
#   {'code': 'RON', 'name': 'Romanian Leu'},
#   {'code': 'RUB', 'name': 'Russian Ruble'},
#   {'code': 'SEK', 'name': 'Swedish Krona'},
#   {'code': 'SGD', 'name': 'Singapore Dollar'},
#   {'code': 'THB', 'name': 'Thai Baht'},
#   {'code': 'TRY', 'name': 'Turkish Lira'},
#   {'code': 'TWD', 'name': 'Taiwan Dollar'},
#   {'code': 'UAH', 'name': 'Ukrainian Hryvna'},
#   {'code': 'VND', 'name': 'Vietnamese Dong'},
#   {'code': 'ZAR', 'name': 'South African Rand'},
#   {'code': 'HRK', 'name': 'Croatian Kuna'},
#   {'code': 'RSD', 'name': 'Serbian Dinar'}],
#  'pairs': [{'fromCurrency': 'EUR', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'GBP', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'GBP'},
#   {'fromCurrency': 'AUD', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'AUD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'JPY'},
#   {'fromCurrency': 'JPY', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'CNY'},
#   {'fromCurrency': 'CNY', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'CAD'},
#   {'fromCurrency': 'CAD', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'CHF'},
#   {'fromCurrency': 'CHF', 'toCurrency': 'USD'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'GBP'},
#   {'fromCurrency': 'GBP', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'CHF'},
#   {'fromCurrency': 'CHF', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'JPY'},
#   {'fromCurrency': 'JPY', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'USD', 'toCurrency': 'ARS'},
#   {'fromCurrency': 'ARS', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'BGN'},
#   {'fromCurrency': 'BGN', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'BRL'},
#   {'fromCurrency': 'BRL', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'CLP'},
#   {'fromCurrency': 'CLP', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'COP'},
#   {'fromCurrency': 'COP', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'CZK'},
#   {'fromCurrency': 'CZK', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'DKK'},
#   {'fromCurrency': 'DKK', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'HKD'},
#   {'fromCurrency': 'HKD', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'HUF'},
#   {'fromCurrency': 'HUF', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'IDR'},
#   {'fromCurrency': 'IDR', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'ILS'},
#   {'fromCurrency': 'ILS', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'INR'},
#   {'fromCurrency': 'INR', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'KRW'},
#   {'fromCurrency': 'KRW', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'KZT'},
#   {'fromCurrency': 'KZT', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'MXN'},
#   {'fromCurrency': 'MXN', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'MYR'},
#   {'fromCurrency': 'MYR', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'NOK'},
#   {'fromCurrency': 'NOK', 'toCurrency': 'USD'},
#   {'fromCurrency': 'NZD', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'NZD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'PEN'},
#   {'fromCurrency': 'PEN', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'PHP'},
#   {'fromCurrency': 'PHP', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'PLN'},
#   {'fromCurrency': 'PLN', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'RON'},
#   {'fromCurrency': 'RON', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'RUB'},
#   {'fromCurrency': 'RUB', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'SEK'},
#   {'fromCurrency': 'SEK', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'SGD'},
#   {'fromCurrency': 'SGD', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'THB'},
#   {'fromCurrency': 'THB', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'TRY'},
#   {'fromCurrency': 'TRY', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'TWD'},
#   {'fromCurrency': 'TWD', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'UAH'},
#   {'fromCurrency': 'UAH', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'VND'},
#   {'fromCurrency': 'VND', 'toCurrency': 'USD'},
#   {'fromCurrency': 'USD', 'toCurrency': 'ZAR'},
#   {'fromCurrency': 'ZAR', 'toCurrency': 'USD'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'AUD'},
#   {'fromCurrency': 'AUD', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'BGN'},
#   {'fromCurrency': 'BGN', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'CAD'},
#   {'fromCurrency': 'CAD', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'CNY'},
#   {'fromCurrency': 'CNY', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'CZK'},
#   {'fromCurrency': 'CZK', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'DKK'},
#   {'fromCurrency': 'DKK', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'HRK'},
#   {'fromCurrency': 'HRK', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'HUF'},
#   {'fromCurrency': 'HUF', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'INR'},
#   {'fromCurrency': 'INR', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'KRW'},
#   {'fromCurrency': 'KRW', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'KZT'},
#   {'fromCurrency': 'KZT', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'NOK'},
#   {'fromCurrency': 'NOK', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'NZD'},
#   {'fromCurrency': 'NZD', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'PLN'},
#   {'fromCurrency': 'PLN', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'RON'},
#   {'fromCurrency': 'RON', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'RSD'},
#   {'fromCurrency': 'RSD', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'RUB'},
#   {'fromCurrency': 'RUB', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'SEK'},
#   {'fromCurrency': 'SEK', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'TRY'},
#   {'fromCurrency': 'TRY', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'UAH'},
#   {'fromCurrency': 'UAH', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'EUR', 'toCurrency': 'ZAR'},
#   {'fromCurrency': 'ZAR', 'toCurrency': 'EUR'},
#   {'fromCurrency': 'CAD', 'toCurrency': 'JPY'},
#   {'fromCurrency': 'JPY', 'toCurrency': 'CAD'},
#   {'fromCurrency': 'CHF', 'toCurrency': 'JPY'},
#   {'fromCurrency': 'JPY', 'toCurrency': 'CHF'},
#   {'fromCurrency': 'NZD', 'toCurrency': 'JPY'},
#   {'fromCurrency': 'JPY', 'toCurrency': 'NZD'},
#   {'fromCurrency': 'NOK', 'toCurrency': 'JPY'},
#   {'fromCurrency': 'JPY', 'toCurrency': 'NOK'},
#   {'fromCurrency': 'ZAR', 'toCurrency': 'JPY'},
#   {'fromCurrency': 'JPY', 'toCurrency': 'ZAR'},
#   {'fromCurrency': 'GBP', 'toCurrency': 'AUD'},
#   {'fromCurrency': 'AUD', 'toCurrency': 'GBP'},
#   {'fromCurrency': 'GBP', 'toCurrency': 'CHF'},
#   {'fromCurrency': 'CHF', 'toCurrency': 'GBP'},
#   {'fromCurrency': 'AUD', 'toCurrency': 'JPY'},
#   {'fromCurrency': 'JPY', 'toCurrency': 'AUD'},
#   {'fromCurrency': 'AUD', 'toCurrency': 'CAD'},
#   {'fromCurrency': 'CAD', 'toCurrency': 'AUD'}]}

# %%
dfs = c.fxSymbolsDF()
dfs[0].head()
# Out:
#                    name
# code
# EUR                Euro
# USD         U.S. Dollar
# GBP       British Pound
# AUD   Australian Dollar
# JPY        Japanese Yen

# %%
dfs[1].head()
# Out:
#   fromCurrency toCurrency
# 0          EUR        USD
# 1          USD        EUR
# 2          GBP        USD
# 3          USD        GBP
# 4          AUD        USD

# %%
l = c.fxSymbolsList()
l[0][:5]
# Out:
# ['EUR', 'USD', 'GBP', 'AUD', 'JPY']

# %%
l[1][:5]
# Out:
# ['EURUSD', 'USDEUR', 'GBPUSD', 'USDGBP', 'AUDUSD']

# %% [markdown]
# ## Options Symbols

# %%
d = c.optionsSymbols()
list(d.keys())[:5]
# Out:
# ['FLIC', 'TMQ-CT', 'GHM', 'MAS', 'HOMB']

# %%
c.optionsSymbolsDF().head()
# Out:
#                                             expirations
# A      [201905, 201906, 201908, 201911, 202001, 202101]
# AA     [201905, 201906, 201907, 201910, 202001, 202101]
# AABA   [201905, 201906, 201907, 201910, 202001, 202101]
# AAC                    [201905, 201906, 201909, 201912]
# AAL   [201905, 201906, 201908, 201909, 201911, 20191...

# %%
c.optionsSymbolsList()[:5]
# Out:
# ['A', 'AA', 'AABA', 'AAC', 'AAL']

# %% [markdown]
# ## International Exchanges

# %%
c.internationalExchanges()[:5]
# Out:
# [{'exchange': 'ADS',
#   'region': 'AE',
#   'description': 'Abu Dhabi Securities Exchange',
#   'mic': 'XADS',
#   'exchangeSuffix': '-DH'},
#  {'exchange': 'BRU',
#   'region': 'BE',
#   'description': 'Euronext Brussels',
#   'mic': 'XBRU',
#   'exchangeSuffix': '-BB'},
#  {'exchange': 'ETR',
#   'region': 'DE',
#   'description': 'XETRA',
#   'mic': 'XETR',
#   'exchangeSuffix': '-GY'},
#  {'exchange': 'PAR',
#   'region': 'FR',
#   'description': 'Euronext Paris',
#   'mic': 'XPAR',
#   'exchangeSuffix': '-FP'},
#  {'exchange': 'LON',
#   'region': 'GB',
#   'description': 'London Stock Exchange',
#   'mic': 'XLON',
#   'exchangeSuffix': '-LN'}]

# %%
c.internationalExchangesDF().head()
# Out:
#                      description exchange exchangeSuffix   mic region
# 0  Abu Dhabi Securities Exchange      ADS            -DH  XADS     AE
# 1              Euronext Brussels      BRU            -BB  XBRU     BE
# 2                          XETRA      ETR            -GY  XETR     DE
# 3                 Euronext Paris      PAR            -FP  XPAR     FR
# 4          London Stock Exchange      LON            -LN  XLON     GB

# %% [markdown]
# ## US Exchanges

# %%
c.exchanges()[:5]
# Out:
# [{'mic': 'ARCX',
#   'name': 'NYSE Arca',
#   'longName': 'NYSE ARCA',
#   'tapeId': 'P',
#   'oatsId': 'XP',
#   'type': 'equities'},
#  {'mic': 'EDGX',
#   'name': 'Cboe EDGX',
#   'longName': 'Cboe EDGX US Equities Exchange',
#   'tapeId': 'K',
#   'oatsId': 'XK',
#   'type': 'equities'},
#  {'mic': 'BATS',
#   'name': 'Cboe BZX',
#   'longName': 'Cboe BZX US Equities Exchange',
#   'tapeId': 'Z',
#   'oatsId': 'XZ',
#   'type': 'equities'},
#  {'mic': 'BATY',
#   'name': 'Cboe BYX',
#   'longName': 'Cboe BYX US Equities Exchange',
#   'tapeId': 'Y',
#   'oatsId': 'XY',
#   'type': 'equities'},
#  {'mic': 'EDGA',
#   'name': 'Cboe EDGA',
#   'longName': 'Cboe EDGA US Equities Exchange',
#   'tapeId': 'J',
#   'oatsId': 'XJ',
#   'type': 'equities'}]

# %%
c.exchangesDF().head()
# Out:
#                          longName   mic       name oatsId tapeId      type
# 0                       NYSE ARCA  ARCX  NYSE Arca     XP      P  equities
# 1  Cboe EDGX US Equities Exchange  EDGX  Cboe EDGX     XK      K  equities
# 2   Cboe BZX US Equities Exchange  BATS   Cboe BZX     XZ      Z  equities
# 3   Cboe BYX US Equities Exchange  BATY   Cboe BYX     XY      Y  equities
# 4  Cboe EDGA US Equities Exchange  EDGA  Cboe EDGA     XJ      J  equities

# %% [markdown]
# ## US Holidays

# %%
c.holidays()[:5]
# Out:
# [{'date': '2019-05-27', 'settlementDate': '2019-05-29'}]

# %%
c.holidaysDF().head()
# Out:
#         date settlementDate
# 0 2019-05-27     2019-05-29

# %% [markdown]
# ## Sectors

# %%
c.sectors()[:5]
# Out:
# [{'name': 'Electronic Technology'},
#  {'name': 'Distribution Services'},
#  {'name': 'Health Technology'},
#  {'name': 'Commercial Services'},
#  {'name': 'Industrial Services'}]

# %%
c.sectorsDF().head()
# Out:
#                     name
# 0  Electronic Technology
# 1  Distribution Services
# 2      Health Technology
# 3    Commercial Services
# 4    Industrial Services

# %% [markdown]
# ## Tags

# %%
c.tags()[:5]
# Out:
# [{'name': 'Electronic Technology'},
#  {'name': 'Distribution Services'},
#  {'name': 'Commercial Services'},
#  {'name': 'Health Technology'},
#  {'name': 'Industrial Services'}]

# %%
c.tagsDF().head()
# Out:
#                     name
# 0  Electronic Technology
# 1  Distribution Services
# 2    Commercial Services
# 3      Health Technology
# 4    Industrial Services

# %% [markdown]
# # Data Points API

# %%
c.points()[:5]
# Out:
# [{'key': 'DGS10',
#   'weight': 1,
#   'description': '10-Year Treasury Rate (daily)',
#   'lastUpdated': '2019-05-07T06:00:00+00:00'},
#  {'key': 'DGS2',
#   'weight': 1,
#   'description': '2-Year Treasury Rate (daily)',
#   'lastUpdated': '2019-05-07T06:00:02+00:00'},
#  {'key': 'DGS1',
#   'weight': 1,
#   'description': '1-Year Treasury Rate (daily)',
#   'lastUpdated': '2019-05-07T06:00:03+00:00'},
#  {'key': 'DGS30',
#   'weight': 1,
#   'description': '30-Year Treasury Rate (daily)',
#   'lastUpdated': '2019-05-07T06:00:04+00:00'},
#  {'key': 'DGS5',
#   'weight': 1,
#   'description': '5-Year Treasury Rate (daily)',
#   'lastUpdated': '2019-05-07T06:00:05+00:00'}]

# %%
c.pointsDF().head()
# Out:
#                      description    key               lastUpdated  weight
# 0  10-Year Treasury Rate (daily)  DGS10 2019-05-07 06:00:00+00:00       1
# 1   2-Year Treasury Rate (daily)   DGS2 2019-05-07 06:00:02+00:00       1
# 2   1-Year Treasury Rate (daily)   DGS1 2019-05-07 06:00:03+00:00       1
# 3  30-Year Treasury Rate (daily)  DGS30 2019-05-07 06:00:04+00:00       1
# 4   5-Year Treasury Rate (daily)   DGS5 2019-05-07 06:00:05+00:00       1

# %%
c.points(key='DGS10')
# Out:
# 2.49

# %%
c.pointsDF('aapl').head()
# Out:
#             description                  key               lastUpdated  weight
# 0    Quote: latestPrice    QUOTE-LATESTPRICE 2019-05-07 20:29:16+00:00       1
# 1   Quote: latestVolume   QUOTE-LATESTVOLUME 2019-05-07 20:29:16+00:00       1
# 2   Quote: latestUpdate   QUOTE-LATESTUPDATE 2019-05-07 20:29:16+00:00       1
# 3         Quote: change         QUOTE-CHANGE 2019-05-07 20:29:16+00:00       1
# 4  Quote: changePercent  QUOTE-CHANGEPERCENT 2019-05-07 20:29:16+00:00       1

# %%
c.points('aapl', 'QUOTE-LATESTPRICE')
# Out:
# 202.86

# %% [markdown]
# # Stock API

# %%
symbol = 'AAPL'

# %% [markdown]
# ## Advanced Stats

# %%
c.advancedStats(symbol)
# Out:
# {'week52change': 0.125945,
#  'week52high': 233.47,
#  'week52low': 142,
#  'marketcap': 959233158400,
#  'employees': 132000,
#  'day200MovingAvg': 192.36,
#  'day50MovingAvg': 191.93,
#  'float': 4594455231,
#  'avg10Volume': 29695469,
#  'avg30Volume': 27470517.9,
#  'ttmEPS': 11.99,
#  'ttmDividendRate': 2.92,
#  'companyName': 'Apple, Inc.',
#  'sharesOutstanding': 4601080000,
#  'maxChangePercent': 205.130117,
#  'year5ChangePercent': 1.463761,
#  'year2ChangePercent': 0.362525,
#  'year1ChangePercent': 0.125945,
#  'ytdChangePercent': 0.320162,
#  'month6ChangePercent': -0.007002,
#  'month3ChangePercent': 0.219609,
#  'month1ChangePercent': 0.041879,
#  'day30ChangePercent': 0.104588,
#  'day5ChangePercent': 0.03892,
#  'nextDividendDate': '2019-05-10',
#  'dividendYield': 0.014006139677666923,
#  'nextEarningsDate': '2019-07-22',
#  'exDividendDate': '2019-05-10',
#  'peRatio': 16.92,
#  'beta': 1.454167231727185,
#  'totalCash': 66301000000,
#  'currentDebt': 20748000000,
#  'revenue': 265809000000,
#  'grossProfit': 101983000000,
#  'totalRevenue': 265809000000,
#  'EBITDA': 80342000000,
#  'revenuePerShare': 0.02,
#  'revenuePerEmployee': 2013704.55,
#  'debtToEquity': 1.07,
#  'profitMargin': 0.22396156638789508,
#  'enterpriseValue': 1022460690000,
#  'enterpriseValueToRevenue': 3.85,
#  'priceToSales': 3.67,
#  'priceToBook': 8.95249664852959,
#  'forwardPERatio': 18.14,
#  'pegRatio': -1.76,
#  'peHigh': '19.635828427249788',
#  'peLow': '11.942809083263246'}

# %%
c.advancedStatsDF(symbol)
# Out:
#         EBITDA  avg10Volume  avg30Volume      beta  companyName  currentDebt  \
# 0  80342000000     29695469   27470517.9  1.454167  Apple, Inc.  20748000000
#
#    day200MovingAvg  day30ChangePercent  day50MovingAvg  day5ChangePercent  \
# 0           192.36            0.104588          191.93            0.03892
#
#    ...  totalRevenue  ttmDividendRate  ttmEPS  week52change  week52high  \
# 0  ...  265809000000             2.92   11.99      0.125945      233.47
#
#   week52low  year1ChangePercent  year2ChangePercent  year5ChangePercent  \
# 0       142            0.125945            0.362525            1.463761
#
#    ytdChangePercent
# 0          0.320162
#
# [1 rows x 48 columns]

# %% [markdown]
# ## Balance Sheet

# %%
c.balanceSheet(symbol)
# Out:
# {'symbol': 'AAPL',
#  'balancesheet': [{'reportDate': '2019-03-31',
#    'currentCash': 38329000000,
#    'shortTermInvestments': 42104000000,
#    'receivables': 15085000000,
#    'inventory': 4884000000,
#    'otherCurrentAssets': 11751000000,
#    'currentAssets': 123346000000,
#    'longTermInvestments': 146807000000,
#    'propertyPlantEquipment': 38746000000,
#    'goodwill': 0,
#    'intangibleAssets': None,
#    'otherAssets': 33099000000,
#    'totalAssets': 341998000000,
#    'accountsPayable': 30443000000,
#    'currentLongTermDebt': 10505000000,
#    'otherCurrentLiabilities': 40900000000,
#    'totalCurrentLiabilities': 93772000000,
#    'longTermDebt': 90201000000,
#    'otherLiabilities': 6279000000,
#    'minorityInterest': 0,
#    'totalLiabilities': 236138000000,
#    'commonStock': 42801000000,
#    'retainedEarnings': 64558000000,
#    'treasuryStock': None,
#    'capitalSurplus': None,
#    'shareholderEquity': 105860000000,
#    'netTangibleAssets': 105860000000}]}

# %%
c.balanceSheetDF(symbol)
# Out:
#             accountsPayable capitalSurplus  commonStock  currentAssets  \
# reportDate
# 2019-03-31      30443000000           None  42801000000   123346000000
#
#             currentCash  currentLongTermDebt  goodwill intangibleAssets  \
# reportDate
# 2019-03-31  38329000000          10505000000         0             None
#
#              inventory  longTermDebt  ...  propertyPlantEquipment  \
# reportDate                            ...
# 2019-03-31  4884000000   90201000000  ...             38746000000
#
#             receivables  retainedEarnings  shareholderEquity  \
# reportDate
# 2019-03-31  15085000000       64558000000       105860000000
#
#             shortTermInvestments   totalAssets  totalCurrentLiabilities  \
# reportDate
# 2019-03-31           42104000000  341998000000              93772000000
#
#             totalLiabilities  treasuryStock  symbol
# reportDate
# 2019-03-31      236138000000           None    AAPL
#
# [1 rows x 27 columns]

# %% [markdown]
# ## Book

# %%
c.book(symbol)
# Out:
# {'quote': {'symbol': 'AAPL',
#   'companyName': 'Apple, Inc.',
#   'calculationPrice': 'close',
#   'open': 205.86,
#   'openTime': 1557235800311,
#   'close': 202.86,
#   'closeTime': 1557259200243,
#   'high': 207.417,
#   'low': 200.825,
#   'latestPrice': 202.86,
#   'latestSource': 'Close',
#   'latestTime': 'May 7, 2019',
#   'latestUpdate': 1557259200243,
#   'latestVolume': 38382396,
#   'iexRealtimePrice': 202.89,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1557259199899,
#   'delayedPrice': 202.86,
#   'delayedPriceTime': 1557259201283,
#   'extendedPrice': 203.08,
#   'extendedChange': 0.22,
#   'extendedChangePercent': 0.00108,
#   'extendedPriceTime': 1557260091760,
#   'previousClose': 208.48,
#   'change': -5.62,
#   'changePercent': -0.02696,
#   'iexMarketPercent': 0.022655255810502293,
#   'iexVolume': 869563,
#   'avgTotalVolume': 27470518,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 933375088800,
#   'peRatio': 16.92,
#   'week52High': 233.47,
#   'week52Low': 142,
#   'ytdChange': 0.293202},
#  'bids': [],
#  'asks': [],
#  'trades': [{'price': 202.89,
#    'size': 100,
#    'tradeId': 1369002144,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259199899},
#   {'price': 202.89,
#    'size': 100,
#    'tradeId': 1369002130,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259199899},
#   {'price': 202.85,
#    'size': 100,
#    'tradeId': 1368943918,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259199769},
#   {'price': 202.83,
#    'size': 100,
#    'tradeId': 1368817668,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259199419},
#   {'price': 202.76,
#    'size': 300,
#    'tradeId': 1368669281,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': True,
#    'timestamp': 1557259199027},
#   {'price': 202.75,
#    'size': 100,
#    'tradeId': 1368668777,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259199027},
#   {'price': 202.75,
#    'size': 100,
#    'tradeId': 1368668745,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259199027},
#   {'price': 202.79,
#    'size': 100,
#    'tradeId': 1368549344,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259198487},
#   {'price': 202.79,
#    'size': 100,
#    'tradeId': 1368549338,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259198487},
#   {'price': 202.82,
#    'size': 100,
#    'tradeId': 1368496168,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259198202},
#   {'price': 202.82,
#    'size': 12,
#    'tradeId': 1368271085,
#    'isISO': False,
#    'isOddLot': True,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259197370},
#   {'price': 202.82,
#    'size': 12,
#    'tradeId': 1368271035,
#    'isISO': False,
#    'isOddLot': True,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259197370},
#   {'price': 202.86,
#    'size': 100,
#    'tradeId': 1368225389,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259197202},
#   {'price': 202.86,
#    'size': 100,
#    'tradeId': 1368225371,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259197202},
#   {'price': 202.89,
#    'size': 100,
#    'tradeId': 1368160699,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259197052},
#   {'price': 202.89,
#    'size': 100,
#    'tradeId': 1368160648,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259197052},
#   {'price': 202.82,
#    'size': 100,
#    'tradeId': 1368110917,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259197002},
#   {'price': 202.82,
#    'size': 100,
#    'tradeId': 1368110875,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259197002},
#   {'price': 202.76,
#    'size': 100,
#    'tradeId': 1368094554,
#    'isISO': False,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259196891},
#   {'price': 202.79,
#    'size': 100,
#    'tradeId': 1367963797,
#    'isISO': True,
#    'isOddLot': False,
#    'isOutsideRegularHours': False,
#    'isSinglePriceCross': False,
#    'isTradeThroughExempt': False,
#    'timestamp': 1557259196401}],
#  'systemEvent': {'systemEvent': 'M', 'timestamp': 1557259200001}}

# %%
c.bookDF(symbol).head()
# Out:
#    avgTotalVolume calculationPrice  change  changePercent   close  \
# 0      27470518.0            close   -5.62       -0.02696  202.86
# 0             NaN              NaN     NaN            NaN     NaN
# 1             NaN              NaN     NaN            NaN     NaN
# 2             NaN              NaN     NaN            NaN     NaN
# 3             NaN              NaN     NaN            NaN     NaN
#
#                 closeTime  companyName  delayedPrice        delayedPriceTime  \
# 0 2019-05-07 20:00:00.243  Apple, Inc.        202.86 2019-05-07 20:00:01.283
# 0                     NaT          NaN           NaN                     NaT
# 1                     NaT          NaN           NaN                     NaT
# 2                     NaT          NaN           NaN                     NaT
# 3                     NaT          NaN           NaN                     NaT
#
#    extendedChange  ...  previousClose   price   size  symbol  \
# 0            0.22  ...         208.48     NaN    NaN    AAPL
# 0             NaN  ...            NaN  202.89  100.0    AAPL
# 1             NaN  ...            NaN  202.89  100.0    AAPL
# 2             NaN  ...            NaN  202.85  100.0    AAPL
# 3             NaN  ...            NaN  202.83  100.0    AAPL
#
#                 timestamp       tradeId   type  week52High week52Low  \
# 0                     NaT           NaN  quote      233.47     142.0
# 0 2019-05-07 19:59:59.899  1.369002e+09    NaN         NaN       NaN
# 1 2019-05-07 19:59:59.899  1.369002e+09    NaN         NaN       NaN
# 2 2019-05-07 19:59:59.769  1.368944e+09    NaN         NaN       NaN
# 3 2019-05-07 19:59:59.419  1.368818e+09    NaN         NaN       NaN
#
#    ytdChange
# 0   0.293202
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
#
# [5 rows x 48 columns]

# %% [markdown]
# ## Cashflow

# %%
c.cashFlow(symbol)
# Out:
# {'symbol': 'AAPL',
#  'cashflow': [{'reportDate': '2019-03-31',
#    'netIncome': 11561000000,
#    'depreciation': 3040000000,
#    'changesInReceivables': 2992000000,
#    'changesInInventories': 70000000,
#    'cashChange': -4954000000,
#    'cashFlow': 11155000000,
#    'capitalExpenditures': -2363000000,
#    'investments': 15749000000,
#    'investingActivityOther': 56000000,
#    'totalInvestingCashFlows': 13348000000,
#    'dividendsPaid': -3443000000,
#    'netBorrowings': -2506000000,
#    'otherFinancingCashFlows': -196000000,
#    'cashFlowFinancing': -29457000000,
#    'exchangeRateEffect': None}]}

# %%
c.cashFlowDF(symbol)
# Out:
#             capitalExpenditures  cashChange     cashFlow  cashFlowFinancing  \
# reportDate
# 2019-03-31          -2363000000 -4954000000  11155000000       -29457000000
#
#             changesInInventories  changesInReceivables  depreciation  \
# reportDate
# 2019-03-31              70000000            2992000000    3040000000
#
#             dividendsPaid  exchangeRateEffect  investingActivityOther  \
# reportDate
# 2019-03-31    -3443000000                 NaN                56000000
#
#             investments  netBorrowings    netIncome  otherFinancingCashFlows  \
# reportDate
# 2019-03-31  15749000000    -2506000000  11561000000               -196000000
#
#             totalInvestingCashFlows symbol
# reportDate
# 2019-03-31              13348000000   AAPL

# %% [markdown]
# ## Collections

# %%
c.collections?
# Out:
# Signature:       c.collections(*args, meth=<function collections at 0x119c3bf28>, **kwargs)
# Call signature:  c.collections(*args, **kwargs)
# Type:            partial
# String form:     functools.partial(<bound method Client.bind of <pyEX.client.Client object at 0x1195fca58>>, meth=<function collections at 0x119c3bf28>)
# File:            /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/functools.py
# Docstring:
# Returns an array of quote objects for a given collection type. Currently supported collection types are sector, tag, and list
#
#
# https://iexcloud.io/docs/api/#collections
#
# Args:
#     tag (string);  Sector, Tag, or List
#     collectionName (string);  Associated name for tag
#     token (string); Access token
#     version (string); API version
#
# Returns:
#     dict: result
# Class docstring:
# partial(func, *args, **keywords) - new function with partial application
# of the given arguments and keywords.

# %%
c.collectionsDF?
# Out:
# Signature:
# c.collectionsDF(
#     *args,
#     meth=<function collectionsDF at 0x119e58048>,
#     **kwargs,
# )
# Call signature:  c.collectionsDF(*args, **kwargs)
# Type:            partial
# String form:     functools.partial(<bound method Client.bind of <pyEX.client.Client object at 0x1195fca58>>, meth=<function collectionsDF at 0x119e58048>)
# File:            /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/functools.py
# Docstring:
# Returns an array of quote objects for a given collection type. Currently supported collection types are sector, tag, and list
#
#
# https://iexcloud.io/docs/api/#collections
#
# Args:
#     tag (string);  Sector, Tag, or List
#     collectionName (string);  Associated name for tag
#     token (string); Access token
#     version (string); API version
#
# Returns:
#     DataFrame: result
# Class docstring:
# partial(func, *args, **keywords) - new function with partial application
# of the given arguments and keywords.

# %% [markdown]
# ## Company

# %%
c.company(symbol)
# Out:
# {'symbol': 'AAPL',
#  'companyName': 'Apple, Inc.',
#  'exchange': 'NASDAQ',
#  'industry': 'Telecommunications Equipment',
#  'website': 'http://www.apple.com',
#  'description': 'Designs, manufactures, and markets mobile communication, media devices, personal computers, and portable digital music players',
#  'CEO': 'Timothy Donald Cook',
#  'securityName': 'Apple Inc.',
#  'issueType': 'cs',
#  'sector': 'Electronic Technology',
#  'employees': 132000,
#  'tags': ['Electronic Technology', 'Telecommunications Equipment']}

# %%
c.companyDF(symbol)
# Out:
#                         CEO  companyName  \
# symbol
# AAPL    Timothy Donald Cook  Apple, Inc.
#
#                                               description  employees exchange  \
# symbol
# AAPL    Designs, manufactures, and markets mobile comm...     132000   NASDAQ
#
#                             industry issueType                 sector  \
# symbol
# AAPL    Telecommunications Equipment        cs  Electronic Technology
#
#        securityName                                               tags  \
# symbol
# AAPL     Apple Inc.  [Electronic Technology, Telecommunications Equ...
#
#                      website
# symbol
# AAPL    http://www.apple.com

# %% [markdown]
# ## Delayed Quote

# %%
c.delayedQuote(symbol)
# Out:
# {'symbol': 'AAPL',
#  'delayedPrice': 203.08,
#  'high': 207.417,
#  'low': 200.825,
#  'delayedSize': 5,
#  'delayedPriceTime': 1557260100013,
#  'totalVolume': 38370354,
#  'processedTime': 1557261004110}

# %%
c.delayedQuoteDF(symbol)
# Out:
#         delayedPrice        delayedPriceTime  delayedSize     high      low  \
# symbol
# AAPL          203.08 2019-05-07 20:15:00.013            5  207.417  200.825
#
#                        processedTime  totalVolume
# symbol
# AAPL   1970-01-01 00:25:57.261004110     38370354

# %% [markdown]
# ## Dividends

# %%
c.dividends(symbol)
# Out:
# [{'exDate': '2019-05-10',
#   'paymentDate': '2019-05-16',
#   'recordDate': '2019-05-13',
#   'declaredDate': '2019-04-30',
#   'amount': 0.77,
#   'flag': 'Increase',
#   'currency': 'USD',
#   'description': 'Apple Hikes Quarterly Dividend 5.5%',
#   'frequency': 'Quarterly',
#   'date': '2019-05-07'},
#  {'exDate': '2019-02-08',
#   'paymentDate': '2019-02-14',
#   'recordDate': '2019-02-11',
#   'declaredDate': '2019-01-29',
#   'amount': 0.73,
#   'flag': 'No Change QoQ',
#   'currency': 'USD',
#   'description': 'Apple Declares Quarterly Dividend of $0.73 Per Share',
#   'frequency': 'Quarterly',
#   'date': '2019-05-07'}]

# %%
c.dividendsDF(symbol)
# Out:
#             amount currency       date declaredDate  \
# exDate
# 2019-05-10    0.77      USD 2019-05-07   2019-04-30
# 2019-02-08    0.73      USD 2019-05-07   2019-01-29
#
#                                                   description           flag  \
# exDate
# 2019-05-10                Apple Hikes Quarterly Dividend 5.5%       Increase
# 2019-02-08  Apple Declares Quarterly Dividend of $0.73 Per...  No Change QoQ
#
#             frequency paymentDate recordDate
# exDate
# 2019-05-10  Quarterly  2019-05-16 2019-05-13
# 2019-02-08  Quarterly  2019-02-14 2019-02-11

# %% [markdown]
# ## Earnings

# %%
c.earnings(symbol)
# Out:
# {'symbol': 'AAPL',
#  'earnings': [{'actualEPS': 2.46,
#    'consensusEPS': 2.36,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 34,
#    'EPSSurpriseDollar': 0.1,
#    'EPSReportDate': '2019-04-30',
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-03-31',
#    'yearAgo': 2.73,
#    'yearAgoChangePercent': -0.0989}]}

# %%
c.earningsDF(symbol)
# Out:
#                EPSSurpriseDollar  actualEPS announceTime  consensusEPS  \
# EPSReportDate
# 2019-04-30                   0.1       2.46          AMC          2.36
#
#               fiscalEndDate fiscalPeriod  numberOfEstimates  yearAgo  \
# EPSReportDate
# 2019-04-30       2019-03-31      Q1 2019                 34     2.73
#
#                yearAgoChangePercent symbol
# EPSReportDate
# 2019-04-30                  -0.0989   AAPL

# %% [markdown]
# ## Earnings Today

# %%
c.earningsToday()
# Out:
# {'bto': [{'consensusEPS': '0.09',
#    'announceTime': 'BTO',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-03-31',
#    'symbol': 'CPGVY',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'CPGVY',
#     'companyName': 'CG Power & Industrial Solutions Ltd.',
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': None,
#     'latestSource': 'N/A',
#     'latestTime': 'N/A',
#     'latestUpdate': None,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': None,
#     'change': None,
#     'changePercent': None,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': None,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': None,
#     'peRatio': None,
#     'week52High': 0,
#     'week52Low': 0,
#     'ytdChange': 0}}],
#  'amc': [{'consensusEPS': '5.19',
#    'announceTime': 'AMC',
#    'numberOfEstimates': 31,
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-04-30',
#    'symbol': 'AVGO',
#    'reportDate': '2019-06-12',
#    'quote': {'symbol': 'AVGO',
#     'companyName': 'Broadcom, Inc.',
#     'calculationPrice': 'tops',
#     'open': 281.52,
#     'openTime': 1560432600943,
#     'close': 279.73,
#     'closeTime': 1560369600575,
#     'high': 282.89,
#     'low': 277.41,
#     'latestPrice': 278.05,
#     'latestSource': 'IEX real time price',
#     'latestTime': '11:51:28 AM',
#     'latestUpdate': 1560441088647,
#     'latestVolume': 1011386,
#     'iexRealtimePrice': 278.05,
#     'iexRealtimeSize': 60,
#     'iexLastUpdated': 1560441088647,
#     'delayedPrice': 277.75,
#     'delayedPriceTime': 1560440345331,
#     'extendedPrice': 281.6,
#     'extendedChange': 3.55,
#     'extendedChangePercent': 0.01277,
#     'extendedPriceTime': 1560432516931,
#     'previousClose': 279.73,
#     'change': -1.68,
#     'changePercent': -0.00601,
#     'iexMarketPercent': 0.022085534108639036,
#     'iexVolume': 22337,
#     'avgTotalVolume': 2925420,
#     'iexBidPrice': 245,
#     'iexBidSize': 100,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 110064980300,
#     'peRatio': 17.95,
#     'week52High': 323.2,
#     'week52Low': 197.45,
#     'ytdChange': 0.097418}},
#   {'consensusEPS': '0.01',
#    'announceTime': 'AMC',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-04-30',
#    'symbol': 'MMMB',
#    'reportDate': '2019-06-12',
#    'quote': {'symbol': 'MMMB',
#     'companyName': "MamaMancini's Holdings, Inc.",
#     'calculationPrice': 'previousclose',
#     'open': None,
#     'openTime': None,
#     'close': None,
#     'closeTime': None,
#     'high': None,
#     'low': None,
#     'latestPrice': 0.5625,
#     'latestSource': 'Previous close',
#     'latestTime': 'June 12, 2019',
#     'latestUpdate': 1560312000000,
#     'latestVolume': 0,
#     'iexRealtimePrice': None,
#     'iexRealtimeSize': None,
#     'iexLastUpdated': None,
#     'delayedPrice': None,
#     'delayedPriceTime': None,
#     'extendedPrice': None,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': None,
#     'previousClose': 0.5625,
#     'change': 0,
#     'changePercent': 0,
#     'iexMarketPercent': None,
#     'iexVolume': None,
#     'avgTotalVolume': 13017,
#     'iexBidPrice': None,
#     'iexBidSize': None,
#     'iexAskPrice': None,
#     'iexAskSize': None,
#     'marketCap': 17924625,
#     'peRatio': 40.76,
#     'week52High': 1.25,
#     'week52Low': 0.33,
#     'ytdChange': -0.147081}}],
#  'other': [{'consensusEPS': '-0.04',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 10,
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-04-30',
#    'symbol': 'HEXO',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'HEXO',
#     'companyName': 'HEXO Corp.',
#     'calculationPrice': 'tops',
#     'open': 6.18,
#     'openTime': 1560432600091,
#     'close': 6.45,
#     'closeTime': 1560369600065,
#     'high': 6.2,
#     'low': 5.88,
#     'latestPrice': 5.93,
#     'latestSource': 'IEX real time price',
#     'latestTime': '11:52:20 AM',
#     'latestUpdate': 1560441140818,
#     'latestVolume': 5497166,
#     'iexRealtimePrice': 5.93,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1560441140818,
#     'delayedPrice': 5.935,
#     'delayedPriceTime': 1560440350234,
#     'extendedPrice': 6.16,
#     'extendedChange': 0.23,
#     'extendedChangePercent': 0.03879,
#     'extendedPriceTime': 1560432600686,
#     'previousClose': 6.45,
#     'change': -0.52,
#     'changePercent': -0.08062,
#     'iexMarketPercent': 0.004538520393962998,
#     'iexVolume': 24949,
#     'avgTotalVolume': 4067398,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 5.94,
#     'iexAskSize': 200,
#     'marketCap': 1247885480,
#     'peRatio': -52.39,
#     'week52High': 8.4,
#     'week52Low': 3.02,
#     'ytdChange': 0.5986739999999999}},
#   {'consensusEPS': '-0.57',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-03-31',
#    'symbol': 'TUFN',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'TUFN',
#     'companyName': 'Tufin Software Technologies Ltd.',
#     'calculationPrice': 'tops',
#     'open': 22.45,
#     'openTime': 1560432604115,
#     'close': 22.17,
#     'closeTime': 1560369891355,
#     'high': 23.39,
#     'low': 20.65,
#     'latestPrice': 20.6,
#     'latestSource': 'IEX real time price',
#     'latestTime': '11:41:32 AM',
#     'latestUpdate': 1560440492032,
#     'latestVolume': 357532,
#     'iexRealtimePrice': 20.6,
#     'iexRealtimeSize': 300,
#     'iexLastUpdated': 1560440492032,
#     'delayedPrice': 20.9,
#     'delayedPriceTime': 1560440301195,
#     'extendedPrice': 22.74,
#     'extendedChange': 2.14,
#     'extendedChangePercent': 0.10388,
#     'extendedPriceTime': 1560432586019,
#     'previousClose': 22.17,
#     'change': -1.57,
#     'changePercent': -0.07082,
#     'iexMarketPercent': 0.035761833905776266,
#     'iexVolume': 12786,
#     'avgTotalVolume': 148066,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 22.04,
#     'iexAskSize': 100,
#     'marketCap': 668202200,
#     'peRatio': None,
#     'week52High': 24.89,
#     'week52Low': 18.05,
#     'ytdChange': 0.08991299999999999}},
#   {'consensusEPS': '0.46',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 5,
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-04-30',
#    'symbol': 'CNR',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'CNR',
#     'companyName': 'Cornerstone Building Brands, Inc.',
#     'calculationPrice': 'tops',
#     'open': 4.26,
#     'openTime': 1560432600160,
#     'close': 4.24,
#     'closeTime': 1560369721192,
#     'high': 4.41,
#     'low': 4.24,
#     'latestPrice': 4.355,
#     'latestSource': 'IEX real time price',
#     'latestTime': '11:54:03 AM',
#     'latestUpdate': 1560441243829,
#     'latestVolume': 188039,
#     'iexRealtimePrice': 4.355,
#     'iexRealtimeSize': 200,
#     'iexLastUpdated': 1560441243829,
#     'delayedPrice': 4.345,
#     'delayedPriceTime': 1560440351031,
#     'extendedPrice': 0,
#     'extendedChange': None,
#     'extendedChangePercent': None,
#     'extendedPriceTime': 1560460212047,
#     'previousClose': 4.24,
#     'change': 0.115,
#     'changePercent': 0.02712,
#     'iexMarketPercent': 0.041252080685389735,
#     'iexVolume': 7757,
#     'avgTotalVolume': 1073638,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 4.36,
#     'iexAskSize': 200,
#     'marketCap': 546613470,
#     'peRatio': 11.29,
#     'week52High': 22.59,
#     'week52Low': 4.2,
#     'ytdChange': -0.411291}},
#   {'consensusEPS': '0.03',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-03-31',
#    'symbol': 'SECO',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'SECO',
#     'companyName': 'Secoo Holding Ltd.',
#     'calculationPrice': 'sip',
#     'open': 8.03,
#     'openTime': 1560432600273,
#     'close': 7.75,
#     'closeTime': 1560369600567,
#     'high': 8.25,
#     'low': 7.858,
#     'latestPrice': 8.03,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '11:39:14 AM',
#     'latestUpdate': 1560440354792,
#     'latestVolume': 121547,
#     'iexRealtimePrice': 8.04,
#     'iexRealtimeSize': 1094,
#     'iexLastUpdated': 1560440106981,
#     'delayedPrice': 8.03,
#     'delayedPriceTime': 1560440354792,
#     'extendedPrice': 8.09,
#     'extendedChange': 0.06,
#     'extendedChangePercent': 0.00747,
#     'extendedPriceTime': 1560432478589,
#     'previousClose': 7.75,
#     'change': 0.28,
#     'changePercent': 0.03613,
#     'iexMarketPercent': 0.06856606909261438,
#     'iexVolume': 8334,
#     'avgTotalVolume': 87770,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': None,
#     'peRatio': 17.73,
#     'week52High': 15.48,
#     'week52Low': 7.03,
#     'ytdChange': -0.10466800000000001}},
#   {'consensusEPS': '-0.99',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 4,
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-04-30',
#    'symbol': 'PTE',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'PTE',
#     'companyName': 'PolarityTE, Inc.',
#     'calculationPrice': 'tops',
#     'open': 5.55,
#     'openTime': 1560432600453,
#     'close': 5.54,
#     'closeTime': 1560369600201,
#     'high': 5.75,
#     'low': 5.4,
#     'latestPrice': 5.52,
#     'latestSource': 'IEX real time price',
#     'latestTime': '11:45:49 AM',
#     'latestUpdate': 1560440749730,
#     'latestVolume': 120309,
#     'iexRealtimePrice': 5.52,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1560440749730,
#     'delayedPrice': 5.477,
#     'delayedPriceTime': 1560440175356,
#     'extendedPrice': 5.6,
#     'extendedChange': 0.08,
#     'extendedChangePercent': 0.01449,
#     'extendedPriceTime': 1560432599135,
#     'previousClose': 5.54,
#     'change': -0.02,
#     'changePercent': -0.00361,
#     'iexMarketPercent': 0.005037029648654714,
#     'iexVolume': 606,
#     'avgTotalVolume': 428467,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 138927360,
#     'peRatio': -0.89,
#     'week52High': 41.22,
#     'week52Low': 4.96,
#     'ytdChange': -0.634768}},
#   {'consensusEPS': '0.13',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-04-30',
#    'symbol': 'CODA',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'CODA',
#     'companyName': 'Coda Octopus Group, Inc.',
#     'calculationPrice': 'sip',
#     'open': 12.12,
#     'openTime': 1560432600774,
#     'close': 9.71,
#     'closeTime': 1560369600405,
#     'high': 14.852,
#     'low': 11.7,
#     'latestPrice': 13.877,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '11:39:05 AM',
#     'latestUpdate': 1560440345508,
#     'latestVolume': 2697449,
#     'iexRealtimePrice': 14.02,
#     'iexRealtimeSize': 2,
#     'iexLastUpdated': 1560439545986,
#     'delayedPrice': 13.877,
#     'delayedPriceTime': 1560440345508,
#     'extendedPrice': 12.15,
#     'extendedChange': -1.727,
#     'extendedChangePercent': -0.12445,
#     'extendedPriceTime': 1560432534572,
#     'previousClose': 9.71,
#     'change': 4.167,
#     'changePercent': 0.42915,
#     'iexMarketPercent': 0.0040256553506665,
#     'iexVolume': 10859,
#     'avgTotalVolume': 211342,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 147984328,
#     'peRatio': 23.04,
#     'week52High': 19.2,
#     'week52Low': 3.4,
#     'ytdChange': 1.050185}},
#   {'consensusEPS': '-0.11',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-03-31',
#    'symbol': 'ACST',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'ACST',
#     'companyName': 'Acasti Pharma, Inc.',
#     'calculationPrice': 'sip',
#     'open': 0.8854,
#     'openTime': 1560432600879,
#     'close': 0.875,
#     'closeTime': 1560369600256,
#     'high': 0.8998,
#     'low': 0.895,
#     'latestPrice': 0.895,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '11:19:26 AM',
#     'latestUpdate': 1560439166180,
#     'latestVolume': 12273,
#     'iexRealtimePrice': 0,
#     'iexRealtimeSize': 0,
#     'iexLastUpdated': 0,
#     'delayedPrice': 0.895,
#     'delayedPriceTime': 1560439166180,
#     'extendedPrice': 0.875,
#     'extendedChange': -0.02,
#     'extendedChangePercent': -0.02235,
#     'extendedPriceTime': 1560285115945,
#     'previousClose': 0.875,
#     'change': 0.02,
#     'changePercent': 0.02286,
#     'iexMarketPercent': None,
#     'iexVolume': 0,
#     'avgTotalVolume': 205483,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 1.25,
#     'iexAskSize': 100,
#     'marketCap': 69901290,
#     'peRatio': -0.94,
#     'week52High': 1.8,
#     'week52Low': 0.4333,
#     'ytdChange': -0.004918000000000002}},
#   {'consensusEPS': '0.16',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q1 2019',
#    'fiscalEndDate': '2019-03-31',
#    'symbol': 'CRWS',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'CRWS',
#     'companyName': 'Crown Crafts, Inc.',
#     'calculationPrice': 'sip',
#     'open': 4.9,
#     'openTime': 1560432600725,
#     'close': 4.8,
#     'closeTime': 1560369600313,
#     'high': 5.05,
#     'low': 4.9,
#     'latestPrice': 5.02,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '11:28:50 AM',
#     'latestUpdate': 1560439730801,
#     'latestVolume': 23100,
#     'iexRealtimePrice': 0,
#     'iexRealtimeSize': 0,
#     'iexLastUpdated': 0,
#     'delayedPrice': 5.02,
#     'delayedPriceTime': 1560439730801,
#     'extendedPrice': 4.9,
#     'extendedChange': -0.12,
#     'extendedChangePercent': -0.0239,
#     'extendedPriceTime': 1560430131119,
#     'previousClose': 4.8,
#     'change': 0.22,
#     'changePercent': 0.04583,
#     'iexMarketPercent': None,
#     'iexVolume': 0,
#     'avgTotalVolume': 54801,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 50817460,
#     'peRatio': 10.39,
#     'week52High': 6.25,
#     'week52Low': 4.01,
#     'ytdChange': -0.144726}},
#   {'consensusEPS': '-1.35',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 2,
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-04-30',
#    'symbol': 'ONCS',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'ONCS',
#     'companyName': 'OncoSec Medical, Inc.',
#     'calculationPrice': 'tops',
#     'open': 2.8,
#     'openTime': 1560432600516,
#     'close': 2.8,
#     'closeTime': 1560369600453,
#     'high': 2.85,
#     'low': 2.8,
#     'latestPrice': 2.835,
#     'latestSource': 'IEX real time price',
#     'latestTime': '11:42:53 AM',
#     'latestUpdate': 1560440573973,
#     'latestVolume': 96945,
#     'iexRealtimePrice': 2.835,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1560440573973,
#     'delayedPrice': 2.84,
#     'delayedPriceTime': 1560440028293,
#     'extendedPrice': 2.9,
#     'extendedChange': 0.065,
#     'extendedChangePercent': 0.02293,
#     'extendedPriceTime': 1560432598042,
#     'previousClose': 2.8,
#     'change': 0.035,
#     'changePercent': 0.0125,
#     'iexMarketPercent': 0.00850997988550209,
#     'iexVolume': 825,
#     'avgTotalVolume': 277410,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 18373295,
#     'peRatio': -0.41,
#     'week52High': 19.6,
#     'week52Low': 2.3,
#     'ytdChange': -0.560019}},
#   {'consensusEPS': '-0.08',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-04-30',
#    'symbol': 'FRAN',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'FRAN',
#     'companyName': "Francesca's Holdings Corp.",
#     'calculationPrice': 'tops',
#     'open': 0.505,
#     'openTime': 1560432600953,
#     'close': 0.505,
#     'closeTime': 1560369600480,
#     'high': 0.505,
#     'low': 0.482,
#     'latestPrice': 0.4811,
#     'latestSource': 'IEX real time price',
#     'latestTime': '11:50:47 AM',
#     'latestUpdate': 1560441047122,
#     'latestVolume': 228449,
#     'iexRealtimePrice': 0.4811,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1560441047122,
#     'delayedPrice': 0.4821,
#     'delayedPriceTime': 1560440226378,
#     'extendedPrice': 0.52,
#     'extendedChange': 0.0389,
#     'extendedChangePercent': 0.08086,
#     'extendedPriceTime': 1560432583173,
#     'previousClose': 0.505,
#     'change': -0.0239,
#     'changePercent': -0.04733,
#     'iexMarketPercent': 0.00043773446152095216,
#     'iexVolume': 100,
#     'avgTotalVolume': 678135,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 16746610,
#     'peRatio': 1.12,
#     'week52High': 8.48,
#     'week52Low': 0.442,
#     'ytdChange': -0.380223}},
#   {'consensusEPS': '-0.10',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 1,
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-04-30',
#    'symbol': 'CHKE',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'CHKE',
#     'companyName': 'Cherokee, Inc.',
#     'calculationPrice': 'sip',
#     'open': 0.72,
#     'openTime': 1560432600891,
#     'close': 0.766,
#     'closeTime': 1560369600200,
#     'high': 0.82,
#     'low': 0.72,
#     'latestPrice': 0.82,
#     'latestSource': '15 minute delayed price',
#     'latestTime': '11:38:36 AM',
#     'latestUpdate': 1560440316677,
#     'latestVolume': 5000,
#     'iexRealtimePrice': 0,
#     'iexRealtimeSize': 0,
#     'iexLastUpdated': 0,
#     'delayedPrice': 0.82,
#     'delayedPriceTime': 1560440316677,
#     'extendedPrice': 0.77,
#     'extendedChange': -0.05,
#     'extendedChangePercent': -0.06098,
#     'extendedPriceTime': 1560432522145,
#     'previousClose': 0.766,
#     'change': 0.054,
#     'changePercent': 0.0705,
#     'iexMarketPercent': None,
#     'iexVolume': 0,
#     'avgTotalVolume': 20201,
#     'iexBidPrice': 0,
#     'iexBidSize': 0,
#     'iexAskPrice': 0,
#     'iexAskSize': 0,
#     'marketCap': 13075720,
#     'peRatio': -0.92,
#     'week52High': 1.25,
#     'week52Low': 0.38,
#     'ytdChange': 0.543577}},
#   {'consensusEPS': '-2.25',
#    'announceTime': 'DMT',
#    'numberOfEstimates': 4,
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-04-30',
#    'symbol': 'FCEL',
#    'reportDate': '2019-06-13',
#    'quote': {'symbol': 'FCEL',
#     'companyName': 'FuelCell Energy, Inc.',
#     'calculationPrice': 'tops',
#     'open': 0.47,
#     'openTime': 1560432600218,
#     'close': 0.5103,
#     'closeTime': 1560369600564,
#     'high': 0.5222,
#     'low': 0.4101,
#     'latestPrice': 0.4301,
#     'latestSource': 'IEX real time price',
#     'latestTime': '11:47:03 AM',
#     'latestUpdate': 1560440823108,
#     'latestVolume': 3484060,
#     'iexRealtimePrice': 0.4301,
#     'iexRealtimeSize': 100,
#     'iexLastUpdated': 1560440823108,
#     'delayedPrice': 0.4349,
#     'delayedPriceTime': 1560440346630,
#     'extendedPrice': 0.46,
#     'extendedChange': 0.0299,
#     'extendedChangePercent': 0.06952,
#     'extendedPriceTime': 1560432584435,
#     'previousClose': 0.5103,
#     'change': -0.0802,
#     'changePercent': -0.15716,
#     'iexMarketPercent': 0.002944840215151289,
#     'iexVolume': 10260,
#     'avgTotalVolume': 2401743,
#     'iexBidPrice': 0.36,
#     'iexBidSize': 300,
#     'iexAskPrice': 0.4251,
#     'iexAskSize': 700,
#     'marketCap': 6573648,
#     'peRatio': -0.04,
#     'week52High': 22.44,
#     'week52Low': 0.201,
#     'ytdChange': -1.08212}}]}

# %%
c.earningsTodayDF().head()
# Out:
#        EPSReportDate EPSSurpriseDollar  actualEPS announceTime consensusEPS  \
# symbol
# ENIC             NaT               NaN        NaN          BTO        74.82
# HENKY     2019-05-07             -0.05    1.50013          BTO         1.55
# WF               NaT               NaN        NaN          BTO         2.07
# RACE             NaT               NaN        NaN          BTO         0.94
# RDSMY     2019-05-07             -0.02    0.31346          BTO         0.33
#
#        fiscalEndDate fiscalPeriod  numberOfEstimates  quote.avgTotalVolume  \
# symbol
# ENIC      2019-03-31      Q1 2019                1.0              316735.0
# HENKY     2019-03-31      Q1 2019                5.0               47502.0
# WF        2019-03-31      Q1 2019                2.0               16784.0
# RACE      2019-03-31      Q1 2019                7.0              364960.0
# RDSMY     2019-03-31      Q1 2019                7.0              104561.0
#
#        quote.calculationPrice  ...  quote.peRatio  quote.previousClose  \
# symbol                         ...
# ENIC                      sip  ...          10.80                 4.86
# HENKY           previousclose  ...           9.18                24.48
# WF                        sip  ...           4.58                35.72
# RACE                      sip  ...          28.16               132.33
# RDSMY           previousclose  ...          15.29                27.67
#
#         quote.symbol  quote.week52High quote.week52Low  quote.ytdChange  \
# symbol
# ENIC            ENIC              6.00            4.17        -0.039023
# HENKY          HENKY             29.62           22.12        -0.001122
# WF                WF             42.76           32.05        -0.130996
# RACE            RACE            149.85           93.85         0.381309
# RDSMY          RDSMY             29.09           19.45         0.384192
#
#         reportDate  when   yearAgo  yearAgoChangePercent
# symbol
# ENIC    2019-05-07   bto       NaN                   NaN
# HENKY          NaT   bto  1.470080                0.0204
# WF      2019-05-07   bto       NaN                   NaN
# RACE    2019-05-07   bto       NaN                   NaN
# RDSMY          NaT   bto  0.588161               -0.4671
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Effective Spread

# %%
c.spread(symbol)
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-13-e3761beeeffa> in <module>
# ----> 1 c.spread(symbol)
#
# ~/Repos/pyEX/pyEX/client.py in bind(self, meth, *args, **kwargs)
#     316
#     317     def bind(self, *args, meth=None, **kwargs):
# --> 318         return meth(token=self._token, version=self._version, *args, **kwargs)
#     319
#     320     def account(self):
#
# ~/Repos/pyEX/pyEX/stocks.py in spread(symbol, token, version)
#     787     """
#     788     _raiseIfNotStr(symbol)
# --> 789     return _getJson('stock/' + symbol + '/effective-spread', token, version)
#     790
#     791
#
# ~/Repos/pyEX/pyEX/common.py in _getJson(url, token, version)
#     104         if version == 'sandbox':
#     105             return _getJsonIEXCloudSandbox(url, token, version)
# --> 106         return _getJsonIEXCloud(url, token, version)
#     107     return _getJsonOrig(url)
#     108
#
# ~/Repos/pyEX/pyEX/common.py in _getJsonIEXCloud(url, token, version)
#     123     if resp.status_code == 200:
#     124         return resp.json()
# --> 125     raise PyEXception('Response %d - ' % resp.status_code, resp.text)
#     126
#     127
#
# PyEXception: ('Response 403 - ', 'The API key provided is not valid.')

# %%
c.spreadDF(symbol)
# Out:
# ---------------------------------------------------------------------------
# PyEXception                               Traceback (most recent call last)
# <ipython-input-14-cfac350caf85> in <module>
# ----> 1 c.spreadDF(symbol)
#
# ~/Repos/pyEX/pyEX/client.py in bind(self, meth, *args, **kwargs)
#     316
#     317     def bind(self, *args, meth=None, **kwargs):
# --> 318         return meth(token=self._token, version=self._version, *args, **kwargs)
#     319
#     320     def account(self):
#
# ~/Repos/pyEX/pyEX/stocks.py in spreadDF(symbol, token, version)
#     816         DataFrame: result
#     817     """
# --> 818     df = pd.DataFrame(spread(symbol, token, version))
#     819     _toDatetime(df)
#     820     _reindex(df, 'venue')
#
# ~/Repos/pyEX/pyEX/stocks.py in spread(symbol, token, version)
#     787     """
#     788     _raiseIfNotStr(symbol)
# --> 789     return _getJson('stock/' + symbol + '/effective-spread', token, version)
#     790
#     791
#
# ~/Repos/pyEX/pyEX/common.py in _getJson(url, token, version)
#     104         if version == 'sandbox':
#     105             return _getJsonIEXCloudSandbox(url, token, version)
# --> 106         return _getJsonIEXCloud(url, token, version)
#     107     return _getJsonOrig(url)
#     108
#
# ~/Repos/pyEX/pyEX/common.py in _getJsonIEXCloud(url, token, version)
#     123     if resp.status_code == 200:
#     124         return resp.json()
# --> 125     raise PyEXception('Response %d - ' % resp.status_code, resp.text)
#     126
#     127
#
# PyEXception: ('Response 403 - ', 'The API key provided is not valid.')

# %% [markdown]
# ## Estimates

# %%
c.estimates(symbol)
# Out:
# {'symbol': 'AAPL',
#  'estimates': [{'consensusEPS': 2.1,
#    'announceTime': 'AMC',
#    'numberOfEstimates': 38,
#    'reportDate': '2019-07-22',
#    'fiscalPeriod': 'Q2 2019',
#    'fiscalEndDate': '2019-06-30'}]}

# %%
c.estimatesDF(symbol)
# Out:
#               announceTime  consensusEPS fiscalPeriod  numberOfEstimates  \
# fiscalEndDate
# 2019-06-30             AMC          2.11      Q2 2019                 36
#
#               reportDate symbol
# fiscalEndDate
# 2019-06-30    2019-07-22   AAPL

# %% [markdown]
# ## Financials

# %%
c.financials(symbol)
# Out:
# {'symbol': 'AAPL',
#  'financials': [{'reportDate': '2019-03-31',
#    'grossProfit': 21648000000,
#    'costOfRevenue': 36270000000,
#    'operatingRevenue': 57918000000,
#    'totalRevenue': 57918000000,
#    'operatingIncome': 13242000000,
#    'netIncome': 11561000000,
#    'researchAndDevelopment': 3948000000,
#    'operatingExpense': 44676000000,
#    'currentAssets': 123346000000,
#    'totalAssets': 341998000000,
#    'totalLiabilities': 236138000000,
#    'currentCash': 38329000000,
#    'currentDebt': 22429000000,
#    'shortTermDebt': 22429000000,
#    'longTermDebt': 90201000000,
#    'totalCash': 80433000000,
#    'totalDebt': 112630000000,
#    'shareholderEquity': 105860000000,
#    'cashChange': -4954000000,
#    'cashFlow': 11155000000}]}

# %%
c.financialsDF(symbol)
# Out:
#             cashChange     cashFlow  costOfRevenue  currentAssets  \
# reportDate
# 2019-03-31 -4954000000  11155000000    36270000000   123346000000
#
#             currentCash  currentDebt  grossProfit  longTermDebt    netIncome  \
# reportDate
# 2019-03-31  38329000000  22429000000  21648000000   90201000000  11561000000
#
#             operatingExpense  ...  operatingRevenue  researchAndDevelopment  \
# reportDate                    ...
# 2019-03-31       44676000000  ...       57918000000              3948000000
#
#             shareholderEquity  shortTermDebt   totalAssets    totalCash  \
# reportDate
# 2019-03-31       105860000000    22429000000  341998000000  80433000000
#
#                totalDebt  totalLiabilities  totalRevenue  symbol
# reportDate
# 2019-03-31  112630000000      236138000000   57918000000    AAPL
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Fund Ownership

# %%
c.fundOwnership(symbol)
# Out:
# [{'report_date': 1553990400000,
#   'entityProperName': 'Vanguard Total Stock Market Index Fund',
#   'adjHolding': 115271453,
#   'adjMv': 21895812497,
#   'reportedHolding': 115271453,
#   'reportedMv': 21895812497},
#  {'report_date': 1553990400000,
#   'entityProperName': 'Vanguard 500 Index Fund',
#   'adjHolding': 86850254,
#   'adjMv': 16497205747,
#   'reportedHolding': 86850254,
#   'reportedMv': 16497205747},
#  {'report_date': 1556582400000,
#   'entityProperName': 'Spdr S&p 500 Etf',
#   'adjHolding': 50728910,
#   'adjMv': 10179770370,
#   'reportedHolding': 50728910,
#   'reportedMv': 10179770370},
#  {'report_date': 1546214400000,
#   'entityProperName': 'Government Pension Fund - Global (the)',
#   'adjHolding': 45933028,
#   'adjMv': 7245475837,
#   'reportedHolding': 45933028,
#   'reportedMv': 7245475993},
#  {'report_date': 1553990400000,
#   'entityProperName': 'Vanguard Institutional Index Fund',
#   'adjHolding': 42377520,
#   'adjMv': 8049609924,
#   'reportedHolding': 42377520,
#   'reportedMv': 8049609924},
#  {'report_date': 1556582400000,
#   'entityProperName': 'Invesco Qqq Trust',
#   'adjHolding': 38489317,
#   'adjMv': 7723651242,
#   'reportedHolding': 38489317,
#   'reportedMv': 7723651242},
#  {'report_date': 1553990400000,
#   'entityProperName': 'Fidelity 500 Index Fund',
#   'adjHolding': 35045571,
#   'adjMv': 6656906211,
#   'reportedHolding': 35045571,
#   'reportedMv': 6656906211},
#  {'report_date': 1556582400000,
#   'entityProperName': 'Ishares Tr. - Core S&p 500 Etf',
#   'adjHolding': 32560950,
#   'adjMv': 6534005837,
#   'reportedHolding': 32560950,
#   'reportedMv': 6534005837},
#  {'report_date': 1548892800000,
#   'entityProperName': 'Blackrock (japan) Ishares Core Msci Kokusai Etf (1657)',
#   'adjHolding': 30589798,
#   'adjMv': 5091365979,
#   'reportedHolding': 30589798,
#   'reportedMv': 1323161},
#  {'report_date': 1553990400000,
#   'entityProperName': 'Vanguard Growth Index Fund',
#   'adjHolding': 29248944,
#   'adjMv': 5555836913,
#   'reportedHolding': 29248944,
#   'reportedMv': 5555836913}]

# %%
c.fundOwnershipDF(symbol)
# Out:
#    adjHolding        adjMv                                   entityProperName  \
# 0   115271453  21895812497             Vanguard Total Stock Market Index Fund
# 1    86850254  16497205747                            Vanguard 500 Index Fund
# 2    50728910  10179770370                                   Spdr S&p 500 Etf
# 3    45933028   7245475837             Government Pension Fund - Global (the)
# 4    42377520   8049609924                  Vanguard Institutional Index Fund
# 5    38489317   7723651242                                  Invesco Qqq Trust
# 6    35045571   6656906211                            Fidelity 500 Index Fund
# 7    32560950   6534005837                     Ishares Tr. - Core S&p 500 Etf
# 8    30589798   5091365979  Blackrock (japan) Ishares Core Msci Kokusai Et...
# 9    29248944   5555836913                         Vanguard Growth Index Fund
#
#   report_date  reportedHolding   reportedMv
# 0  2019-03-31        115271453  21895812497
# 1  2019-03-31         86850254  16497205747
# 2  2019-04-30         50728910  10179770370
# 3  2018-12-31         45933028   7245475993
# 4  2019-03-31         42377520   8049609924
# 5  2019-04-30         38489317   7723651242
# 6  2019-03-31         35045571   6656906211
# 7  2019-04-30         32560950   6534005837
# 8  2019-01-31         30589798      1323161
# 9  2019-03-31         29248944   5555836913

# %% [markdown]
# ## Historical Prices

# %%
c.chart(symbol)
# Out:
# [{'date': '2019-04-08',
#   'open': 196.42,
#   'close': 200.1,
#   'high': 200.23,
#   'low': 196.34,
#   'volume': 25881697,
#   'uOpen': 196.42,
#   'uClose': 200.1,
#   'uHigh': 200.23,
#   'uLow': 196.34,
#   'uVolume': 25881697,
#   'change': 0,
#   'changePercent': 0,
#   'label': 'Apr 8',
#   'changeOverTime': 0},
#  {'date': '2019-04-09',
#   'open': 200.32,
#   'close': 199.5,
#   'high': 202.85,
#   'low': 199.23,
#   'volume': 35768237,
#   'uOpen': 200.32,
#   'uClose': 199.5,
#   'uHigh': 202.85,
#   'uLow': 199.23,
#   'uVolume': 35768237,
#   'change': -0.6,
#   'changePercent': -0.2999,
#   'label': 'Apr 9',
#   'changeOverTime': -0.002999},
#  {'date': '2019-04-10',
#   'open': 198.68,
#   'close': 200.62,
#   'high': 200.74,
#   'low': 198.18,
#   'volume': 21695288,
#   'uOpen': 198.68,
#   'uClose': 200.62,
#   'uHigh': 200.74,
#   'uLow': 198.18,
#   'uVolume': 21695288,
#   'change': 1.12,
#   'changePercent': 0.5614,
#   'label': 'Apr 10',
#   'changeOverTime': 0.002599},
#  {'date': '2019-04-11',
#   'open': 200.85,
#   'close': 198.95,
#   'high': 201,
#   'low': 198.44,
#   'volume': 20900808,
#   'uOpen': 200.85,
#   'uClose': 198.95,
#   'uHigh': 201,
#   'uLow': 198.44,
#   'uVolume': 20900808,
#   'change': -1.67,
#   'changePercent': -0.8324,
#   'label': 'Apr 11',
#   'changeOverTime': -0.005747},
#  {'date': '2019-04-12',
#   'open': 199.2,
#   'close': 198.87,
#   'high': 200.14,
#   'low': 196.21,
#   'volume': 27760668,
#   'uOpen': 199.2,
#   'uClose': 198.87,
#   'uHigh': 200.14,
#   'uLow': 196.21,
#   'uVolume': 27760668,
#   'change': -0.08,
#   'changePercent': -0.0402,
#   'label': 'Apr 12',
#   'changeOverTime': -0.006147},
#  {'date': '2019-04-15',
#   'open': 198.58,
#   'close': 199.23,
#   'high': 199.85,
#   'low': 198.01,
#   'volume': 17536646,
#   'uOpen': 198.58,
#   'uClose': 199.23,
#   'uHigh': 199.85,
#   'uLow': 198.01,
#   'uVolume': 17536646,
#   'change': 0.36,
#   'changePercent': 0.181,
#   'label': 'Apr 15',
#   'changeOverTime': -0.004348},
#  {'date': '2019-04-16',
#   'open': 199.46,
#   'close': 199.25,
#   'high': 201.37,
#   'low': 198.56,
#   'volume': 25696385,
#   'uOpen': 199.46,
#   'uClose': 199.25,
#   'uHigh': 201.37,
#   'uLow': 198.56,
#   'uVolume': 25696385,
#   'change': 0.02,
#   'changePercent': 0.01,
#   'label': 'Apr 16',
#   'changeOverTime': -0.004248},
#  {'date': '2019-04-17',
#   'open': 199.54,
#   'close': 203.13,
#   'high': 203.38,
#   'low': 198.61,
#   'volume': 28906780,
#   'uOpen': 199.54,
#   'uClose': 203.13,
#   'uHigh': 203.38,
#   'uLow': 198.61,
#   'uVolume': 28906780,
#   'change': 3.88,
#   'changePercent': 1.9473,
#   'label': 'Apr 17',
#   'changeOverTime': 0.015142},
#  {'date': '2019-04-18',
#   'open': 203.12,
#   'close': 203.86,
#   'high': 204.15,
#   'low': 202.52,
#   'volume': 24195766,
#   'uOpen': 203.12,
#   'uClose': 203.86,
#   'uHigh': 204.15,
#   'uLow': 202.52,
#   'uVolume': 24195766,
#   'change': 0.73,
#   'changePercent': 0.3594,
#   'label': 'Apr 18',
#   'changeOverTime': 0.018791},
#  {'date': '2019-04-22',
#   'open': 202.83,
#   'close': 204.53,
#   'high': 204.94,
#   'low': 202.34,
#   'volume': 19439545,
#   'uOpen': 202.83,
#   'uClose': 204.53,
#   'uHigh': 204.94,
#   'uLow': 202.34,
#   'uVolume': 19439545,
#   'change': 0.67,
#   'changePercent': 0.3287,
#   'label': 'Apr 22',
#   'changeOverTime': 0.022139},
#  {'date': '2019-04-23',
#   'open': 204.43,
#   'close': 207.48,
#   'high': 207.75,
#   'low': 203.9,
#   'volume': 23322991,
#   'uOpen': 204.43,
#   'uClose': 207.48,
#   'uHigh': 207.75,
#   'uLow': 203.9,
#   'uVolume': 23322991,
#   'change': 2.95,
#   'changePercent': 1.4423,
#   'label': 'Apr 23',
#   'changeOverTime': 0.036882},
#  {'date': '2019-04-24',
#   'open': 207.36,
#   'close': 207.16,
#   'high': 208.48,
#   'low': 207.05,
#   'volume': 17540609,
#   'uOpen': 207.36,
#   'uClose': 207.16,
#   'uHigh': 208.48,
#   'uLow': 207.05,
#   'uVolume': 17540609,
#   'change': -0.32,
#   'changePercent': -0.1542,
#   'label': 'Apr 24',
#   'changeOverTime': 0.035282},
#  {'date': '2019-04-25',
#   'open': 206.83,
#   'close': 205.28,
#   'high': 207.76,
#   'low': 205.12,
#   'volume': 18543206,
#   'uOpen': 206.83,
#   'uClose': 205.28,
#   'uHigh': 207.76,
#   'uLow': 205.12,
#   'uVolume': 18543206,
#   'change': -1.88,
#   'changePercent': -0.9075,
#   'label': 'Apr 25',
#   'changeOverTime': 0.025887},
#  {'date': '2019-04-26',
#   'open': 204.9,
#   'close': 204.3,
#   'high': 205,
#   'low': 202.12,
#   'volume': 18649102,
#   'uOpen': 204.9,
#   'uClose': 204.3,
#   'uHigh': 205,
#   'uLow': 202.12,
#   'uVolume': 18649102,
#   'change': -0.98,
#   'changePercent': -0.4774,
#   'label': 'Apr 26',
#   'changeOverTime': 0.02099},
#  {'date': '2019-04-29',
#   'open': 204.4,
#   'close': 204.61,
#   'high': 205.97,
#   'low': 203.86,
#   'volume': 22204716,
#   'uOpen': 204.4,
#   'uClose': 204.61,
#   'uHigh': 205.97,
#   'uLow': 203.86,
#   'uVolume': 22204716,
#   'change': 0.31,
#   'changePercent': 0.1517,
#   'label': 'Apr 29',
#   'changeOverTime': 0.022539},
#  {'date': '2019-04-30',
#   'open': 203.06,
#   'close': 200.67,
#   'high': 203.4,
#   'low': 199.11,
#   'volume': 46534923,
#   'uOpen': 203.06,
#   'uClose': 200.67,
#   'uHigh': 203.4,
#   'uLow': 199.11,
#   'uVolume': 46534923,
#   'change': -3.94,
#   'changePercent': -1.9256,
#   'label': 'Apr 30',
#   'changeOverTime': 0.002849},
#  {'date': '2019-05-01',
#   'open': 209.88,
#   'close': 210.52,
#   'high': 215.31,
#   'low': 209.23,
#   'volume': 64827328,
#   'uOpen': 209.88,
#   'uClose': 210.52,
#   'uHigh': 215.31,
#   'uLow': 209.23,
#   'uVolume': 64827328,
#   'change': 9.85,
#   'changePercent': 4.9086,
#   'label': 'May 1',
#   'changeOverTime': 0.052074},
#  {'date': '2019-05-02',
#   'open': 209.84,
#   'close': 209.15,
#   'high': 212.65,
#   'low': 208.13,
#   'volume': 31996324,
#   'uOpen': 209.84,
#   'uClose': 209.15,
#   'uHigh': 212.65,
#   'uLow': 208.13,
#   'uVolume': 31996324,
#   'change': -1.37,
#   'changePercent': -0.6508,
#   'label': 'May 2',
#   'changeOverTime': 0.045227},
#  {'date': '2019-05-03',
#   'open': 210.89,
#   'close': 211.75,
#   'high': 211.84,
#   'low': 210.23,
#   'volume': 20892378,
#   'uOpen': 210.89,
#   'uClose': 211.75,
#   'uHigh': 211.84,
#   'uLow': 210.23,
#   'uVolume': 20892378,
#   'change': 2.6,
#   'changePercent': 1.2431,
#   'label': 'May 3',
#   'changeOverTime': 0.058221},
#  {'date': '2019-05-06',
#   'open': 204.29,
#   'close': 208.48,
#   'high': 208.84,
#   'low': 203.5,
#   'volume': 32443113,
#   'uOpen': 204.29,
#   'uClose': 208.48,
#   'uHigh': 208.84,
#   'uLow': 203.5,
#   'uVolume': 32443113,
#   'change': -3.27,
#   'changePercent': -1.5443,
#   'label': 'May 6',
#   'changeOverTime': 0.041879}]

# %%
c.chartDF(symbol)
# Out:
#             change  changeOverTime  changePercent   close    high   label  \
# date
# 2019-04-08    0.00        0.000000         0.0000  200.10  200.23   Apr 8
# 2019-04-09   -0.60       -0.002999        -0.2999  199.50  202.85   Apr 9
# 2019-04-10    1.12        0.002599         0.5614  200.62  200.74  Apr 10
# 2019-04-11   -1.67       -0.005747        -0.8324  198.95  201.00  Apr 11
# 2019-04-12   -0.08       -0.006147        -0.0402  198.87  200.14  Apr 12
# 2019-04-15    0.36       -0.004348         0.1810  199.23  199.85  Apr 15
# 2019-04-16    0.02       -0.004248         0.0100  199.25  201.37  Apr 16
# 2019-04-17    3.88        0.015142         1.9473  203.13  203.38  Apr 17
# 2019-04-18    0.73        0.018791         0.3594  203.86  204.15  Apr 18
# 2019-04-22    0.67        0.022139         0.3287  204.53  204.94  Apr 22
# 2019-04-23    2.95        0.036882         1.4423  207.48  207.75  Apr 23
# 2019-04-24   -0.32        0.035282        -0.1542  207.16  208.48  Apr 24
# 2019-04-25   -1.88        0.025887        -0.9075  205.28  207.76  Apr 25
# 2019-04-26   -0.98        0.020990        -0.4774  204.30  205.00  Apr 26
# 2019-04-29    0.31        0.022539         0.1517  204.61  205.97  Apr 29
# 2019-04-30   -3.94        0.002849        -1.9256  200.67  203.40  Apr 30
# 2019-05-01    9.85        0.052074         4.9086  210.52  215.31   May 1
# 2019-05-02   -1.37        0.045227        -0.6508  209.15  212.65   May 2
# 2019-05-03    2.60        0.058221         1.2431  211.75  211.84   May 3
# 2019-05-06   -3.27        0.041879        -1.5443  208.48  208.84   May 6
#
#                low    open  uClose   uHigh    uLow   uOpen   uVolume    volume
# date
# 2019-04-08  196.34  196.42  200.10  200.23  196.34  196.42  25881697  25881697
# 2019-04-09  199.23  200.32  199.50  202.85  199.23  200.32  35768237  35768237
# 2019-04-10  198.18  198.68  200.62  200.74  198.18  198.68  21695288  21695288
# 2019-04-11  198.44  200.85  198.95  201.00  198.44  200.85  20900808  20900808
# 2019-04-12  196.21  199.20  198.87  200.14  196.21  199.20  27760668  27760668
# 2019-04-15  198.01  198.58  199.23  199.85  198.01  198.58  17536646  17536646
# 2019-04-16  198.56  199.46  199.25  201.37  198.56  199.46  25696385  25696385
# 2019-04-17  198.61  199.54  203.13  203.38  198.61  199.54  28906780  28906780
# 2019-04-18  202.52  203.12  203.86  204.15  202.52  203.12  24195766  24195766
# 2019-04-22  202.34  202.83  204.53  204.94  202.34  202.83  19439545  19439545
# 2019-04-23  203.90  204.43  207.48  207.75  203.90  204.43  23322991  23322991
# 2019-04-24  207.05  207.36  207.16  208.48  207.05  207.36  17540609  17540609
# 2019-04-25  205.12  206.83  205.28  207.76  205.12  206.83  18543206  18543206
# 2019-04-26  202.12  204.90  204.30  205.00  202.12  204.90  18649102  18649102
# 2019-04-29  203.86  204.40  204.61  205.97  203.86  204.40  22204716  22204716
# 2019-04-30  199.11  203.06  200.67  203.40  199.11  203.06  46534923  46534923
# 2019-05-01  209.23  209.88  210.52  215.31  209.23  209.88  64827328  64827328
# 2019-05-02  208.13  209.84  209.15  212.65  208.13  209.84  31996324  31996324
# 2019-05-03  210.23  210.89  211.75  211.84  210.23  210.89  20892378  20892378
# 2019-05-06  203.50  204.29  208.48  208.84  203.50  204.29  32443113  32443113

# %% [markdown]
# ## Income Statement

# %%
c.incomeStatement(symbol)
# Out:
# {'symbol': 'AAPL',
#  'income': [{'reportDate': '2019-03-31',
#    'totalRevenue': 57918000000,
#    'costOfRevenue': 36270000000,
#    'grossProfit': 21648000000,
#    'researchAndDevelopment': 3948000000,
#    'sellingGeneralAndAdmin': 4458000000,
#    'operatingExpense': 44676000000,
#    'operatingIncome': 13242000000,
#    'otherIncomeExpenseNet': 551000000,
#    'ebit': 13242000000,
#    'interestIncome': 1010000000,
#    'pretaxIncome': 13793000000,
#    'incomeTax': 2232000000,
#    'minorityInterest': 0,
#    'netIncome': 11561000000,
#    'netIncomeBasic': 11561000000}]}

# %%
c.incomeStatementDF(symbol)
# Out:
#             costOfRevenue         ebit  grossProfit   incomeTax  \
# reportDate
# 2019-03-31    36270000000  13242000000  21648000000  2232000000
#
#             interestIncome  minorityInterest    netIncome  netIncomeBasic  \
# reportDate
# 2019-03-31      1010000000                 0  11561000000     11561000000
#
#             operatingExpense  operatingIncome  otherIncomeExpenseNet  \
# reportDate
# 2019-03-31       44676000000      13242000000              551000000
#
#             pretaxIncome  researchAndDevelopment  sellingGeneralAndAdmin  \
# reportDate
# 2019-03-31   13793000000              3948000000              4458000000
#
#             totalRevenue symbol
# reportDate
# 2019-03-31   57918000000   AAPL

# %% [markdown]
# ## Insider Roster

# %%
c.insiderRoster(symbol)
# Out:
# [{'position': 3235000,
#   'reportDate': 1553990400000,
#   'entityName': 'WELLCOME TRUST LTD /DIRECT INVESTMENTS/'},
#  {'position': 1147283,
#   'reportDate': 1551398400000,
#   'entityName': 'Arthur D. Levinson'},
#  {'position': 878425,
#   'reportDate': 1546387200000,
#   'entityName': 'Timothy Donald Cook'},
#  {'position': 419896,
#   'reportDate': 1533772800000,
#   'entityName': 'Craig Federighi'},
#  {'position': 164620,
#   'reportDate': 1554076800000,
#   'entityName': 'Jeffrey E. Williams'},
#  {'position': 151102,
#   'reportDate': 1555286400000,
#   'entityName': "Deirdre O'Brien"},
#  {'position': 80696,
#   'reportDate': 1551398400000,
#   'entityName': 'Albert Arnold Gore'},
#  {'position': 73455,
#   'reportDate': 1546214400000,
#   'entityName': 'SEPIO CAPITAL LLC'},
#  {'position': 65370,
#   'reportDate': 1522540800000,
#   'entityName': 'Eduardo H. Cue'},
#  {'position': 61158,
#   'reportDate': 1534464000000,
#   'entityName': 'Johny Srouji'}]

# %%
c.insiderRosterDF(symbol)
# Out:
#                                 entityName  position reportDate
# 0  WELLCOME TRUST LTD /DIRECT INVESTMENTS/   3235000 2019-03-31
# 1                       Arthur D. Levinson   1147283 2019-03-01
# 2                      Timothy Donald Cook    878425 2019-01-02
# 3                          Craig Federighi    419896 2018-08-09
# 4                      Jeffrey E. Williams    164620 2019-04-01
# 5                          Deirdre O'Brien    151102 2019-04-15
# 6                       Albert Arnold Gore     80696 2019-03-01
# 7                        SEPIO CAPITAL LLC     73455 2018-12-31
# 8                           Eduardo H. Cue     65370 2018-04-01
# 9                             Johny Srouji     61158 2018-08-17

# %% [markdown]
# ## Insider Summary

# %%
c.insiderSummary(symbol)
# Out:
# [{'reportedTitle': 'Director',
#   'netTransacted': 1429,
#   'totalBought': 2950,
#   'totalSold': -1521,
#   'fullName': 'Susan Lynne Wagner'},
#  {'reportedTitle': 'Director',
#   'netTransacted': 1429,
#   'totalBought': 2950,
#   'totalSold': -1521,
#   'fullName': 'James A. Bell'},
#  {'reportedTitle': 'Principal Accounting Officer',
#   'netTransacted': -6466,
#   'totalBought': 6917,
#   'totalSold': -13383,
#   'fullName': 'Chris Kondo'},
#  {'reportedTitle': 'COO',
#   'netTransacted': -48989,
#   'totalBought': 105400,
#   'totalSold': -154389,
#   'fullName': 'Jeffrey E. Williams'},
#  {'reportedTitle': 'Director',
#   'netTransacted': 1429,
#   'totalBought': 2950,
#   'totalSold': -1521,
#   'fullName': 'Andrea Jung'},
#  {'reportedTitle': 'Director',
#   'netTransacted': -92,
#   'totalBought': 2950,
#   'totalSold': -3042,
#   'fullName': 'Arthur D. Levinson'},
#  {'reportedTitle': 'Director',
#   'netTransacted': 1429,
#   'totalBought': 2950,
#   'totalSold': -1521,
#   'fullName': 'Robert A. Iger'},
#  {'reportedTitle': 'Director',
#   'netTransacted': 1429,
#   'totalBought': 2950,
#   'totalSold': -1521,
#   'fullName': 'Ronald D. Sugar'},
#  {'reportedTitle': 'Director',
#   'netTransacted': 1429,
#   'totalBought': 37950,
#   'totalSold': -36521,
#   'fullName': 'Albert Arnold Gore'},
#  {'reportedTitle': 'SVP, GC and Secretary',
#   'netTransacted': -7019,
#   'totalBought': 14371,
#   'totalSold': -21390,
#   'fullName': 'Katherine L. Adams'},
#  {'reportedTitle': 'Senior Vice President, CFO',
#   'netTransacted': -105400,
#   'totalBought': 105400,
#   'totalSold': -210800,
#   'fullName': 'Luca Maestri'},
#  {'reportedTitle': 'Senior Vice President',
#   'netTransacted': 304602,
#   'totalBought': 339353,
#   'totalSold': -34751,
#   'fullName': "Deirdre O'Brien"}]

# %%
c.insiderSummaryDF(symbol)
# Out:
#                fullName  netTransacted                 reportedTitle  \
# 0    Susan Lynne Wagner           1429                      Director
# 1         James A. Bell           1429                      Director
# 2           Chris Kondo          -6466  Principal Accounting Officer
# 3   Jeffrey E. Williams         -48989                           COO
# 4           Andrea Jung           1429                      Director
# 5    Arthur D. Levinson            -92                      Director
# 6        Robert A. Iger           1429                      Director
# 7       Ronald D. Sugar           1429                      Director
# 8    Albert Arnold Gore           1429                      Director
# 9    Katherine L. Adams          -7019         SVP, GC and Secretary
# 10         Luca Maestri        -105400    Senior Vice President, CFO
# 11      Deirdre O'Brien         304602         Senior Vice President
#
#     totalBought  totalSold
# 0          2950      -1521
# 1          2950      -1521
# 2          6917     -13383
# 3        105400    -154389
# 4          2950      -1521
# 5          2950      -3042
# 6          2950      -1521
# 7          2950      -1521
# 8         37950     -36521
# 9         14371     -21390
# 10       105400    -210800
# 11       339353     -34751

# %% [markdown]
# ## Insider Transactions

# %%
c.insiderTransactions(symbol)[:5]
# Out:
# [{'fullName': "Deirdre O'Brien",
#   'reportedTitle': 'Senior Vice President',
#   'effectiveDate': 1555286400000,
#   'tranShares': -4154,
#   'tranPrice': None,
#   'tranValue': None},
#  {'fullName': "Deirdre O'Brien",
#   'reportedTitle': 'Senior Vice President',
#   'effectiveDate': 1555286400000,
#   'tranShares': -5574,
#   'tranPrice': None,
#   'tranValue': None},
#  {'fullName': "Deirdre O'Brien",
#   'reportedTitle': 'Senior Vice President',
#   'effectiveDate': 1555286400000,
#   'tranShares': -6908,
#   'tranPrice': None,
#   'tranValue': None},
#  {'fullName': "Deirdre O'Brien",
#   'reportedTitle': 'Senior Vice President',
#   'effectiveDate': 1555286400000,
#   'tranShares': -7334,
#   'tranPrice': None,
#   'tranValue': None},
#  {'fullName': "Deirdre O'Brien",
#   'reportedTitle': 'Senior Vice President',
#   'effectiveDate': 1555286400000,
#   'tranShares': -10781,
#   'tranPrice': 199.23,
#   'tranValue': -2147898.63}]

# %%
c.insiderTransactionsDF(symbol)
# Out:
#                fullName  netTransacted                 reportedTitle  \
# 0    Susan Lynne Wagner           1429                      Director
# 1         James A. Bell           1429                      Director
# 2           Chris Kondo          -6466  Principal Accounting Officer
# 3   Jeffrey E. Williams         -48989                           COO
# 4           Andrea Jung           1429                      Director
# 5    Arthur D. Levinson            -92                      Director
# 6        Robert A. Iger           1429                      Director
# 7       Ronald D. Sugar           1429                      Director
# 8    Albert Arnold Gore           1429                      Director
# 9    Katherine L. Adams          -7019         SVP, GC and Secretary
# 10         Luca Maestri        -105400    Senior Vice President, CFO
# 11      Deirdre O'Brien         304602         Senior Vice President
#
#     totalBought  totalSold
# 0          2950      -1521
# 1          2950      -1521
# 2          6917     -13383
# 3        105400    -154389
# 4          2950      -1521
# 5          2950      -3042
# 6          2950      -1521
# 7          2950      -1521
# 8         37950     -36521
# 9         14371     -21390
# 10       105400    -210800
# 11       339353     -34751

# %% [markdown]
# ## Institutional Ownership

# %%
c.institutionalOwnership(symbol)
# Out:
# [{'reportDate': 1553990400000,
#   'adjHolding': 16434619,
#   'reportedHolding': 16434619,
#   'adjMv': 3121755879,
#   'entityProperName': 'Janus Henderson Group Plc (Subfiler)'},
#  {'reportDate': 1553990400000,
#   'adjHolding': 13191995,
#   'reportedHolding': 13191995,
#   'adjMv': 2505819450,
#   'entityProperName': 'Fisher Asset Management LLC'},
#  {'reportDate': 1553990400000,
#   'adjHolding': 9713927,
#   'reportedHolding': 9713927,
#   'adjMv': 1845160434,
#   'entityProperName': 'The California Public Employees Retirement System'},
#  {'reportDate': 1553990400000,
#   'adjHolding': 8267773,
#   'reportedHolding': 8267773,
#   'adjMv': 1570463481,
#   'entityProperName': 'BMO Harris Bank, NA (Private Bank)'},
#  {'reportDate': 1553990400000,
#   'adjHolding': 8260851,
#   'reportedHolding': 8260851,
#   'adjMv': 1569148647,
#   'entityProperName': 'RhumbLine Advisers LP'},
#  {'reportDate': 1553990400000,
#   'adjHolding': 8134174,
#   'reportedHolding': 8134174,
#   'adjMv': 1545086351,
#   'entityProperName': 'Sanders Capital LLC'},
#  {'reportDate': 1553990400000,
#   'adjHolding': 6414428,
#   'reportedHolding': 6414428,
#   'adjMv': 1218420599,
#   'entityProperName': 'State Board of Administration of Florida Retirement (13F)'},
#  {'reportDate': 1553990400000,
#   'adjHolding': 5179469,
#   'reportedHolding': 5179469,
#   'adjMv': 983840137,
#   'entityProperName': 'Swedbank AB'},
#  {'reportDate': 1553990400000,
#   'adjHolding': 5145938,
#   'reportedHolding': 5145938,
#   'adjMv': 977470923,
#   'entityProperName': 'Raymond James & Associates, Inc.'},
#  {'reportDate': 1553990400000,
#   'adjHolding': 3994473,
#   'reportedHolding': 3994473,
#   'adjMv': 758750146,
#   'entityProperName': 'Los Angeles Capital Management & Equity Research, Inc.'}]

# %%
c.institutionalOwnershipDF(symbol)
# Out:
#    adjHolding       adjMv                                   entityProperName  \
# 0    16434619  3121755879               Janus Henderson Group Plc (Subfiler)
# 1    13191995  2505819450                        Fisher Asset Management LLC
# 2     9713927  1845160434  The California Public Employees Retirement System
# 3     8267773  1570463481                 BMO Harris Bank, NA (Private Bank)
# 4     8260851  1569148647                              RhumbLine Advisers LP
# 5     8134174  1545086351                                Sanders Capital LLC
# 6     6414428  1218420599  State Board of Administration of Florida Retir...
# 7     5179469   983840137                                        Swedbank AB
# 8     5145938   977470923                   Raymond James & Associates, Inc.
# 9     3994473   758750146  Los Angeles Capital Management & Equity Resear...
#
#   reportDate  reportedHolding
# 0 2019-03-31         16434619
# 1 2019-03-31         13191995
# 2 2019-03-31          9713927
# 3 2019-03-31          8267773
# 4 2019-03-31          8260851
# 5 2019-03-31          8134174
# 6 2019-03-31          6414428
# 7 2019-03-31          5179469
# 8 2019-03-31          5145938
# 9 2019-03-31          3994473

# %% [markdown]
# ## Intraday Prices

# %%
c.intraday(symbol)[:5]
# Out:
# [{'date': '2019-05-07',
#   'minute': '09:30',
#   'label': '09:30 AM',
#   'high': 206.47,
#   'low': 205.72,
#   'average': 205.928,
#   'volume': 5646,
#   'notional': 1162672.17,
#   'numberOfTrades': 56,
#   'marketHigh': 206.557,
#   'marketLow': 205.7,
#   'marketAverage': 205.925,
#   'marketVolume': 603640,
#   'marketNotional': 124304727.856,
#   'marketNumberOfTrades': 1566,
#   'open': 205.895,
#   'close': 206.47,
#   'marketOpen': 205.88,
#   'marketClose': 206.557,
#   'changeOverTime': 0,
#   'marketChangeOverTime': 0},
#  {'date': '2019-05-07',
#   'minute': '09:31',
#   'label': '09:31 AM',
#   'high': 207.37,
#   'low': 206.565,
#   'average': 206.934,
#   'volume': 2895,
#   'notional': 599074.79,
#   'numberOfTrades': 30,
#   'marketHigh': 207.417,
#   'marketLow': 206.54,
#   'marketAverage': 207.071,
#   'marketVolume': 317632,
#   'marketNotional': 65772420.8479,
#   'marketNumberOfTrades': 1236,
#   'open': 206.565,
#   'close': 207.27,
#   'marketOpen': 206.6,
#   'marketClose': 207.134,
#   'changeOverTime': 0.004885202595081777,
#   'marketChangeOverTime': 0.005565132936748751},
#  {'date': '2019-05-07',
#   'minute': '09:32',
#   'label': '09:32 AM',
#   'high': 207.04,
#   'low': 206.5,
#   'average': 206.697,
#   'volume': 2300,
#   'notional': 475403.5,
#   'numberOfTrades': 19,
#   'marketHigh': 207.22,
#   'marketLow': 206.49,
#   'marketAverage': 206.766,
#   'marketVolume': 225791,
#   'marketNotional': 46685865.2891,
#   'marketNumberOfTrades': 809,
#   'open': 207.04,
#   'close': 206.81,
#   'marketOpen': 207.14,
#   'marketClose': 206.85,
#   'changeOverTime': 0.0037343149061808277,
#   'marketChangeOverTime': 0.004084011169114871},
#  {'date': '2019-05-07',
#   'minute': '09:33',
#   'label': '09:33 AM',
#   'high': 206.96,
#   'low': 206.68,
#   'average': 206.813,
#   'volume': 2297,
#   'notional': 475049.95,
#   'numberOfTrades': 25,
#   'marketHigh': 206.97,
#   'marketLow': 206.68,
#   'marketAverage': 206.827,
#   'marketVolume': 137883,
#   'marketNotional': 28518003.9585,
#   'marketNumberOfTrades': 702,
#   'open': 206.79,
#   'close': 206.74,
#   'marketOpen': 206.76,
#   'marketClose': 206.804,
#   'changeOverTime': 0.004297618585136508,
#   'marketChangeOverTime': 0.004380235522641674},
#  {'date': '2019-05-07',
#   'minute': '09:34',
#   'label': '09:34 AM',
#   'high': 206.9,
#   'low': 206.55,
#   'average': 206.681,
#   'volume': 1300,
#   'notional': 268685.5,
#   'numberOfTrades': 13,
#   'marketHigh': 206.9,
#   'marketLow': 206.53,
#   'marketAverage': 206.686,
#   'marketVolume': 80998,
#   'marketNotional': 16741155.1995,
#   'marketNumberOfTrades': 490,
#   'open': 206.9,
#   'close': 206.66,
#   'marketOpen': 206.79,
#   'marketClose': 206.595,
#   'changeOverTime': 0.00365661784701456,
#   'marketChangeOverTime': 0.0036955202136700043}]

# %%
c.intradayDF(symbol).head()
# Out:
#         average  changeOverTime   close       date    high     label      low  \
# minute
# 09:30   205.928        0.000000  206.47 2019-05-07  206.47  09:30 AM  205.720
# 09:31   206.934        0.004885  207.27 2019-05-07  207.37  09:31 AM  206.565
# 09:32   206.697        0.003734  206.81 2019-05-07  207.04  09:32 AM  206.500
# 09:33   206.813        0.004298  206.74 2019-05-07  206.96  09:33 AM  206.680
# 09:34   206.681        0.003657  206.66 2019-05-07  206.90  09:34 AM  206.550
#
#         marketAverage  marketChangeOverTime  marketClose  marketHigh  \
# minute
# 09:30         205.925              0.000000      206.557     206.557
# 09:31         207.071              0.005565      207.134     207.417
# 09:32         206.766              0.004084      206.850     207.220
# 09:33         206.827              0.004380      206.804     206.970
# 09:34         206.686              0.003696      206.595     206.900
#
#         marketLow  marketNotional  marketNumberOfTrades  marketOpen  \
# minute
# 09:30      205.70    1.243047e+08                  1566      205.88
# 09:31      206.54    6.577242e+07                  1236      206.60
# 09:32      206.49    4.668587e+07                   809      207.14
# 09:33      206.68    2.851800e+07                   702      206.76
# 09:34      206.53    1.674116e+07                   490      206.79
#
#         marketVolume    notional  numberOfTrades     open  volume
# minute
# 09:30         603640  1162672.17              56  205.895    5646
# 09:31         317632   599074.79              30  206.565    2895
# 09:32         225791   475403.50              19  207.040    2300
# 09:33         137883   475049.95              25  206.790    2297
# 09:34          80998   268685.50              13  206.900    1300

# %% [markdown]
# ## IPO Calendar

# %%
c.ipoToday()
# Out:
# {'rawData': [{'symbol': 'LCAHU',
#    'companyName': 'LANDCADIA HOLDINGS II, INC.',
#    'expectedDate': '2019-05-07',
#    'leadUnderwriters': ['Jefferies LLC'],
#    'underwriters': [],
#    'companyCounsel': ['Winston & Strawn LLP'],
#    'underwriterCounsel': ['Shearman & Sterling LLP'],
#    'auditor': 'Continental Stock Transfer & Trust Company',
#    'market': 'NASDAQ Capital',
#    'cik': '0001768012',
#    'address': '1510 WEST LOOP SOUTH',
#    'city': 'HOUSTON',
#    'state': 'TX',
#    'zip': '77027',
#    'phone': '713-850-1010',
#    'ceo': 'Tilman J. Fertitta',
#    'employees': 5,
#    'url': '',
#    'status': 'Filed',
#    'sharesOffered': 25000000,
#    'priceLow': 10,
#    'priceHigh': None,
#    'offerAmount': None,
#    'totalExpenses': 1000000,
#    'sharesOverAlloted': 3750000,
#    'shareholderShares': None,
#    'sharesOutstanding': 31250000,
#    'lockupPeriodExpiration': '',
#    'quietPeriodExpiration': '',
#    'revenue': None,
#    'netIncome': 0,
#    'totalAssets': 0,
#    'totalLiabilities': 0,
#    'stockholderEquity': 0,
#    'companyDescription': 'We are a blank check company whose business purpose is to effect a merger, &#10; capital stock exchange, asset acquisition, stock purchase, reorganization or &#10; similar business combination with one or more businesses, which we refer to &#10; throughout this prospectus as our initial business combination. We have not &#10; selected any specific business combination target and we have not, nor has &#10; anyone on our behalf, initiated any substantive discussions, directly or &#10; indirectly, with any business combination target with respect to an initial &#10; business combination with us. While we may pursue an initial business &#10; combination target in any industry, we intend to focus our search on investment &#10; opportunities in the consumer, dining, hospitality, entertainment and gaming &#10; industries, including technology companies operating in these industries. &#10; --- &#10;  &#10; Our executive offices are located at 1510 West Loop South, Houston, Texas 77027, &#10; and our telephone number is (713) 850-1010.',
#    'businessDescription': 'We are a blank check company whose business purpose is to effect a merger, &#10; capital stock exchange, asset acquisition, stock purchase, reorganization or &#10; similar business combination with one or more businesses, which we refer to &#10; throughout this prospectus as our initial business combination. We have not &#10; selected any specific business combination target and we have not, nor has &#10; anyone on our behalf, initiated any substantive discussions, directly or &#10; indirectly, with any business combination target with respect to an initial &#10; business combination with us. While we may pursue an initial business &#10; combination target in any industry, we intend to focus our search on investment &#10; opportunities in the consumer, dining, hospitality, entertainment and gaming &#10; industries, including technology companies operating in these industries. &#10; --- &#10;  &#10; Our executive offices are located at 1510 West Loop South, Houston, Texas 77027, &#10; and our telephone number is (713) 850-1010.',
#    'useOfProceeds': 'We are offering 25,000,000 units at an offering price of $10.00 per unit. We &#10; estimate that the net proceeds of this offering together with the funds we will &#10; receive from the sale of the private placement warrants will be used as set &#10; forth in the following table. &#10;  &#10;                                                                                                                     Without           Over-Allotment  &#10;                                                                                                                 Over-Allotment         Option Fully     &#10;                                                                                                                      Option               Exercised       &#10; Gross proceeds                                                                                                                                            &#10; Gross proceeds from units offered to public(1)                                                                    $ 250,000,000         $ 287,500,000     &#10; Gross proceeds from private placement warrants offered in the private placement                                       7,500,000             8,250,000     &#10; Total gross proceeds                                                                                              $ 257,500,000         $ 295,750,000     &#10; Offering expenses(2)                                                                                                                                      &#10; Underwriting commissions (2% of gross proceeds from units offered to public, excluding deferred portion)(3)       $   5,000,000         $   5,750,000     &#10; Legal fees and expenses                                                                                                 300,000               300,000     &#10; Accounting fees and expenses                                                                                             50,000                50,000     &#10; SEC/FINRA Expenses                                                                                                       75,000                75,000     &#10; Travel and road show                                                                                                     25,000                25,000     &#10; Nasdaq listing and filing fees                                                                                           75,000                75,000     &#10; Director and Officer liability insurance premiums                                                                       150,000               150,000     &#10; Printing and engraving expenses                                                                                          50,000                50,000     &#10; Miscellaneous                                                                                                           275,000               275,000     &#10; Total offering expenses (excluding underwriting commissions)                                                      $   1,000,000         $   1,000,000     &#10; Proceeds after offering expenses                                                                                  $ 251,500,000         $ 289,000,000     &#10; Held in trust account(3)                                                                                          $ 250,000,000         $ 287,500,000     &#10; % of public offering size                                                                                                  100%                  100%     &#10; Not held in trust account                                                                                         $   1,500,000         $   1,500,000     &#10;  &#10; The following table shows the estimated use of the approximately $1,500,000 of &#10; net proceeds not held in the trust account.(4) &#10;                            ...
#    'competition': 'In identifying, evaluating and selecting a target business for our initial &#10; business combination, we may encounter competition from other entities having a &#10; business objective similar to ours, including other blank check companies, &#10; private equity groups and leveraged buyout funds, public companies and operating &#10; businesses seeking strategic business combinations. Many of these entities are &#10; well established and have extensive experience identifying and effecting &#10; business combinations directly or through affiliates. Moreover, many of these &#10; competitors possess greater financial, technical, human and other resources than &#10; we do. Our ability to acquire larger target businesses will be limited by our &#10; available financial resources. This inherent limitation gives others an &#10; advantage in pursuing the initial business combination of a target business. &#10; Furthermore, our obligation to pay cash in connection with our public &#10; stockholders who exercise their redemption rights may reduce the resources &#10; available to us for our initial business combination and our outstanding &#10; warrants, and the future dilution they potentially represent, may not be viewed &#10; favorably by certain target businesses. Either of these factors may place us at &#10; a competitive disadvantage in successfully negotiating an initial business &#10; combination.',
#    'amount': 125000000,
#    'percentOffered': '80.00'},
#   {'symbol': 'TRVI',
#    'companyName': 'TREVI THERAPEUTICS, INC.',
#    'expectedDate': '2019-05-07',
#    'leadUnderwriters': ['BMO Capital Markets Corp',
#     'Stifel Nicolaus & Company, Incorporated',
#     'SVB Leerink LLC'],
#    'underwriters': ['Needham & Company, LLC'],
#    'companyCounsel': ['Wilmer Cutler Pickering Hale and Dorr LLP'],
#    'underwriterCounsel': ['Covington & Burling LLP'],
#    'auditor': 'Computershare Trust Company, N.A',
#    'market': 'NASDAQ Global',
#    'cik': '0001563880',
#    'address': '195 CHURCH STREET',
#    'city': 'NEW HAVEN',
#    'state': 'CT',
#    'zip': '06510',
#    'phone': '203-304-2499',
#    'ceo': 'Jennifer Good',
#    'employees': 16,
#    'url': 'www.trevitherapeutics.com',
#    'status': 'Filed',
#    'sharesOffered': 5500000,
#    'priceLow': 10,
#    'priceHigh': None,
#    'offerAmount': None,
#    'totalExpenses': 2500000,
#    'sharesOverAlloted': 825000,
#    'shareholderShares': None,
#    'sharesOutstanding': 17771751,
#    'lockupPeriodExpiration': '',
#    'quietPeriodExpiration': '',
#    'revenue': 0,
#    'netIncome': -20545000,
#    'totalAssets': 10526000,
#    'totalLiabilities': 3182000,
#    'stockholderEquity': -109494000,
#    'companyDescription': 'We are a clinical-stage biopharmaceutical company focused on the development and &#10; commercialization of nalbuphine ER to treat serious neurologically mediated &#10; conditions. We are currently developing nalbuphine ER for the treatment of &#10; chronic pruritus, chronic cough in patients with idiopathic pulmonary fibrosis, &#10; or IPF, and levodopa-induced dyskinesia, or LID, in patients with Parkinson’s &#10; disease. These conditions share a common pathophysiology that is mediated &#10; through opioid receptors in the central and peripheral nervous systems. Due to &#10; nalbuphine’s mechanism of action as a modulator of opioid receptors, we believe &#10; it has the potential to be effective in treating each of these conditions. We &#10; are currently conducting a Phase 2b/3 clinical trial of nalbuphine ER, which we &#10; refer to as the PRISM trial, in patients with severe pruritus associated with &#10; prurigo nodularis, and expect to report top-line data from the trial in the &#10; first half of 2020. If successful, we expect that we will use the PRISM trial &#10; and an additional Phase 3 clinical trial that we plan to conduct to support the &#10; submission of a new drug application, or NDA, to the United States Food and Drug &#10; Administration, or FDA, and a marketing authorization application, or MAA, to &#10; the European Medicines Agency, or EMA, for nalbuphine ER for the treatment of &#10; pruritus associated with prurigo nodularis. &#10; --- &#10;  &#10; We were incorporated under the laws of the State of Delaware on March 17, 2011 &#10; under the name Trevi Therapeutics, Inc. Our principal executive offices are &#10; located at 195 Church Street, 14th Floor, New Haven, Connecticut 06510, and our &#10; telephone number is (203) 304-2499. Our website address is &#10; www.trevitherapeutics.com.',
#    'businessDescription': 'We are a clinical-stage biopharmaceutical company focused on the development and &#10; commercialization of nalbuphine ER to treat serious neurologically mediated &#10; conditions. We are currently developing nalbuphine ER for the treatment of &#10; chronic pruritus, chronic cough in patients with idiopathic pulmonary fibrosis, &#10; or IPF, and levodopa-induced dyskinesia, or LID, in patients with Parkinson’s &#10; disease. These conditions share a common pathophysiology that is mediated &#10; through opioid receptors in the central and peripheral nervous systems. Due to &#10; nalbuphine’s mechanism of action as a modulator of opioid receptors, we believe &#10; it has the potential to be effective in treating each of these conditions. We &#10; are currently conducting a Phase 2b/3 clinical trial of nalbuphine ER, which we &#10; refer to as the PRISM trial, in patients with severe pruritus associated with &#10; prurigo nodularis, and expect to report top-line data from the trial in the &#10; first half of 2020. If successful, we expect that we will use the PRISM trial &#10; and an additional Phase 3 clinical trial that we plan to conduct to support the &#10; submission of a new drug application, or NDA, to the United States Food and Drug &#10; Administration, or FDA, and a marketing authorization application, or MAA, to &#10; the European Medicines Agency, or EMA, for nalbuphine ER for the treatment of &#10; pruritus associated with prurigo nodularis. &#10;  &#10; Nalbuphine ER is an oral extended release formulation of nalbuphine. Nalbuphine &#10; is a mixed k-opioid receptor agonist and m-opioid receptor antagonist that has &#10; been approved and marketed as an injectable for pain indications for more than &#10; 20 years in the United States and Europe. The k- and m-opioid receptors are &#10; known to be critical mediators of itch, cough and certain movement disorders. &#10; Nalbuphine’s mechanism of action also mitigates the risk of abuse associated &#10; with m-opioid agonists because it antagonizes, or blocks, the m-opioid receptor. &#10; Nalbuphine is currently the only opioid approved for marketing that is not &#10; classified as a controlled substance in the United States or Europe. &#10;  &#10; We have retained worldwide development and commercial rights for nalbuphine ER  &#10; in all indications. &#10; --- &#10;  &#10; Chronic pruritus, defined as itching lasting longer than six weeks, causes a &#10; number of physical and psychological issues that can substantially impact &#10; patients’ daily well-being. The urge to scratch can be unbearable and the act of &#10; scratching can remove layers of skin and break the skin barrier, leading to &#10; bleeding and scarring and greatly increasing the risk of infection. Chronic &#10; pruritus can also lead to trouble sleeping, resulting in loss of work &#10; productivity and increased anxiety and depression as patients struggle to &#10; maintain self-control. Chronic pruritus is a hallmark of many dermatologic and &#10; systemic diseases and is the predominant reason that patients with these &#10; diseases experience so much discomfort. A recent report published in the Journal &#10; of the American Academy of Dermatology estimated that up to 26% of the worldwide &#10; population will suffer from chronic pruritus at some point in their lives. &#10; According to the Global Pruritus Therapeutic Market Research Report issued in &#10; 2017, the market for pruritus therapeutics was $10.8 billion in 2016 and is &#10; expected to grow to $14.3 billion in 2022. Despite the large market opportunity &#10; and the severity of chronic pruritus, there are no drugs approved in the United &#10; States or Europe for the treatment of moderate to severe pruritus. Nalbuphine &#10; ER’s dual mechanism of action targets opioid receptors located in both the &#10; central and peripheral nervous systems, each of which plays a role in modulating &#10; the sensation of itch ...
#    'useOfProceeds': 'We estimate that the net proceeds from our issuance and sale of 5,500,000 shares &#10; of our common stock in this offering will be approximately $48.7 million, or &#10; $56.3 million if the underwriters exercise their option to purchase 825,000 &#10; additional shares in full, assuming an initial public offering price of $10.00 &#10; per share, after deducting underwriting discounts and commissions and estimated &#10; offering expenses payable by us. We also expect to receive net proceeds of $14.0 &#10; million from the sale of shares of our common stock to New Enterprise &#10; Associates, or NEA, in the proposed concurrent private placement, based on the &#10; assumed initial public offering price of $10.00 per share and after deducting &#10; estimated placement agent fees payable by us, for aggregate net proceeds to be &#10; raised by us in this offering and the concurrent private placement of $62.6 &#10; million. Because we have not entered into any definitive agreements with NEA &#10; related to the proposed concurrent private placement, there can be no guarantee &#10; that the proposed concurrent private placement will take place or that the terms &#10; of the proposed concurrent private placement will be consistent with those &#10; assumed in this prospectus. &#10;  &#10; A $1.00 decrease in the assumed initial public offering price of $10.00 per &#10; share would decrease the net proceeds to us from this offering by approximately &#10; $5.1 million, assuming that the number of shares offered by us in this offering, &#10; as set forth on the cover page of this prospectus, remains the same and after &#10; deducting underwriting discounts and commissions and estimated offering expenses &#10; payable by us, and both assuming completion of the proposed concurrent private &#10; placement, the proceeds of which would be unaffected by such decrease, and &#10; deduction of estimated placement agent fees. An increase (decrease) of 1,000,000 &#10; shares in the number of shares offered by us in this offering, as set forth on &#10; the cover page of this prospectus, would increase (decrease) the net proceeds to &#10; us from this offering and the proposed concurrent private placement by &#10; approximately $9.3 million, assuming no change in the assumed initial public &#10; offering price per share and after deducting underwriting discounts and &#10; commissions and estimated offering expenses payable by us, and both assuming &#10; completion of the proposed concurrent private placement and deduction of &#10; estimated placement agent fees. &#10;  &#10; As of December 31, 2018, we had cash and cash equivalents of $7.2 million. We &#10; currently estimate that we will use the net proceeds from this offering, &#10; together with our existing cash and cash equivalents, as follows: &#10;  &#10; • approximately $7.5 million to $13.5 million to fund the development of     &#10;   nalbuphine ER for the treatment of pruritus associated with prurigo nodularis; &#10;  &#10; • approximately $5.0 million to $7.5 million to fund the development of      &#10;   nalbuphine ER for the treatment of pruritus associated with chronic liver  &#10;   disease; &#10;  &#10; • approximately $4.0 million to $8.0 million to fund the development of      &#10;   nalbuphine ER for the treatment of chronic cough in patients with IPF;  &#10;  &#10; • approximately $5.5 million to $7.5 million to fund the development of      &#10;   nalbuphine ER for the treatment of LID in patients with Parkinson’s disease; &#10;   and &#10;  &#10; • the remainder for working capital and other general corporate purposes. &#10;  &#10; We currently estimate that, if we receive additional net proceeds of $14.0 &#10; million from the sale of shares of our common stock to NEA in the proposed &#10; concurrent private placement, we will use such net proceeds as follows: &#10;  &#10; • approximately $2.5 to $4.0 million to fund the development of nalbuphine ER &#10; ...
#    'competition': 'The biopharmaceutical industry is intensely competitive and is subject to rapid &#10; and significant change. While we believe that our technology, knowledge, &#10; experience and scientific resources provide us with competitive advantages, we &#10; face potential competition from many sources, including major pharmaceutical, &#10; specialty pharmaceutical and biotechnology companies. If we are able to &#10; successfully develop and commercialize nalbuphine ER, it would compete with &#10; existing therapies and new therapies that may become available in the future. &#10;  &#10; Chronic Pruritus &#10;  &#10; We are developing nalbuphine ER for the treatment of pruritus associated with &#10; prurigo nodularis. Currently, there are no products approved in the United &#10; States or Europe for the treatment of pruritus associated with prurigo &#10; nodularis, however there are many products that are used to help manage pruritus &#10; associated with prurigo nodularis with which we expect that nalbuphine ER would &#10; compete if it is approved in this indication. The most common of these agents &#10; are anti-itch creams and emollients as well as oral or injectable &#10; antihistamines. All of these products have limited degrees of efficacy and are &#10; available generically. Additionally, patients may try several other agents such &#10; as gabapentin and Lyrica (pregabalin), which are prescription medicines approved &#10; for the treatment of seizures and neuropathic pain, naltrexone and UVB light &#10; therapy, generally with limited success. If approved for the treatment of &#10; pruritus associated with prurigo nodularis, we expect that nalbuphine ER might &#10; also compete with product candidates currently in clinical development in this &#10; indication, including serlopitant, an oral neurokinin-1 receptor antagonist &#10; being developed by Menlo Therapeutics that is in Phase 3 clinical trials; &#10; nemolizumab, an anti-interleukin-31 receptor A humanized monoclonal antibody &#10; being developed by Galderma; and KPL-716, a monoclonal antibody targeting &#10; oncostatin M receptor beta being developed by Kiniksa Pharmaceuticals. In &#10; addition, a number of other product candidates are currently in clinical &#10; development to treat other pruritic conditions and nalbuphine ER, if approved &#10; for the treatment of pruritus associated with prurigo nodularis or another &#10; pruritic condition, could face competition from these product candidates. These &#10; product candidates include KORSUVA, a k-opioid receptor agonist being developed &#10; by Cara Therapeutics that is in Phase 3 clinical trials for administration by &#10; injection for uremic pruritus and earlier-stage clinical trials for oral &#10; administration for uremic pruritus and pruritus associated with chronic liver &#10; disease, and tradipitant, an oral neurokinin-1 receptor antagonist being &#10; developed by Vanda Pharmaceuticals that is in Phase 3 clinical trials for &#10; chronic pruritus in patients with atopic dermatitis. &#10;  &#10; If approved for the treatment of pruritus associated with chronic liver disease, &#10; nalbuphine ER may also compete with bile acid sequestrants, such as &#10; cholestyramine, which are used off label and generally as first-line therapy, &#10; although they typically provide only modest relief. Cholestyramine is marketed &#10; as Questran in the United States and as Colestyr, Efensol, Ipocol, Kolestran, &#10; Lipocol, Olestyr, Prevalite or Quantalan in various other countries. Nalbuphine &#10; ER may also complete with second-line therapies such as the antibiotic &#10; rifampicin, naltrexone, the anti-depressant sertraline, as well as phototherapy &#10; and drugs such as gabapentin and Lyrica (pregabalin), which are approved for the &#10; treatment of seizures and neuropathic pain. In addition, it is possible that &#10; therapies to reduce chronic liver disease, such as ursodeoxycholic acid, which ...
#    'amount': 27500000,
#    'percentOffered': '30.95'}],
#  'viewData': [{'Company': 'LANDCADIA HOLDINGS II, INC.',
#    'Symbol': 'LCAHU',
#    'Price': '$10.00',
#    'Shares': '25,000,000',
#    'Amount': '125,000,000',
#    'Float': '31,250,000',
#    'Percent': '80.00%',
#    'Market': 'NASDAQ Capital',
#    'Expected': '2019-05-07',
#    'quote': {'latestPrice': 10.01, 'changePercent': 0.0009999999999999788}},
#   {'Company': 'TREVI THERAPEUTICS, INC.',
#    'Symbol': 'TRVI',
#    'Price': '$10.00',
#    'Shares': '5,500,000',
#    'Amount': '27,500,000',
#    'Float': '17,771,751',
#    'Percent': '30.95%',
#    'Market': 'NASDAQ Global',
#    'Expected': '2019-05-07',
#    'quote': {'latestPrice': 7.89, 'changePercent': -0.21100000000000002}}],
#  'lastUpdate': '2019-05-07'}

# %%
c.ipoTodayDF()
# Out:
#                      address     amount  \
# symbol
# LCAHU   1510 WEST LOOP SOUTH  125000000
# TRVI       195 CHURCH STREET   27500000
#
#                                            auditor  \
# symbol
# LCAHU   Continental Stock Transfer & Trust Company
# TRVI              Computershare Trust Company, N.A
#
#                                       businessDescription                 ceo  \
# symbol
# LCAHU   We are a blank check company whose business pu...  Tilman J. Fertitta
# TRVI    We are a clinical-stage biopharmaceutical comp...       Jennifer Good
#
#                cik       city                               companyCounsel  \
# symbol
# LCAHU   0001768012    HOUSTON                       [Winston & Strawn LLP]
# TRVI    0001563880  NEW HAVEN  [Wilmer Cutler Pickering Hale and Dorr LLP]
#
#                                        companyDescription  \
# symbol
# LCAHU   We are a blank check company whose business pu...
# TRVI    We are a clinical-stage biopharmaceutical comp...
#
#                         companyName  ... status  stockholderEquity  \
# symbol                               ...
# LCAHU   LANDCADIA HOLDINGS II, INC.  ...  Filed                  0
# TRVI       TREVI THERAPEUTICS, INC.  ...  Filed         -109494000
#
#        totalAssets totalExpenses totalLiabilities         underwriterCounsel  \
# symbol
# LCAHU            0       1000000                0  [Shearman & Sterling LLP]
# TRVI      10526000       2500000          3182000  [Covington & Burling LLP]
#
#                     underwriters                        url  \
# symbol
# LCAHU                         []
# TRVI    [Needham & Company, LLC]  www.trevitherapeutics.com
#
#                                             useOfProceeds    zip
# symbol
# LCAHU   We are offering 25,000,000 units at an offerin...  77027
# TRVI    We estimate that the net proceeds from our iss...  06510
#
# [2 rows x 39 columns]

# %%
c.ipoUpcoming()
# Out:
# {'rawData': [{'symbol': 'PSN',
#    'companyName': 'PARSONS CORP',
#    'expectedDate': '2019-05-08',
#    'leadUnderwriters': ['BofA Merrill Lynch', 'Goldman Sachs & Co. LLC'],
#    'underwriters': ['Cowen and Company, LLC',
#     'Jefferies LLC',
#     'Morgan Stanley & Co. LLC',
#     'MUFG Securities Americas Inc.',
#     'Scotia Capital Markets',
#     'SunTrust Robinson Humphrey, Inc',
#     'Wells Fargo Securities, LLC'],
#    'companyCounsel': ['Latham & Watkins LLP'],
#    'underwriterCounsel': ['Gibson Dunn and Crutcher LLP'],
#    'auditor': 'American Stock Transfer & Trust Company, LLC',
#    'market': 'NYSE',
#    'cik': '0000275880',
#    'address': '5875 TRINITY PKWY #300',
#    'city': 'CENTREVILLE',
#    'state': 'VA',
#    'zip': '20120',
#    'phone': '703-988-8500',
#    'ceo': 'Charles L. Harrington',
#    'employees': 15633,
#    'url': 'www.parsons.com',
#    'status': 'Filed',
#    'sharesOffered': 18518500,
#    'priceLow': 26,
#    'priceHigh': 28,
#    'offerAmount': None,
#    'totalExpenses': 9551215,
#    'sharesOverAlloted': 2777775,
#    'shareholderShares': None,
#    'sharesOutstanding': 96657331,
#    'lockupPeriodExpiration': '',
#    'quietPeriodExpiration': '',
#    'revenue': 3560508000,
#    'netIncome': 222337000,
#    'totalAssets': 2612578000,
#    'totalLiabilities': 1657345000,
#    'stockholderEquity': -967537000,
#    'companyDescription': 'We are a leading provider of technology-driven solutions in the defense, &#10; intelligence and critical infrastructure markets. We provide technical design &#10; and engineering services and software to address our customers’ challenges. We &#10; have developed significant expertise and differentiated capabilities in key &#10; areas of cybersecurity, intelligence, defense, military training, connected &#10; communities, physical infrastructure and mobility solutions. By combining our &#10; talented team of professionals and advanced technology, we help solve complex &#10; technical challenges to enable a safer, smarter and more interconnected world. &#10; --- &#10;  &#10; We are a Delaware corporation and commenced our principal operations in 1944. &#10; Our principal executive offices are located at 5875 Trinity Parkway #300, &#10; Centreville, Virginia 20120, and our telephone number is (703) 988-8500. Our &#10; website address is www.parsons.com.',
#    'businessDescription': 'We are a leading provider of technology-driven solutions in the defense, &#10; intelligence and critical infrastructure markets. We provide technical design &#10; and engineering services and software to address our customers’ challenges. We &#10; have developed significant expertise and differentiated capabilities in key &#10; areas of cybersecurity, intelligence, defense, military training, connected &#10; communities, physical infrastructure and mobility solutions. By combining our &#10; talented team of professionals and advanced technology, we help solve complex &#10; technical challenges to enable a safer, smarter and more interconnected world. &#10;  &#10; Since our founding 75 years ago, we have built our reputation and business on &#10; our ability to successfully transform and innovate our services while leveraging &#10; cutting-edge technologies in order to expand our offerings. Whether our &#10; customers need a first-of-its-kind advanced missile development and testing &#10; facility, or an artificial intelligence enabled cloud platform to defend against &#10; cybersecurity threats, we deliver for our customers. We seek to grow by offering &#10; our clients innovative solutions supported by research and development, as well &#10; as acquisitions of emerging technologies. We have developed longstanding &#10; relationships with customers such as the U.S. military and intelligence agencies &#10; and state and local governments and agencies. &#10;  &#10; Advances in technology are dramatically shifting the operating landscape across &#10; our markets. Governments and companies are grappling with pressing challenges &#10; ranging from confronting increasingly sophisticated cybersecurity threats to &#10; upgrading aging systems and infrastructure. To address these challenges, our &#10; customers are actively seeking technology-enabled solutions to enhance and &#10; transform their operations and assets. Our wide-ranging capabilities enable us &#10; to provide our services and solutions across the defense, intelligence and &#10; critical infrastructure markets. As a leading technology-driven solutions &#10; provider with a proven track record, we believe we are well positioned to &#10; benefit from these trends and serve our customers’ evolving needs. We have &#10; capabilities in the following four areas that cut across our segments and &#10; business lines: &#10;  &#10; Systems Integration: We provide engineering services and technology for large &#10; digital and physical systems with high technical complexity. We lead projects &#10; from concept development through design, implementation, testing and &#10; verification, ensuring interoperability of these complex, disparate systems. &#10;  &#10; Software Development: We develop software and systems across many domains and &#10; mission-specific applications. Our experienced software engineers and developers &#10; design, develop, integrate, operate and sustain mission-critical software &#10; applications and systems across cyber, intelligence, defense and commercial &#10; customers. &#10;  &#10; Program Management: We provide expertise and technology to advance our  &#10; customers’ execution of large, complex projects within their defined time and &#10; cost parameters. &#10;  &#10; Critical Mission Support: We provide a diverse set of technical services to &#10; help our nation’s military on land, sea, air and space. These services include &#10; mission training, protecting national airspace, fighting infectious diseases, &#10; digitizing the health environment, performing contingency operations and &#10; providing operations and maintenance for physical infrastructure. &#10;  &#10; Our customer relationships, which are based on a long history of successfully &#10; delivering complex technical services, are key to our success. We are often &#10; involved in the early stages of our customers’ planning processes, which allows &#10; us to eff ...
#    'useOfProceeds': 'We estimate that the net proceeds to us from the sale of shares of our common &#10; stock in this offering will be approximately $462.9 million, based upon the &#10; assumed initial public offering price of $27.00 per share, which is the midpoint &#10; of the estimated offering price range set forth on the cover page of this &#10; prospectus, and after deducting underwriting discounts and commissions and &#10; estimated offering expenses payable by us. If the underwriters exercise their &#10; option to purchase additional shares in full, we estimate that the net proceeds &#10; to be received by us will be approximately $533.8 million, after deducting &#10; underwriting discounts, commissions and estimated offering expenses payable by &#10; us. &#10;  &#10; A $1.00 increase (decrease) in the assumed initial public offering price of &#10; $27.00 per share would increase (decrease) the net proceeds that we receive from &#10; this offering by approximately $17.5 million, assuming that the number of shares &#10; offered by us, as set forth on the cover page of this prospectus, remains the &#10; same and after deducting the underwriting discounts and commissions and &#10; estimated offering expenses payable by us. Similarly, each increase (decrease) &#10; of 1.0 million in the number of shares offered by us would increase (decrease) &#10; the net proceeds that we receive from this offering by approximately $25.5 &#10; million, assuming that the assumed initial public offering price remains the &#10; same and after deducting the underwriting discounts and commissions and &#10; estimated offering expenses payable by us. &#10;  &#10; The principal purposes of this offering are to increase our capitalization and &#10; financial flexibility, create a public market for our common stock and thereby &#10; enable access to the public equity markets for us and our stockholders. We &#10; intend to use the net proceeds to us from this offering to fund the IPO Dividend &#10; of $52.1 million, repay the outstanding balance of $150.5 million under our Term &#10; Loan and repay outstanding indebtedness under our Revolving Credit Facility. &#10;  &#10; In January 2019, we borrowed $150.0 million under our Term Loan Agreement to &#10; partially finance the OGSystems Acquisition. Our Term Loan is comprised of &#10; Offshore Rate Loans and Base Rate Loans (each as defined in the Term Loan &#10; Agreement), with an initial aggregate principal amount of $150.0 million. The &#10; Offshore Rate Loans bear interest at a rate per annum of LIBOR, divided by 1.00 &#10; minus the Eurodollar Reserve Percentage, plus 1.25%. The Base Rate Loans bear &#10; interest at a rate per annum of the sum of (a) the highest of (1) the &#10; administrative agent’s reference rate; (2) the rate equal to 1.50% per annum &#10; above the Offshore Rate; and (3) the rate equal to 0.50% per annum above the &#10; latest federal funds rate, plus (b) 0.25%. The Term Loan has a maturity date of &#10; January 3, 2020. We intend to use $150.5 million of our net proceeds from this &#10; offering to repay the outstanding balance under our Term Loan upon the &#10; consummation of this offering. &#10;  &#10; As of December 31, 2018, the outstanding indebtedness under our Revolving Credit &#10; Facility was $180.0 million, which does not include $110.0 million we borrowed &#10; under our Revolving Credit Facility in January 2019 to partially finance the &#10; OGSystems Acquisition. In May 2018, we borrowed $260.0 million under our &#10; Revolving Credit Facility to partially finance the acquisition of Polaris Alpha. &#10; Under the terms of our Credit Agreement, borrowings under our Revolving Credit &#10; Facility bear interest, at our option, at either the Base Rate (as defined in &#10; the Credit Agreement), plus an applicable margin, or LIBOR plus an applicable &#10; margin. The applicable margin for Base Rate loans is a range of 0.125% to 1.00% &#10; and the applicable  ...
#    'competition': 'The industries we operate in consist of a large number of enterprises ranging &#10; from small, niche-oriented companies to multi-billion dollar corporations that &#10; serve many government and commercial customers. We compete on the basis of our &#10; technical expertise, technological innovation, our ability to deliver &#10; cost-effective multi-faceted services in a timely manner, our reputation and &#10; relationships with our customers, qualified and/or security-clearance personnel, &#10; and pricing. Our main competitors in Federal Solutions are U.S. federal systems &#10; integrators and service providers such as CACI International Inc, Leidos &#10; Holdings, Inc., Science Applications International Corporation, Booz Allen &#10; Hamilton, CSRA Inc., The Raytheon Company, Northrop Grumman Corporation, &#10; Perspecta Inc. and ManTech International Corporation. Our main competitors in &#10; Critical Infrastructure include Jacobs Engineering Group Inc. and Tetra Tech, &#10; Inc., as well as Siemens AG and Cisco Systems, Inc. in the connected communities &#10; market. Large defense firms or technology companies may develop products or &#10; services in the future that could compete with us.',
#    'amount': 499999500,
#    'percentOffered': '19.16'},
#   {'symbol': 'HHR',
#    'companyName': 'HEADHUNTER GROUP PLC',
#    'expectedDate': '2019-05-09',
#    'leadUnderwriters': ['Credit Suisse Securities (USA) LLC',
#     'Goldman Sachs & Co. LLC',
#     'Morgan Stanley & Co. LLC',
#     'VTB Capital plc'],
#    'underwriters': ['BofA Merrill Lynch', 'Sberbank CIB (UK) Limited'],
#    'companyCounsel': ['Latham & Watkins (London) LLP'],
#    'underwriterCounsel': ['White and Case LLP'],
#    'auditor': 'Not Specified',
#    'market': 'NASDAQ Global Select',
#    'cik': '0001721181',
#    'address': 'DOSITHEOU, 42, STROVOLOS',
#    'city': 'NICOSIA 2028',
#    'state': '',
#    'zip': '',
#    'phone': '357-22-418200',
#    'ceo': 'Mikhail Zhukov',
#    'employees': 683,
#    'url': 'www.hh.ru',
#    'status': 'Filed',
#    'sharesOffered': 16304348,
#    'priceLow': 11,
#    'priceHigh': 13.5,
#    'offerAmount': None,
#    'totalExpenses': 4369364,
#    'sharesOverAlloted': 2445652,
#    'shareholderShares': 16304348,
#    'sharesOutstanding': 50000000,
#    'lockupPeriodExpiration': '',
#    'quietPeriodExpiration': '',
#    'revenue': 88063000,
#    'netIncome': 14867000,
#    'totalAssets': 192013000,
#    'totalLiabilities': 148780000,
#    'stockholderEquity': 42809000,
#    'companyDescription': 'We are the leading online recruitment platform in Russia and the Commonwealth of &#10; Independent States (“CIS”) and focus on connecting job seekers with employers. &#10; We offer potential employers and recruiters paid access to our extensive &#10; curriculum vitae (“CV”) database and job postings platform. We also provide job &#10; seekers and employers with a value added services (“VAS”) portfolio centered &#10; around their recruitment needs. Our brand and the strength of our platform allow &#10; us to generate significant traffic, over 86% of which was free for us as of &#10; November, 2018 according to our internal data, and we were the third most &#10; visited job and employment website globally as of January 1, 2019, according to &#10; the latest available data from SimilarWeb. Our CV database contained 22.1 &#10; million, 26.4 million and 36.2 million total CVs (excluding Ukraine) as of &#10; December 31, 2016, 2017 and 2018, respectively, the growth partially due to our &#10; acquisition of Job.ru in January 2018, and our platform hosted a daily average &#10; of more than 344,000, 398,000 and 559,000 job postings (excluding Ukraine) in &#10; the years ended December 31, 2016, 2017 and 2018, respectively. For the years &#10; ended December 31, 2016, 2017 and 2018, our platform averaged 16.7 million, &#10; 17.5 million and 20.0 million unique visitors per month, respectively, according &#10; to LiveInternet. &#10; --- &#10;  &#10; We were incorporated in Cyprus on May 28, 2014 under the Cyprus Companies Law, &#10; Cap. 113 as Zemenik Trading Limited, and our registered office is located at 42 &#10; Dositheou Street, Strovolos, Nicosia, Cyprus. On March 1, 2018, Zemenik Trading &#10; Limited was converted from a private limited company incorporated in Cyprus into &#10; a public limited company incorporated in Cyprus, and the Company’s name changed, &#10; pursuant to a special resolution at a general meeting of the shareholders, to &#10; HeadHunter Group PLC. The legal effect of this conversion under Cypriot law was &#10; limited to the change of legal form. Following the completion of this offering, &#10; we are considering changing the place of management of HeadHunter Group PLC from &#10; Cyprus to Russia, which will result in HeadHunter Group PLC becoming a Russian &#10; tax resident. &#10;  &#10; The principal executive office of our key operating subsidiary, Headhunter LLC, &#10; is located at 9/10 Godovikova Street, Moscow, 129085 Russia. The telephone &#10; number at this address is +7 495 974-6427. Our website address is www.hh.ru.',
#    'businessDescription': 'We are the leading online recruitment platform in Russia and the Commonwealth of &#10; Independent States (“CIS”) and focus on connecting job seekers with employers. &#10; We offer potential employers and recruiters paid access to our extensive &#10; curriculum vitae (“CV”) database and job postings platform. We also provide job &#10; seekers and employers with a value added services (“VAS”) portfolio centered &#10; around their recruitment needs. Our brand and the strength of our platform allow &#10; us to generate significant traffic, over 86% of which was free for us as of &#10; November, 2018 according to our internal data, and we were the third most &#10; visited job and employment website globally as of January 1, 2019, according to &#10; the latest available data from SimilarWeb. Our CV database contained 22.1 &#10; million, 26.4 million and 36.2 million total CVs (excluding Ukraine) as of &#10; December 31, 2016, 2017 and 2018, respectively, the growth partially due to our &#10; acquisition of Job.ru in January 2018, and our platform hosted a daily average &#10; of more than 344,000, 398,000 and 559,000 job postings (excluding Ukraine) in &#10; the years ended December 31, 2016, 2017 and 2018, respectively. For the years &#10; ended December 31, 2016, 2017 and 2018, our platform averaged 16.7 million, &#10; 17.5 million and 20.0 million unique visitors per month, respectively, according &#10; to LiveInternet. &#10;  &#10; Our user base consists primarily of job seekers who use our products and &#10; services to discover new career opportunities. The majority of the services we &#10; provide to job seekers are free. Our customer base consists primarily of &#10; businesses using our CV database and job posting service to fill vacancies &#10; inside their organizations. &#10;  &#10; The quality and quantity of CVs in our database attract an increasing number of &#10; customers, which leads to more job seekers turning to us as their primary &#10; recruitment and related services provider, creating a powerful network effect &#10; that has allowed us to continuously solidify our market leadership and increase &#10; the gap between us and our competitors. &#10;  &#10; Our portfolio of recruitment-centric VAS is designed to improve the customer &#10; experience, increase the effectiveness of the recruitment process for our &#10; customer base and enable us to penetrate each link of the recruitment value &#10; chain beginning with sourcing, to engaging, pre-selecting, interviewing and then &#10; onboarding the selected candidates. We are working to further integrate our VAS &#10; features into our core products in order to enhance efficiency throughout the &#10; overall recruitment process, which we believe will increase the value &#10; proposition of our services and improve retention rates and average revenue per &#10; customer. &#10;  &#10; We were founded in 2000 and have successfully established a strong, trusted &#10; brand and the leading market position, which have enabled us to achieve &#10; significant growth in recent years. We had approximately 253,000 paying &#10; customers on our platform for the year ended December 31, 2018. We have a highly &#10; diversified customer base, representing the majority of the industries active in &#10; the Russian economy. Our brand awareness is one of the highest among the Russian &#10; online recruitment players, according to Socis MR Rus, which, coupled with a &#10; nationwide sales force and broad customer reach, creates barriers for new &#10; entrants to our markets. &#10;  &#10; We engage with job seekers and employers via our desktop sites, mobile sites and &#10; mobile applications. Since launch, our mobile applications had been downloaded &#10; 15.3 million times cumulatively as of December 31, 2018, and our mobile  &#10; platforms currently account for the majority of our traffic. Our scalable  &#10; technology platform utilizes an increasingly c ...
#    'useOfProceeds': 'The Selling Shareholders are selling all of the ADSs being sold in this &#10; offering. Accordingly, we will not receive any proceeds from the sale of ADSs in &#10; this offering. We will bear all costs, fees and expenses in connection with this &#10; offering, which are estimated to be approximately $4.4 million. &#10;  &#10; In connection with the Acquisition, Highworld Investments Limited entered into a &#10; profit sharing arrangement with an affiliate of Ivan Tavrin, and ELQ Investors &#10; VIII Limited in turn entered into a pro rata arrangement with Highworld &#10; Investments Limited, pursuant to which Mr. Tavrin’s affiliate will receive &#10; approximately 9% of any profit that Highworld Investments Limited and ELQ &#10; Investors VIII Limited realize with regard to their investment in the Company, &#10; including any profit realized upon the sale of its ADSs in this offering. &#10; Pursuant to this arrangement, Mr. Tavrin’s affiliate will receive approximately &#10; $16.0 million from the sale of ADSs by the Selling Shareholders in this &#10; offering, assuming an initial public offering price per share of $12.25, which &#10; is the midpoint of the price range set forth on the cover page of this &#10; prospectus (or approximately $18.7 million if the underwriters exercise their &#10; option to purchase additional ADSs in full). Neither Mr. Tavrin nor his &#10; affiliate provided services in connection with the Acquisition or to the &#10; Company. Neither Mr. Tavrin nor his affiliate is a shareholder of the Company &#10; and neither has rights in the Company or its shares or with regard to its &#10; management. Instead, the profit sharing arrangement with Mr. Tavrin settles the &#10; Selling Shareholders’ obligation to Mr. Tavrin arising from his relinquishing a &#10; previously existing position as the preferred purchaser in the Acquisition. Mr. &#10; Tavrin is a well-known Russian telecom, media and technology entrepreneur who &#10; was a founder, shareholder and head of a number of Russian companies. He was CEO &#10; of Megafon from 2012 to 2016. Mr. Tavrin previously held a position on the board &#10; of directors of Mail.Ru (but did not hold such position at the time of the &#10; Acquisition) and affiliates of Highworld Investments Limited have historically &#10; had and continue to have joint investment projects with Mr. Tavrin in other &#10; businesses that are not related to the Company. Neither Mr. Tavrin nor his &#10; affiliate is otherwise affiliated with the Selling Shareholders or the Company, &#10; and the Company has no obligations to Mr. Tavrin or his affiliate.',
#    'competition': 'We are the largest player in the Russian online recruitment market and offer the &#10; most comprehensive package of HR and recruiting services, supported by the &#10; largest CV database, a well-recognized brand and a growing base of job postings, &#10; as well as by our ability to attract new customers and retain existing ones. We &#10; believe that our scale and position in the Russian online recruitment market &#10; provide a competitive edge over other market participants and help us &#10; successfully sustain and compete for additional market share. &#10;  &#10; The Russian online recruitment market is characterized by a dynamic competitive &#10; landscape and ongoing technological evolution. We face competition mainly from &#10; Russian online job portals, online classifieds platforms with presence in the &#10; jobs vertical and offline media. Our key competitors include Russian online &#10; recruitment services providers such as SuperJob.ru, Zarplata.ru and Rabota.ru, &#10; who also offer access to CV databases and job posting services. In addition, we &#10; face competition from the large Russian general classifieds company Avito, which &#10; is focused on blue collar job seekers and small businesses, monetizing primarily &#10; through a fee-per-job posting model. Our former shareholder, Mail.Ru, runs its &#10; classifieds business under the “Youla” brand and in 2018, launched a job &#10; aggregation model under this brand, and later in the summer of 2018, allowed &#10; employers to post job vacancies directly on its site for free, and it is &#10; uncertain how this could affect the overall competitive climate. Yandex, another &#10; well-established Internet player in Russia, is currently present in the  &#10; recruitment market via an aggregator platform and might decide to expand its  &#10; presence in the jobs’ market by directly targeting some or all of our customers. &#10; Over the last two years, we have noticed the emergence of mobile-only startups,  &#10; which target blue collar high turnover professions. These startups are still in  &#10; the early stages, and it is uncertain how they will affect the overall  &#10; competitive climate in Russia. Several new specialized HR technology companies  &#10; are bringing new technologies to recruitment functions and could challenge the  &#10; automation of certain recruitment related functions and have emerged as new  &#10; players, which could gain a larger presence in the market. In certain  &#10; geographies and specific segments, we compete mainly with offline media, such &#10; as local newspapers with a jobs classifieds section. &#10;  &#10; Our international competitors include or may in the future include global &#10; professional networks, such as LinkedIn, job portals and aggregators, such as &#10; Indeed, HR technology companies and players who operate adjacent business &#10; models, including social networks, such as Facebook, and search engines, such as &#10; Google, who recently introduced its enhanced job search user function called &#10; “Google for Jobs” in Russia. The competition from international players is &#10; currently limited, given that Russia is perceived as a market with strong &#10; domestic Internet players, as well as Russia’s regulatory regime, compliance &#10; with which entails significant investments and costs, such as the requirement to &#10; store personal data of Russian citizens within Russia as prescribed by the Law &#10; on Personal Data. Notably, access to LinkedIn’s resources in Russia was blocked &#10; by the Roskomnadzor in November 2016 as a result of LinkedIn’s failure to  &#10; comply with this regulation. We believe we are advantageously positioned  &#10; against our indirect competitors, such as social networks and search engines. &#10;  &#10; Because our CV database, traffic to our website and the range of additional &#10; services for employers exceed those of our competitors, we view premium prici ...
#    'amount': 199728263,
#    'percentOffered': '32.61'},
#   {'symbol': 'APLT',
#    'companyName': 'APPLIED THERAPEUTICS INC.',
#    'expectedDate': '2019-05-09',
#    'leadUnderwriters': ['Citigroup Global Markets Inc',
#     'Cowen and Company, LLC',
#     'UBS Investment Bank'],
#    'underwriters': ['Robert W. Baird & Co. Incorporated'],
#    'companyCounsel': ['Cooley LLP'],
#    'underwriterCounsel': ['Davis Polk & Wardwell LLP'],
#    'auditor': 'Computershare Trust Company, N.A',
#    'market': 'NASDAQ Global',
#    'cik': '0001697532',
#    'address': '340 MADISON AVENUE',
#    'city': 'NEW YORK',
#    'state': 'NY',
#    'zip': '10173',
#    'phone': '212-220-9319',
#    'ceo': 'Shoshana Shendelman',
#    'employees': 9,
#    'url': 'www.appliedtherapeutics.com',
#    'status': 'Filed',
#    'sharesOffered': 4000000,
#    'priceLow': 14,
#    'priceHigh': 16,
#    'offerAmount': None,
#    'totalExpenses': 3200000,
#    'sharesOverAlloted': 600000,
#    'shareholderShares': None,
#    'sharesOutstanding': 17052202,
#    'lockupPeriodExpiration': '',
#    'quietPeriodExpiration': '',
#    'revenue': 0,
#    'netIncome': -16521000,
#    'totalAssets': 20246000,
#    'totalLiabilities': 4428000,
#    'stockholderEquity': -19592000,
#    'companyDescription': 'We are a clinical-stage biopharmaceutical company developing a pipeline of novel &#10; product candidates against validated molecular targets in indications of high  &#10; unmet medical need. We focus on molecules and pathways whose role in the disease &#10; process is well known based on prior research, but have previously failed to &#10; yield successful products due to poor efficacy and tolerability. Our unique &#10; approach to drug development leverages recent technological advances to design &#10; improved drugs, employs early use of biomarkers to confirm biological activity &#10; and focuses on abbreviated regulatory pathways. We develop product candidates &#10; with increased potency and selectivity by leveraging recent technological  &#10; advances in high throughput crystallography and in situ structural design. Our &#10; strategy is also informed by early use of biomarkers to confirm biological  &#10; activity and target engagement. The result of this unique multifaceted approach &#10; to drug development is a portfolio of highly specific and selective product  &#10; candidates that we believe are significantly de-risked and can move quickly &#10; through the development process. &#10; --- &#10;  &#10; We were incorporated under the laws of the State of Delaware on January 20,  &#10; 2016. Our principal executive offices are located at 340 Madison Avenue, 19th &#10; Floor, New York, New York 10173, and our telephone number is (212) 220-9226. Our &#10; corporate website address is www.appliedtherapeutics.com.',
#    'businessDescription': 'We are a clinical-stage biopharmaceutical company developing a pipeline of novel &#10; product candidates against validated molecular targets in indications of high  &#10; unmet medical need. We focus on molecules and pathways whose role in the disease &#10; process is well known based on prior research, but have previously failed to  &#10; yield successful products due to poor efficacy and tolerability. Our unique  &#10; approach to drug development leverages recent technological advances to design &#10; improved drugs, employs early use of biomarkers to confirm biological activity &#10; and focuses on abbreviated regulatory pathways. We develop product candidates  &#10; with increased potency and selectivity by leveraging recent technological  &#10; advances in high throughput crystallography and in situ structural design. Our &#10; strategy is also informed by early use of biomarkers to confirm biological  &#10; activity and target engagement. The result of this unique multifaceted approach &#10; to drug development is a portfolio of highly specific and selective product  &#10; candidates that we believe are significantly de-risked and can move quickly  &#10; through the development process. &#10;  &#10; Our first molecular target is aldose reductase, or AR, the first enzyme and &#10; rate-limiting step in the polyol pathway, an alternative glucose metabolism &#10; pathway. AR is a redox-regulated enzyme that is activated by an altered redox &#10; state within the cell, such as oxidative stress, which occurs during &#10; hyperglycemia and ischemia. AR activity produces excess sorbitol, which causes &#10; osmotic dysregulation within cells and tissues, and is implicated in multiple &#10; diseases. The detrimental consequences of aberrent AR activation include broad &#10; effects, such as mitochondrial dysfunction and cell death, as well as &#10; tissue-specific changes, such as neuronal degeneration in peripheral nerves, &#10; collagen crosslinking and fibrosis in cardiac tissue, and damage to blood &#10; vessels in the lens of the eye. Prior attempts to inhibit this enzyme were &#10; hindered by nonselective, nonspecific inhibition, which resulted in limited &#10; efficacy and significant off-target safety effects. Our AR inhibitor, or ARI, &#10; program currently includes three small molecules, which are all designed to be &#10; potent and selective ARIs, and are engineered to have unique tissue permeability &#10; profiles to target different disease states, including diabetic complications, &#10; heart disease and a rare pediatric metabolic disease. &#10;  &#10; Our lead product candidate, AT-001, is a novel ARI with broad systemic exposure &#10; and peripheral nerve permeability, that we are developing for the treatment of  &#10; diabetic cardiomyopathy, or DbCM, a fatal fibrosis of the heart, for which no  &#10; treatments are available. DbCM is estimated to afflict 17% of diabetic patients, &#10; equating to an estimated 77 million patients globally. We initially plan to  &#10; target the 50% of these patients who are within the symptomatic stages of  &#10; disease we believe most likely to be responsive to treatment. We are also  &#10; developing AT-001 for diabetic peripheral neuropathy, or DPN, a debilitating &#10; neurodegenerative disease that significantly reduces quality of life, and for &#10; which there are currently no approved treatments in the United States.  &#10; Approximately 50% of the global diabetic population, or 226 million diabetic &#10; patients, suffer from DPN. We recently completed a Phase 1/2 clinical trial  &#10; evaluating AT-001 in approximately 120 patients with type 2 diabetes, in which &#10; no drug-related adverse effects or tolerability issues were observed. This trial &#10; also demonstrated target engagement and proof of biological activity, as  &#10; measured by reduction in sorbitol, a biomarker of AR activity, and NTproBNP, a &#10; marker of cardiac stre ...
#    'useOfProceeds': 'We estimate that the net proceeds to us from this offering will be approximately &#10; $52.6 million (or approximately $61.0 million if the underwriters exercise in  &#10; full their option to purchase up to 600,000 additional shares of common stock to &#10; cover over-allotments), based on an assumed initial public offering price of  &#10; $15.00 per share, the midpoint of the price range set forth on the cover page of &#10; this prospectus, after deducting estimated underwriting discounts and &#10; commissions and estimated offering expenses payable by us. &#10;  &#10; Each $1.00 increase or decrease in the assumed initial public offering price of &#10; $15.00 per share, the midpoint of the price range set forth on the cover page of &#10; this prospectus, would increase or decrease the net proceeds to us from this &#10; offering by $3.7 million, assuming that the number of shares of common stock &#10; offered by us, as set forth on the cover page of this prospectus, remains the &#10; same and after deducting the estimated underwriting discounts and commissions &#10; and estimated offering expenses payable by us. Similarly, each increase or &#10; decrease of 1.0 million shares of common stock offered by us, would increase or &#10; decrease the net proceeds to us by $14.0 million, assuming the assumed initial &#10; public offering price per share remains the same, and after deducting the &#10; estimated underwriting discounts and commissions. &#10;  &#10; The principal purposes of this offering are to increase our capitalization and &#10; financial flexibility, establish a public market for our common stock and to &#10; facilitate future access to the public equity markets by us, our employees and &#10; our stockholders, obtain additional capital to support our operations and &#10; increase our visibility in the marketplace. &#10;  &#10; We currently intend to use the net proceeds from this offering, together with &#10; our existing cash and cash equivalents, as follows: &#10;  &#10; • approximately $30 million to fund our pivotal Phase 2/3 clinical trial for &#10;   AT-001 for the treatment of diabetic cardiomyopathy; &#10;  &#10; • approximately $5 million to advance AT-007 for the treatment of galactosemia  &#10;   in adults through our planned Phase 1 clinical trial; &#10;  &#10; • approximately $4 million to advance AT-003 for the treatment of diabetic  &#10;   retinopathy into our planned Phase 1 clinical trial; and &#10;  &#10; • the remainder to fund other research and development activities, working  &#10;   capital and other general corporate purposes. &#10;  &#10; We may also use a portion of the remaining net proceeds to in-license, acquire &#10; or invest in complementary businesses, technologies, products or assets.  &#10; However, we have no current commitments or obligations to do so. &#10;  &#10; This expected use of the net proceeds from this offering represents our  &#10; intentions based on our current plans and business conditions, which could &#10; change in the future as our plans and business conditions evolve. Further, due &#10; to the uncertainties inherent in the drug development process, it is difficult &#10; to estimate with certainty the exact amounts of the net proceeds from this &#10; offering that may be used for the above purposes. &#10;  &#10; Our management will have broad discretion over the use of the net proceeds from &#10; this offering, and our investors will be relying on the judgment of our &#10; management regarding the application of the net proceeds of this offering. The &#10; amounts and timing of our expenditures will depend upon numerous factors &#10; including the results of our research and development efforts, the timing and &#10; success of preclinical studies and any ongoing clinical trials or clinical &#10; trials we may commence in the future, the timing of regulatory submissions and &#10; the amount of cash obtained through current and any future col ...
#    'competition': 'The pharmaceutical industry is characterized by rapidly advancing technologies, &#10; intense competition and a strong emphasis on proprietary products. While we  &#10; believe that our technology, the expertise of our executive and scientific team, &#10; research, clinical capabilities, development experience and scientific knowledge &#10; provide us with competitive advantages, we face potential competition from many &#10; different sources, including pharmaceutical and biotechnology companies,  &#10; academic institutions and governmental agencies and public and private research &#10; institutions. Product candidates that we successfully develop and commercialize &#10; may compete with existing therapies and new therapies that may become available &#10; in the future. &#10;  &#10; Our competitors may have significantly greater financial resources, established &#10; presence in the market, expertise in research and development, manufacturing,  &#10; preclinical and clinical testing, obtaining regulatory approvals and  &#10; reimbursement and marketing approved products than we do. These competitors also &#10; compete with us in recruiting and retaining qualified scientific, sales, &#10; marketing and management personnel, establishing clinical trial sites and &#10; patient registration for clinical trials, as well as in acquiring technologies &#10; complementary to, or necessary for, our programs. Smaller or early-stage &#10; companies may also prove to be significant competitors, particularly through &#10; collaborative arrangements with large and established companies. &#10;  &#10; There are currently no therapies approved to treat DbCM. Entresto, a drug  &#10; developed by Novartis International AG, or Novartis, is approved for acute heart &#10; failure, which can be caused by many conditions, including DbCM. However, we are &#10; aware that Novartis may be pursuing a label expansion for earlier treatment of &#10; generalized heart failure, which may overlap with our target disease stages in &#10; DbCM. Additionally, sponsors of sodium-glucose cotransporter-2, or SGLT2, &#10; inhibitors are pursuing broad cardiovascular labels in type 2 diabetes patients, &#10; which may include a subset of DbCM patients as part of the larger diabetic &#10; population at risk for heart failure. We are also aware of planned Phase 2 &#10; clinical trials on glucagon-like peptide-1, or GLP-1, agonists in DbCM, as well &#10; as anti-fibrotic therapies in Phase 1 clinical development. Many of these &#10; programs are sponsored by large pharmaceutical companies with a strong presence &#10; in cardiology and metabolic disease. Additionally, stem-cell targeted &#10; initiatives are in various stages of preclinical and early clinical development &#10; to stimulate regeneration of cardiac tissue to counter fibrosis in DbCM. There &#10; have been prior studies demonstrating effectiveness in DbCM of off-label use of &#10; sildenafil, although we do not believe this represents a commercially viable &#10; competitive threat. &#10;  &#10; There are no disease modifying therapies approved to treat DPN outside of Japan, &#10; India and China. In these limited markets, epalrestat, another ARI, is approved &#10; to prevent worsening of DPN, and despite challenges in compliance due to  &#10; frequent dosing three to five times daily, the drugs are generic and offer a low &#10; cost alternative. A more effective therapy with improved tolerability and dosing &#10; may offer an advantage. A re-formulation of proprietary crystalline epalrestat, &#10; BNV-222, is in development for DPN in Russia in a 12-month Phase 2/3 clinical  &#10; trial, which completed enrollment in 2016, but has not yet reported any results. &#10;  &#10; There are currently no therapies approved to treat galactosemia. Due to the &#10; importance of GALK and GALT enzymes within neurons in the CNS, we believe that &#10; enzyme replacement therapy is not an effective approac ...
#    'amount': 60000000,
#    'percentOffered': '23.46'},
#   {'symbol': 'NXTC',
#    'companyName': 'NEXTCURE, INC.',
#    'expectedDate': '2019-05-09',
#    'leadUnderwriters': ['BofA Merrill Lynch',
#     'Morgan Stanley & Co. LLC',
#     'Piper Jaffray & Co.'],
#    'underwriters': [],
#    'companyCounsel': ['Hogan Lovells US LLP'],
#    'underwriterCounsel': ['Cooley LLP'],
#    'auditor': 'American Stock Transfer & Trust Company, LLC',
#    'market': 'NASDAQ Global Select',
#    'cik': '0001661059',
#    'address': '9000 VIRGINIA MANOR ROAD, SUITE 200',
#    'city': 'BELTSVILLE',
#    'state': 'MD',
#    'zip': '20705',
#    'phone': '240-399-4900',
#    'ceo': 'Michael Richman',
#    'employees': 44,
#    'url': 'www.nextcure.com',
#    'status': 'Filed',
#    'sharesOffered': 5000000,
#    'priceLow': 14,
#    'priceHigh': 16,
#    'offerAmount': None,
#    'totalExpenses': 3200000,
#    'sharesOverAlloted': 750000,
#    'shareholderShares': None,
#    'sharesOutstanding': 21935381,
#    'lockupPeriodExpiration': '',
#    'quietPeriodExpiration': '',
#    'revenue': 0,
#    'netIncome': -22799000,
#    'totalAssets': 147628000,
#    'totalLiabilities': 32349000,
#    'stockholderEquity': -46944000,
#    'companyDescription': 'We are a clinical-stage biopharmaceutical company committed to discovering &#10; and developing novel, first-in-class immunomedicines to treat cancer and other &#10; immune-related diseases by restoring normal immune function. We view the immune &#10; system holistically and, rather than target one specific immune cell type, we &#10; focus on understanding biological pathways, the interactions of cells and the &#10; role each interaction plays in an immune response. Through our proprietary &#10; Functional, Integrated, NextCure Discovery in Immuno-Oncology, or FIND-IO, &#10; platform, we study various immune cells to discover and understand targets and &#10; structural components of immune cells and their functional impact in order to &#10; develop immunomedicines. We are focused on patients who do not respond to &#10; current therapies, patients whose cancer progresses despite treatment and &#10; patients with cancer types not adequately addressed by available therapies. We &#10; are committed to discovering and developing first-in-class immunomedicines, &#10; which are immunomedicines that use new or unique mechanisms of action to treat a &#10; medical condition, for these patients. &#10; --- &#10;  &#10; We were incorporated in Delaware in September 2015. Our primary executive &#10; offices are located at 9000 Virginia Manor Road, Suite 200, Beltsville, Maryland &#10; 20705 and our telephone number is (240) 399-4900. Our website address is &#10; www.nextcure.com.',
#    'businessDescription': 'We are a clinical-stage biopharmaceutical company committed to discovering &#10; and developing novel, first-in-class immunomedicines to treat cancer and other &#10; immune-related diseases by restoring normal immune function. We view the immune &#10; system holistically and, rather than target one specific immune cell type, we &#10; focus on understanding biological pathways, the interactions of cells and the &#10; role each interaction plays in an immune response. Through our proprietary &#10; Functional, Integrated, NextCure Discovery in Immuno-Oncology, or FIND-IO, &#10; platform, we study various immune cells to discover and understand targets and &#10; structural components of immune cells and their functional impact in order to &#10; develop immunomedicines. We are focused on patients who do not respond to &#10; current therapies, patients whose cancer progresses despite treatment and &#10; patients with cancer types not adequately addressed by available therapies. We &#10; are committed to discovering and developing first-in-class immunomedicines, &#10; which are immunomedicines that use new or unique mechanisms of action to treat a &#10; medical condition, for these patients. &#10;  &#10; Our lead product candidate, NC318, is a first-in-class immunomedicine against a &#10; novel immunomodulatory receptor called Siglec-15, or S15. In October 2018, we &#10; initiated a Phase 1/2 clinical trial of NC318 in patients with advanced or  &#10; metastatic solid tumors. We expect completion of the Phase 1 portion of this  &#10; trial in the fourth quarter of 2019 and completion of the Phase 2 portion in the &#10; fourth quarter of 2020. Our second product candidate, NC410, is a novel  &#10; immunomedicine designed to block immune suppression mediated by an immune  &#10; modulator called Leukocyte-Associated Immunoglobulin-like Receptor 1, or LAIR-1. &#10; We expect to submit an investigational new drug application, or IND, to the U.S. &#10; Food and Drug Administration, or FDA, for NC410 in the first quarter of 2020. &#10;  &#10; Our approach to identifying targets for new immunomedicines is based on our  &#10; FIND-IO platform. FIND-IO embodies a rational approach to the discovery of novel &#10; cell surface and secretory molecules that drive functional immune responses. We &#10; use our immunology knowledge, experience, capabilities and tools we have &#10; developed, including our FIND-IO platform, to support our discovery efforts. We &#10; are working to discover novel targets that play a key role in mediating immune &#10; dysfunction that allows tumors to evade the immune system. We are seeking to &#10; identify and develop immunomedicines that counteract these outcomes and to &#10; further validate and advance our product candidates. We have identified multiple &#10; novel targets using our FIND-IO platform, including those for which certain of &#10; our research programs are being designed to target. In addition, the &#10; immunosuppressive properties of S15, the target of NC318, were discovered using &#10; a predecessor of our FIND-IO platform. &#10;  &#10; The advancement of cancer to late stages indicates a failure of the immune  &#10; system to mount an effective anti-tumor immune response. Immuno-oncology, which &#10; focuses on stimulating the immune system to respond to cancer and includes &#10; checkpoint inhibitors targeting PD-L1, PD-1 and CTLA-4, is one of the most &#10; significant advances in the history of cancer treatment. In 2011, the first &#10; checkpoint inhibitor was approved, and today, despite only a modest breadth of &#10; efficacy, this class of therapies is estimated to have had global sales of more &#10; than $17 billion in 2018 and is predicted to reach more than $33 billion in &#10; global sales by 2022. However, despite the recent success of checkpoint &#10; inhibitors, efficacy has been limited. It is estimated that up to 60% to 70% of &#10; cancer patients, includi ...
# ...
#    'amount': 168750000,
#    'percentOffered': '100.00'},
#   {'symbol': 'LK',
#    'companyName': 'LUCKIN COFFEE INC.',
#    'expectedDate': '2019-05-17',
#    'leadUnderwriters': ['China International Capital Corporation Hong Kong Securities...',
#     'Credit Suisse Securities (USA) LLC',
#     'Haitong International Securities Company Limited',
#     'Morgan Stanley & Co. LLC'],
#    'underwriters': ['KeyBanc Capital Markets Inc', 'Needham & Company, LLC'],
#    'companyCounsel': ['Davis Polk & Wardwell LLP'],
#    'underwriterCounsel': ['Cleary Gottlieb Steen & Hamilton LLP'],
#    'auditor': 'Not Specified',
#    'market': 'NASDAQ Global Select',
#    'cik': '0001767582',
#    'address': '17F BLOCK A, TEFANG PORTMAN TOWER',
#    'city': 'XIAMEN, FUJIAN 361008',
#    'state': '',
#    'zip': '',
#    'phone': '86 592 338 6666',
#    'ceo': 'Jenny Zhiya Qian',
#    'employees': 16645,
#    'url': 'www.luckincoffee.com',
#    'status': 'Filed',
#    'sharesOffered': 30000000,
#    'priceLow': 15,
#    'priceHigh': 17,
#    'offerAmount': None,
#    'totalExpenses': 6366788.6,
#    'sharesOverAlloted': 4500000,
#    'shareholderShares': None,
#    'sharesOutstanding': 34075688,
#    'lockupPeriodExpiration': '',
#    'quietPeriodExpiration': '',
#    'revenue': 71300000,
#    'netIncome': -82218000,
#    'totalAssets': 432221000,
#    'totalLiabilities': 160899000,
#    'stockholderEquity': -374341000,
#    'companyDescription': "Our mission is to be part of everyone's everyday life, starting with coffee. &#10;  &#10; We are China's second largest and fastest-growing coffee network, in terms of &#10; number of stores and cups of coffee sold, according to the Frost & Sullivan &#10; Report. We have pioneered a technology-driven new retail model to provide coffee &#10; and other products with high quality, high affordability and high convenience to &#10; our customers. We believe that our disruptive model has fulfilled the large &#10; unmet demand for coffee and driven its mass market consumption in China, while &#10; allowing us to achieve significant scale and growth since our inception. &#10;  &#10; Driven by technology, our new retail model is built upon our mobile apps and &#10; store network. &#10;  &#10; • Mobile apps: Our mobile apps cover the entire customer purchase process, &#10;   offering our customers a 100% cashier-less environment. This enhances our &#10;   customer experience, improves our operating efficiency, and allows us to stay &#10;   connected with our customers and engage them anytime, anywhere. &#10;  &#10; • Store network: While operating three types of stores, we strategically focus &#10;   on pick-up stores, which accounted for 91.3% of our total stores as of March &#10;   31, 2019. Our pick-up stores have limited seating and are typically located in &#10;   areas with high demand for coffee, such as office buildings, commercial areas &#10;   and university campuses. This enables us to stay close to our target customers &#10;   and expand rapidly with low rental and decoration costs. &#10; --- &#10;  &#10; Our principal executive offices are located at 17F Block A, Tefang Portman &#10; Tower, No. 81 Zhanhong Road, Siming District, Xiamen, Fujian, People's Republic &#10; of China. Our telephone number at this address is +86-592-3386666. &#10;  &#10; Our registered office in the Cayman Islands is located at Conyers Trust Company &#10; (Cayman) Limited, Cricket Square, Hutchins Drive, P.O. Box 2681, Grand Cayman, &#10; KY1-1111, Cayman Islands. &#10;  &#10; Our agent for service of process in the United States is Cogency Global Inc. &#10; located at 10 E. 40th Street, 10th Floor New York, New York 10016. Our principal &#10; website is www.luckincoffee.com.",
#    'businessDescription': "Our mission is to be part of everyone's everyday life, starting with coffee. &#10;  &#10; We are China's second largest and fastest-growing coffee network, in terms of &#10; number of stores and cups of coffee sold, according to the Frost & Sullivan &#10; Report. We have pioneered a technology-driven new retail model to provide coffee &#10; and other products with high quality, high affordability and high convenience to &#10; our customers. We believe that our disruptive model has fulfilled the large &#10; unmet demand for coffee and driven its mass market consumption in China, while &#10; allowing us to achieve significant scale and growth since our inception. &#10;  &#10; Driven by technology, our new retail model is built upon our mobile apps and &#10; store network. &#10;  &#10; • Mobile apps: Our mobile apps cover the entire customer purchase process, &#10;   offering our customers a 100% cashier-less environment. This enhances our &#10;   customer experience, improves our operating efficiency, and allows us to stay &#10;   connected with our customers and engage them anytime, anywhere. &#10;  &#10; • Store network: While operating three types of stores, we strategically focus &#10;   on pick-up stores, which accounted for 91.3% of our total stores as of March &#10;   31, 2019. Our pick-up stores have limited seating and are typically located in &#10;   areas with high demand for coffee, such as office buildings, commercial areas &#10;   and university campuses. This enables us to stay close to our target customers &#10;   and expand rapidly with low rental and decoration costs. &#10;  &#10; By disrupting the status quo of the traditional coffee shop model, we have &#10; gained significant cost advantages and provided attractive value propositions to &#10; our customers. &#10;  &#10; Technology is at the core of our business. With our centralized technology &#10; system, we are able to simplify and standardize our operations, which allows us &#10; to improve operational efficiency and quickly expand and scale up our business. &#10; We leverage big data analytics and AI to analyze our customer behavior and &#10; transaction data, which enables us to continuously enhance our products and &#10; services, implement dynamic pricing and improve customer retention. We also &#10; leverage our proprietary technologies in store operations and supply chain to &#10; support our business, such as new store selection, inventory management and &#10; workforce management. Our focus on technologies has enabled us to operate &#10; efficiently, grow rapidly while maintaining quality control. &#10; --- &#10;   &#10; We offer premium coffee and other high-quality products to our customers. We &#10; source premium Arabica coffee beans from prominent suppliers and engage World &#10; Barista Champion teams to design our coffee recipes. We procure coffee machines &#10; and coffee condiments from renowned global suppliers such as Schaerer. Our &#10; coffee has won numerous awards, including most recently the Gold Medal in the &#10; 2018 IIAC International Coffee Tasting competition. We also partner with &#10; reputable suppliers for our other products such as juices and light meals. Due &#10; to our scale, we are able to procure high-quality products from our suppliers at &#10; favorable prices. &#10;  &#10; Since inception, we have successfully built a brand of distinguished value &#10; propositions—high quality, high affordability and high convenience. We have also &#10; been able to cultivate a large and loyal customer base and achieve strong &#10; growth. Within 18 months, we expanded from a single trial store in Beijing to &#10; 2,370 stores in 28 cities in China as of March 31, 2019. We had over 16.8 &#10; million of cumulative transacting customers as of March 31, 2019. In addition, &#10; our customer repurchase rate in 2018 was over 54%. &#10;  &#10; China's coffee market is highly underpenetrated. Inconsistent q ...
#    'useOfProceeds': 'We estimate that we will receive net proceeds from this offering and the &#10; concurrent private placement to Louis Dreyfus Company B.V. of approximately &#10; US$490.0 million, or approximately US$557.0 million if the underwriters exercise &#10; their option to purchase additional ADSs in full, after deducting underwriting &#10; discounts and commissions and the estimated offering expenses payable by us. &#10;  &#10; We plan to use the net proceeds of this offering and the concurrent private &#10; placement to Louis Dreyfus Company B.V. for general corporate purposes, which &#10; may include store network expansion, customer acquisition, research and &#10; development, sales and marketing, investment in our technology infrastructure, &#10; working capital, and other general and administrative matters. In utilizing the &#10; proceeds from this offering and the concurrent private placement to Louis &#10; Dreyfus Company B.V., we are permitted under PRC laws and regulations to provide &#10; funding to our PRC subsidiaries only through loans or capital contributions, and &#10; to our consolidated VIE only through loans, and only if we satisfy the &#10; applicable government registration and approval requirements. We cannot assure &#10; you that we will be able to meet these requirements on a timely basis, if at &#10; all. We expect that all the net proceeds from this offering and the concurrent &#10; private placement to Louis Dreyfus Company B.V. will be used in the PRC in the &#10; form of RMB and mainly by funding our PRC subsidiaries through capital &#10; contributions. In general, the relevant registration and approval procedures for &#10; capital contributions typically take approximately eight weeks to complete and &#10; there is no statutory limit on the amount of capital contributions under PRC &#10; laws and regulations. We currently see no material obstacles in completing the &#10; registration and approval procedures with respect to future capital &#10; contributions to our PRC subsidiaries. &#10;  &#10; Pending use of the net proceeds, we intend to hold our net proceeds in &#10; short-term, interest-bearing, financial instruments or demand deposits.',
#    'competition': "We face intense competition in China's coffee industry. Our current or potential &#10; competitors are mainly coffee shop operators. &#10;  &#10; We believe that the principal competitive factors in China coffee industry &#10; include the following: &#10;  &#10; • Store network; &#10;  &#10; • Product quality and safety; &#10;  &#10; • Product pricing; &#10;  &#10; • Supply chain management and operating efficiency; &#10;  &#10; • Quality of customer services; &#10;  &#10; • Brand recognition and reputation; &#10;  &#10; • Effectiveness of sales and marketing; and &#10;  &#10; • Customer experience &#10;  &#10; We believe that we are well-positioned to effectively compete on the basis of &#10; the factors listed above. However, our competitors may have longer operating &#10; history, greater brand recognition, more capital, better supplier relationships &#10; and larger customer base.",
#    'amount': 480000000,
#    'percentOffered': '88.04'}],
#  'viewData': [{'Company': 'PARSONS CORP',
#    'Symbol': 'PSN',
#    'Price': '$26.00 - 28.00',
#    'Shares': '18,518,500',
#    'Amount': '499,999,500',
#    'Float': '96,657,331',
#    'Percent': '19.16%',
#    'Market': 'NYSE',
#    'Expected': '2019-05-08'},
#   {'Company': 'HEADHUNTER GROUP PLC',
#    'Symbol': 'HHR',
#    'Price': '$11.00 - 13.50',
#    'Shares': '16,304,348',
#    'Amount': '199,728,263',
#    'Float': '50,000,000',
#    'Percent': '32.61%',
#    'Market': 'NASDAQ Global Select',
#    'Expected': '2019-05-09'},
#   {'Company': 'APPLIED THERAPEUTICS INC.',
#    'Symbol': 'APLT',
#    'Price': '$14.00 - 16.00',
#    'Shares': '4,000,000',
#    'Amount': '60,000,000',
#    'Float': '17,052,202',
#    'Percent': '23.46%',
#    'Market': 'NASDAQ Global',
#    'Expected': '2019-05-09'},
#   {'Company': 'NEXTCURE, INC.',
#    'Symbol': 'NXTC',
#    'Price': '$14.00 - 16.00',
#    'Shares': '5,000,000',
#    'Amount': '75,000,000',
#    'Float': '21,935,381',
#    'Percent': '22.79%',
#    'Market': 'NASDAQ Global Select',
#    'Expected': '2019-05-09'},
#   {'Company': 'SOUTH PLAINS FINANCIAL, INC.',
#    'Symbol': 'SPFI',
#    'Price': '$17.50 - 19.50',
#    'Shares': '3,380,000',
#    'Amount': '62,530,000',
#    'Float': '17,471,520',
#    'Percent': '19.35%',
#    'Market': 'NASDAQ Global Select',
#    'Expected': '2019-05-09'},
#   {'Company': 'MAYVILLE ENGINEERING COMPANY, INC.',
#    'Symbol': 'MEC',
#    'Price': '$19.00 - 21.00',
#    'Shares': '6,250,000',
#    'Amount': '125,000,000',
#    'Float': '19,693,484',
#    'Percent': '31.74%',
#    'Market': 'NYSE',
#    'Expected': '2019-05-09'},
#   {'Company': 'CORTEXYME, INC.',
#    'Symbol': 'CRTX',
#    'Price': '$16.00 - 18.00',
#    'Shares': '4,412,000',
#    'Amount': '75,004,000',
#    'Float': '26,013,334',
#    'Percent': '16.96%',
#    'Market': 'NASDAQ Global Select',
#    'Expected': '2019-05-09'},
#   {'Company': 'AXCELLA HEALTH INC.',
#    'Symbol': 'AXLA',
#    'Price': '$20.00 - 22.00',
#    'Shares': '3,571,428',
#    'Amount': '74,999,988',
#    'Float': '22,988,359',
#    'Percent': '15.54%',
#    'Market': 'NASDAQ Global',
#    'Expected': '2019-05-09'},
#   {'Company': 'MILESTONE PHARMACEUTICALS INC.',
#    'Symbol': 'MIST',
#    'Price': '$14.00 - 16.00',
#    'Shares': '5,000,000',
#    'Amount': '75,000,000',
#    'Float': '23,147,589',
#    'Percent': '21.60%',
#    'Market': 'NASDAQ Global',
#    'Expected': '2019-05-09'},
#   {'Company': 'DIAMOND EAGLE ACQUISITION CORP. \\ DE',
#    'Symbol': 'DEACU',
#    'Price': '$10.00',
#    'Shares': '35,000,000',
#    'Amount': '175,000,000',
#    'Float': '43,750,000',
#    'Percent': '80.00%',
#    'Market': 'NASDAQ Capital',
#    'Expected': '2019-05-09'},
#   {'Company': 'UBER TECHNOLOGIES, INC',
#    'Symbol': 'UBER',
#    'Price': '$44.00 - 50.00',
#    'Shares': '180,000,000',
#    'Amount': '8,460,000,000',
#    'Float': '1,676,959,021',
#    'Percent': '10.73%',
#    'Market': 'NYSE',
#    'Expected': '2019-05-10'},
#   {'Company': 'POSTAL REALTY TRUST, INC.',
#    'Symbol': 'PSTL',
#    'Price': '$19.00 - 21.00',
#    'Shares': '5,000,000',
#    'Amount': '100,000,000',
#    'Float': '5,763,308',
#    'Percent': '86.76%',
#    'Market': 'NYSE',
#    'Expected': '2019-05-10'},
#   {'Company': 'SONIM TECHNOLOGIES INC',
#    'Symbol': 'SONM',
#    'Price': '$13.00 - 15.00',
#    'Shares': '3,571,429',
#    'Amount': '50,000,006',
#    'Float': '19,509,611',
#    'Percent': '18.31%',
#    'Market': 'NASDAQ Global',
#    'Expected': '2019-05-10'},
#   {'Company': 'HEALTH SCIENCES ACQUISITIONS CORP',
#    'Symbol': 'HSACU',
#    'Price': '$10.00',
#    'Shares': '10,000,000',
#    'Amount': '50,000,000',
#    'Float': '12,500,000',
#    'Percent': '80.00%',
#    'Market': 'NASDAQ Capital',
#    'Expected': '2019-05-10'},
#   {'Company': 'CONVERSIONPOINT HOLDINGS, INC.',
#    'Symbol': 'CPTI',
#    'Price': '$6.00 - 7.00',
#    'Shares': '6,153,846',
#    'Amount': '39,999,999',
#    'Float': '28,153,846',
#    'Percent': '21.86%',
#    'Market': 'NASDAQ Capital',
#    'Expected': '2019-05-14'},
#   {'Company': 'BRICKTOWN BREWERY RESTAURANTS LLC',
#    'Symbol': 'BEER',
#    'Price': '$7.00 - 9.00',
#    'Shares': '1,875,000',
#    'Amount': '15,000,000',
#    'Float': '5,000,000',
#    'Percent': '37.50%',
#    'Market': 'NASDAQ Capital',
#    'Expected': '2019-05-15'},
#   {'Company': 'PIMCO MORTGAGE INCOME TRUST INC.',
#    'Symbol': 'PMTG',
#    'Price': '$20.00',
#    'Shares': '50,000,000',
#    'Amount': '500,000,000',
#    'Float': '50,000,000',
#    'Percent': '100.00%',
#    'Market': 'NYSE',
#    'Expected': '2019-05-16'},
#   {'Company': 'AVANTOR, INC.',
#    'Symbol': 'AVTR',
#    'Price': '$18.00 - 21.00',
#    'Shares': '154,000,000',
#    'Amount': '3,003,000,000',
#    'Float': '426,444,907',
#    'Percent': '36.11%',
#    'Market': 'NYSE',
#    'Expected': '2019-05-17'},
#   {'Company': 'FASTLY, INC.',
#    'Symbol': 'FSLY',
#    'Price': '$14.00 - 16.00',
#    'Shares': '11,250,000',
#    'Amount': '168,750,000',
#    'Float': '11,250,000',
#    'Percent': '100.00%',
#    'Market': 'NYSE',
#    'Expected': '2019-05-17'},
#   {'Company': 'LUCKIN COFFEE INC.',
#    'Symbol': 'LK',
#    'Price': '$15.00 - 17.00',
#    'Shares': '30,000,000',
#    'Amount': '480,000,000',
#    'Float': '34,075,688',
#    'Percent': '88.04%',
#    'Market': 'NASDAQ Global Select',
#    'Expected': '2019-05-17'}]}

# %%
c.ipoUpcomingDF()
# Out:
#                                 address     amount  \
# symbol
# CHWY      1855 GRIFFIN ROAD, SUITE B-42  832000000
# STOK                    3 PRESTON COURT  100500000
# PSNL                 1330 O'BRIEN DRIVE  100000005
# GO                   5650 HOLLIS STREET  275000000
# DRMT              2398 E. CAMELBACK RD.  100100000
# PRVL    430 EAST 29TH STREET, SUITE 940  125001000
# BCEL     500 SAGINAW DRIVE, FIRST FLOOR  124950000
# AKRO                     170 HARBOR WAY   75000000
#
#                                               auditor  \
# symbol
# CHWY     American Stock Transfer & Trust Company, LLC
# STOK     American Stock Transfer & Trust Company, LLC
# PSNL                 Computershare Trust Company, N.A
# GO      American Stock Transfer and Trust Company LLC
# DRMT     American Stock Transfer & Trust Company, LLC
# PRVL                 Computershare Trust Company, N.A
# BCEL                 Computershare Trust Company, N.A
# AKRO                 Computershare Trust Company, N.A
#
#                                       businessDescription  \
# symbol
# CHWY    Our mission is to be the most trusted and conv...
# STOK    We are pioneering a new way to treat the under...
# PSNL    We are a growing cancer genomics company trans...
# GO      We are a high-growth, extreme value retailer o...
# DRMT    We are a clinical-stage biopharmaceutical comp...
# PRVL    We are a gene therapy company leveraging break...
# BCEL    We are a biopharmaceutical company utilizing o...
# AKRO    We are a clinical-stage biotechnology company ...
#
#                           ceo         cik                 city  \
# symbol
# CHWY              Sumit Singh  0001766502          DANIA BEACH
# STOK           Edward M. Kaye  0001623526              BEDFORD
# PSNL                John West  0001527753           MENLO PARK
# GO      Eric J. Lindberg, Jr.  0001771515           EMERYVILLE
# DRMT           Todd Zavodnick  0001753483              PHOENIX
# PRVL           Asa Abeliovich  0001714798             NEW YORK
# BCEL            John A. Orwin  0001532346         REDWOOD CITY
# AKRO             Andrew Cheng  0001744659  SOUTH SAN FRANCISCO
#
#                           companyCounsel  \
# symbol
# CHWY              [Kirkland & Ellis LLP]
# STOK                [Fenwick & West LLP]
# PSNL                        [Cooley LLP]
# GO      [Simpson Thacher & Bartlett LLP]
# DRMT                        [Cooley LLP]
# PRVL                        [Cooley LLP]
# BCEL                        [Cooley LLP]
# AKRO               [Goodwin Procter LLP]
#
#                                        companyDescription  \
# symbol
# CHWY    Our mission is to be the most trusted and conv...
# STOK    We are pioneering a new way to treat the under...
# PSNL    We are a growing cancer genomics company trans...
# GO      We are a high-growth, extreme value retailer o...
# DRMT    We are a clinical-stage biopharmaceutical comp...
# PRVL    We are a gene therapy company leveraging break...
# BCEL    We are a biopharmaceutical company utilizing o...
# AKRO    We are a clinical-stage biotechnology company ...
#
#                          companyName  ... status  stockholderEquity  \
# symbol                                ...
# CHWY                     CHEWY, INC.  ...  Filed         -335942000
# STOK        STOKE THERAPEUTICS, INC.  ...  Filed           99581000
# PSNL                PERSONALIS, INC.  ...  Filed         -110523000
# GO      GROCERY OUTLET HOLDING CORP.  ...  Filed          303851000
# DRMT          DERMAVANT SCIENCES LTD  ...  Filed         -106432163
# PRVL       PREVAIL THERAPEUTICS INC.  ...  Filed          -27750643
# BCEL                    ATRECA, INC.  ...  Filed         -105795000
# AKRO        AKERO THERAPEUTICS, INC.  ...  Filed          -55066000
#
#        totalAssets totalExpenses totalLiabilities  \
# symbol
# CHWY     541622000       5500000        877564000
# STOK     102934000       2450000          3353000
# PSNL      57647000       3200000         78766000
# GO      2059912000       8055476       1756061000
# DRMT      18101609       3500000        124533772
# PRVL     115194156       2900000         13400958
# BCEL     109126000       2378440          5253000
# AKRO      72066000       2472451          2404000
#
#                  underwriterCounsel  \
# symbol
# CHWY    [Davis Polk & Wardwell LLP]
# STOK    [Davis Polk & Wardwell LLP]
# PSNL    [Davis Polk & Wardwell LLP]
# GO      [Davis Polk & Wardwell LLP]
# DRMT         [Latham & Watkins LLP]
# PRVL         [Latham & Watkins LLP]
# BCEL    [Davis Polk & Wardwell LLP]
# AKRO                   [Cooley LLP]
#
#                                              underwriters  \
# symbol
# CHWY    [Barclays Capital Inc, BofA Securities, Inc, J...
# STOK                              [Canaccord Genuity LLC]
# PSNL                             [Oppenheimer & Co. Inc.]
# GO      [Barclays Capital Inc, Cowen and Company, LLC,...
# DRMT                                                   []
# PRVL                             [Wedbush Securities Inc]
# BCEL    [Brookline Capital Markets, a division of Arca...
# AKRO                         [Roth Capital Partners, Inc]
#
#                                 url  \
# symbol
# CHWY                  www.chewy.com
# STOK      www.stoketherapeutics.com
# PSNL             www.personalis.com
# GO            www.groceryoutlet.com
# DRMT              www.dermavant.com
# PRVL    www.prevailtherapeutics.com
# BCEL                 www.atreca.com
# AKRO                www.akerotx.com
#
#                                             useOfProceeds    zip
# symbol
# CHWY    We expect to receive net proceeds from this of...  33004
# STOK    We estimate that the net proceeds from our sal...  01730
# PSNL    We estimate that we will receive net proceeds ...  94025
# GO      We estimate that we will receive net proceeds ...  94608
# DRMT    We estimate that the net proceeds from our iss...  85016
# PRVL    We estimate that the net proceeds from this of...  10016
# BCEL    We estimate that we will receive net proceeds ...  94063
# AKRO    We estimate that the net proceeds to us from t...  94080
#
# [8 rows x 39 columns]

# %% [markdown]
# ## Key Stats

# %%
c.keyStats(symbol)
# Out:
# {'week52change': 0.125945,
#  'week52high': 233.47,
#  'week52low': 142,
#  'marketcap': 959233158400,
#  'employees': 132000,
#  'day200MovingAvg': 192.36,
#  'day50MovingAvg': 191.93,
#  'float': 4594455231,
#  'avg10Volume': 29695469,
#  'avg30Volume': 27470517.9,
#  'ttmEPS': 11.99,
#  'ttmDividendRate': 2.92,
#  'companyName': 'Apple, Inc.',
#  'sharesOutstanding': 4601080000,
#  'maxChangePercent': 205.130117,
#  'year5ChangePercent': 1.463761,
#  'year2ChangePercent': 0.362525,
#  'year1ChangePercent': 0.125945,
#  'ytdChangePercent': 0.320162,
#  'month6ChangePercent': -0.007002,
#  'month3ChangePercent': 0.219609,
#  'month1ChangePercent': 0.041879,
#  'day30ChangePercent': 0.104588,
#  'day5ChangePercent': 0.03892,
#  'nextDividendDate': '2019-05-10',
#  'dividendYield': 0.014006139677666923,
#  'nextEarningsDate': '2019-07-22',
#  'exDividendDate': '2019-05-10',
#  'peRatio': 16.92,
#  'beta': 1.454167231727185}

# %%
c.keyStatsDF(symbol)
# Out:
#    avg10Volume  avg30Volume      beta  companyName  day200MovingAvg  \
# 0     29695469   27470517.9  1.454167  Apple, Inc.           192.36
#
#    day30ChangePercent  day50MovingAvg  day5ChangePercent  dividendYield  \
# 0            0.104588          191.93            0.03892       0.014006
#
#    employees  ... sharesOutstanding  ttmDividendRate  ttmEPS  week52change  \
# 0     132000  ...        4601080000             2.92   11.99      0.125945
#
#    week52high  week52low  year1ChangePercent year2ChangePercent  \
# 0      233.47        142            0.125945           0.362525
#
#   year5ChangePercent  ytdChangePercent
# 0           1.463761          0.320162
#
# [1 rows x 30 columns]

# %% [markdown]
# ## Largest Trades

# %%
c.largestTrades(symbol)
# Out:
# [{'price': 202.64,
#   'size': 29815,
#   'time': 1557259112641,
#   'timeLabel': '15:58:32',
#   'venue': 'XNGS',
#   'venueName': 'Nasdaq'},
#  {'price': 201.49,
#   'size': 26229,
#   'time': 1557251006634,
#   'timeLabel': '13:43:26',
#   'venue': 'None',
#   'venueName': 'Off Exchange'},
#  {'price': 201,
#   'size': 21100,
#   'time': 1557257999636,
#   'timeLabel': '15:39:59',
#   'venue': 'None',
#   'venueName': 'Off Exchange'},
#  {'price': 202.11,
#   'size': 20243,
#   'time': 1557252084201,
#   'timeLabel': '14:01:24',
#   'venue': 'None',
#   'venueName': 'Off Exchange'},
#  {'price': 205.64,
#   'size': 19334,
#   'time': 1557237644656,
#   'timeLabel': '10:00:44',
#   'venue': 'XNGS',
#   'venueName': 'Nasdaq'},
#  {'price': 202.67,
#   'size': 18777,
#   'time': 1557259140544,
#   'timeLabel': '15:59:00',
#   'venue': 'XNGS',
#   'venueName': 'Nasdaq'},
#  {'price': 203.69,
#   'size': 18710,
#   'time': 1557248941169,
#   'timeLabel': '13:09:01',
#   'venue': 'XNGS',
#   'venueName': 'Nasdaq'},
#  {'price': 204.7,
#   'size': 17289,
#   'time': 1557246318742,
#   'timeLabel': '12:25:18',
#   'venue': 'XNGS',
#   'venueName': 'Nasdaq'},
#  {'price': 201.61,
#   'size': 17200,
#   'time': 1557251024041,
#   'timeLabel': '13:43:44',
#   'venue': 'XPHL',
#   'venueName': 'Nasdaq PSX'},
#  {'price': 206.92,
#   'size': 15760,
#   'time': 1557236001139,
#   'timeLabel': '09:33:21',
#   'venue': 'None',
#   'venueName': 'Off Exchange'}]

# %%
c.largestTradesDF(symbol)
# Out:
#                           price   size timeLabel venue     venueName
# time
# 2019-05-07 19:58:32.641  202.64  29815  15:58:32  XNGS        Nasdaq
# 2019-05-07 17:43:26.634  201.49  26229  13:43:26  None  Off Exchange
# 2019-05-07 19:39:59.636  201.00  21100  15:39:59  None  Off Exchange
# 2019-05-07 18:01:24.201  202.11  20243  14:01:24  None  Off Exchange
# 2019-05-07 14:00:44.656  205.64  19334  10:00:44  XNGS        Nasdaq
# 2019-05-07 19:59:00.544  202.67  18777  15:59:00  XNGS        Nasdaq
# 2019-05-07 17:09:01.169  203.69  18710  13:09:01  XNGS        Nasdaq
# 2019-05-07 16:25:18.742  204.70  17289  12:25:18  XNGS        Nasdaq
# 2019-05-07 17:43:44.041  201.61  17200  13:43:44  XPHL    Nasdaq PSX
# 2019-05-07 13:33:21.139  206.92  15760  09:33:21  None  Off Exchange

# %% [markdown]
# ## List

# %%
c.list()[:5]
# Out:
# [{'symbol': 'AMD',
#   'companyName': 'Advanced Micro Devices, Inc.',
#   'calculationPrice': 'close',
#   'open': 27.2,
#   'openTime': 1557235800425,
#   'close': 26.66,
#   'closeTime': 1557259200467,
#   'high': 27.35,
#   'low': 26.21,
#   'latestPrice': 26.66,
#   'latestSource': 'Close',
#   'latestTime': 'May 7, 2019',
#   'latestUpdate': 1557259200467,
#   'latestVolume': 75187428,
#   'iexRealtimePrice': 26.645,
#   'iexRealtimeSize': 140,
#   'iexLastUpdated': 1557259189758,
#   'delayedPrice': 26.66,
#   'delayedPriceTime': 1557259200467,
#   'extendedPrice': 26.69,
#   'extendedChange': 0.03,
#   'extendedChangePercent': 0.00113,
#   'extendedPriceTime': 1557260206139,
#   'previousClose': 27.42,
#   'change': -0.76,
#   'changePercent': -0.02772,
#   'iexMarketPercent': 0.010079384548172069,
#   'iexVolume': 757843,
#   'avgTotalVolume': 66639014,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 28835456000,
#   'peRatio': 96.84,
#   'week52High': 34.14,
#   'week52Low': 11.3,
#   'ytdChange': 0.428467},
#  {'symbol': 'CHK',
#   'companyName': 'Chesapeake Energy Corp.',
#   'calculationPrice': 'close',
#   'open': 2.84,
#   'openTime': 1557235800151,
#   'close': 2.78,
#   'closeTime': 1557259360279,
#   'high': 2.86,
#   'low': 2.73,
#   'latestPrice': 2.78,
#   'latestSource': 'Close',
#   'latestTime': 'May 7, 2019',
#   'latestUpdate': 1557259360279,
#   'latestVolume': 61919727,
#   'iexRealtimePrice': 2.8,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1557259199970,
#   'delayedPrice': 2.78,
#   'delayedPriceTime': 1557259360289,
#   'extendedPrice': 2.8,
#   'extendedChange': 0.02,
#   'extendedChangePercent': 0.00719,
#   'extendedPriceTime': 1557260159151,
#   'previousClose': 2.89,
#   'change': -0.11,
#   'changePercent': -0.03806,
#   'iexMarketPercent': 0.022101728581587578,
#   'iexVolume': 1368533,
#   'avgTotalVolume': 40279387,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 4540018000,
#   'peRatio': 3.22,
#   'week52High': 5.6,
#   'week52Low': 1.71,
#   'ytdChange': 0.281575},
#  {'symbol': 'BAC',
#   'companyName': 'Bank of America Corp.',
#   'calculationPrice': 'close',
#   'open': 30.16,
#   'openTime': 1557235823901,
#   'close': 29.92,
#   'closeTime': 1557259357613,
#   'high': 30.17,
#   'low': 29.63,
#   'latestPrice': 29.92,
#   'latestSource': 'Close',
#   'latestTime': 'May 7, 2019',
#   'latestUpdate': 1557259357613,
#   'latestVolume': 57900808,
#   'iexRealtimePrice': 29.895,
#   'iexRealtimeSize': 200,
#   'iexLastUpdated': 1557259193658,
#   'delayedPrice': 29.92,
#   'delayedPriceTime': 1557259357638,
#   'extendedPrice': 29.94,
#   'extendedChange': 0.02,
#   'extendedChangePercent': 0.00067,
#   'extendedPriceTime': 1557260174072,
#   'previousClose': 30.47,
#   'change': -0.55,
#   'changePercent': -0.01805,
#   'iexMarketPercent': 0.019121857504993713,
#   'iexVolume': 1107171,
#   'avgTotalVolume': 57036390,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 284485344000,
#   'peRatio': 10.96,
#   'week52High': 31.91,
#   'week52Low': 22.66,
#   'ytdChange': 0.202703},
#  {'symbol': 'GE',
#   'companyName': 'General Electric Co.',
#   'calculationPrice': 'close',
#   'open': 10.31,
#   'openTime': 1557235807469,
#   'close': 10.11,
#   'closeTime': 1557259217691,
#   'high': 10.36,
#   'low': 10.06,
#   'latestPrice': 10.11,
#   'latestSource': 'Close',
#   'latestTime': 'May 7, 2019',
#   'latestUpdate': 1557259217691,
#   'latestVolume': 56597983,
#   'iexRealtimePrice': 10.115,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1557259190610,
#   'delayedPrice': 10.11,
#   'delayedPriceTime': 1557259217736,
#   'extendedPrice': 10.15,
#   'extendedChange': 0.04,
#   'extendedChangePercent': 0.00396,
#   'extendedPriceTime': 1557260206031,
#   'previousClose': 10.43,
#   'change': -0.32,
#   'changePercent': -0.03068,
#   'iexMarketPercent': 0.01441443593493429,
#   'iexVolume': 815828,
#   'avgTotalVolume': 65900696,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 88167389100,
#   'peRatio': -4.27,
#   'week52High': 15.59,
#   'week52Low': 6.66,
#   'ytdChange': 0.26497200000000004},
#  {'symbol': 'MYL',
#   'companyName': 'Mylan NV',
#   'calculationPrice': 'close',
#   'open': 26.7,
#   'openTime': 1557235800219,
#   'close': 21.53,
#   'closeTime': 1557259200479,
#   'high': 26.95,
#   'low': 21.52,
#   'latestPrice': 21.53,
#   'latestSource': 'Close',
#   'latestTime': 'May 7, 2019',
#   'latestUpdate': 1557259200479,
#   'latestVolume': 50755023,
#   'iexRealtimePrice': 21.84,
#   'iexRealtimeSize': 150,
#   'iexLastUpdated': 1557259218048,
#   'delayedPrice': 21.77,
#   'delayedPriceTime': 1557260143481,
#   'extendedPrice': 21.78,
#   'extendedChange': 0.25,
#   'extendedChangePercent': 0.01161,
#   'extendedPriceTime': 1557260203532,
#   'previousClose': 28.26,
#   'change': -6.73,
#   'changePercent': -0.23815,
#   'iexMarketPercent': 0.025444693424727636,
#   'iexVolume': 1291446,
#   'avgTotalVolume': 4541439,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 11096949540,
#   'peRatio': 31.66,
#   'week52High': 42.5,
#   'week52Low': 21.52,
#   'ytdChange': -0.225972}]

# %%
c.listDF().head()
# Out:
#         avgTotalVolume calculationPrice  change  changePercent  close  \
# symbol
# AMD           66639014            close   -0.76       -0.02772  26.66
# CHK           40279387            close   -0.11       -0.03806   2.78
# BAC           57036390            close   -0.55       -0.01805  29.92
# GE            65900696            close   -0.32       -0.03068  10.11
# MYL            4541439            close   -6.73       -0.23815  21.53
#
#                      closeTime                   companyName  delayedPrice  \
# symbol
# AMD    2019-05-07 20:00:00.467  Advanced Micro Devices, Inc.         26.66
# CHK    2019-05-07 20:02:40.279       Chesapeake Energy Corp.          2.78
# BAC    2019-05-07 20:02:37.613         Bank of America Corp.         29.92
# GE     2019-05-07 20:00:17.691          General Electric Co.         10.11
# MYL    2019-05-07 20:00:00.479                      Mylan NV         21.77
#
#               delayedPriceTime  extendedChange  ...  latestVolume    low  \
# symbol                                          ...
# AMD    2019-05-07 20:00:00.467            0.03  ...      75187428  26.21
# CHK    2019-05-07 20:02:40.289            0.02  ...      61919727   2.73
# BAC    2019-05-07 20:02:37.638            0.02  ...      57900808  29.63
# GE     2019-05-07 20:00:17.736            0.04  ...      56597983  10.06
# MYL    2019-05-07 20:15:43.481            0.25  ...      50755023  21.52
#
#            marketCap   open                openTime  peRatio  previousClose  \
# symbol
# AMD      28835456000  27.20 2019-05-07 13:30:00.425    96.84          27.42
# CHK       4540018000   2.84 2019-05-07 13:30:00.151     3.22           2.89
# BAC     284485344000  30.16 2019-05-07 13:30:23.901    10.96          30.47
# GE       88167389100  10.31 2019-05-07 13:30:07.469    -4.27          10.43
# MYL      11096949540  26.70 2019-05-07 13:30:00.219    31.66          28.26
#
#         week52High week52Low  ytdChange
# symbol
# AMD          34.14     11.30   0.428467
# CHK           5.60      1.71   0.281575
# BAC          31.91     22.66   0.202703
# GE           15.59      6.66   0.264972
# MYL          42.50     21.52  -0.225972
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Logo

# %%
c.logo(symbol)
# Out:
# {'url': 'https://storage.googleapis.com/iex/api/logos/AAPL.png'}

# %%
c.logoPNG(symbol) # Not available for sandbox
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=128x128 at 0x11EA413C8>

# %%
c.logoNotebook(symbol) # Not available for sandbox
# Out:
# <img src="https://storage.googleapis.com/iex/api/logos/AAPL.png"/>

# %% [markdown]
# ## Market Volume

# %%
c.marketVolume()[:5]
# Out:
# [{'mic': 'TRF',
#   'tapeId': '',
#   'venueName': 'TRF Volume',
#   'volume': 2616598627,
#   'tapeA': 1188236034,
#   'tapeB': 547148220,
#   'tapeC': 881214373,
#   'marketPercent': 0.34625,
#   'lastUpdated': 1557259276121},
#  {'mic': 'XNGS',
#   'tapeId': 'Q',
#   'venueName': 'NASDAQ',
#   'volume': 1442531109,
#   'tapeA': 498799249,
#   'tapeB': 251498694,
#   'tapeC': 692233166,
#   'marketPercent': 0.19089,
#   'lastUpdated': 1557259276074},
#  {'mic': 'XNYS',
#   'tapeId': 'N',
#   'venueName': 'NYSE',
#   'volume': 869030484,
#   'tapeA': 755995804,
#   'tapeB': 61562727,
#   'tapeC': 51471953,
#   'marketPercent': 0.115,
#   'lastUpdated': 1557259276081},
#  {'mic': 'ARCX',
#   'tapeId': 'P',
#   'venueName': 'NYSE Arca',
#   'volume': 751073908,
#   'tapeA': 215781374,
#   'tapeB': 351378614,
#   'tapeC': 183913920,
#   'marketPercent': 0.09939,
#   'lastUpdated': 1557259275920},
#  {'mic': 'BATS',
#   'tapeId': 'Z',
#   'venueName': 'BATS BZX',
#   'volume': 448589733,
#   'tapeA': 190127101,
#   'tapeB': 125882003,
#   'tapeC': 132580629,
#   'marketPercent': 0.05936,
#   'lastUpdated': 1557259275613}]

# %%
c.marketVolumeDF()
# Out:
#                lastUpdated  marketPercent   mic       tapeA      tapeB  \
# 0  2019-05-07 20:31:39.915        0.34822   TRF  1246784428  581102068
# 1  2019-05-07 20:31:40.061        0.18413  XNGS   499012364  253100508
# 2  2019-05-07 20:05:42.778        0.13184  XNYS   922545920   61562727
# 3  2019-05-07 20:31:39.913        0.09622  ARCX   216171089  353817727
# 4  2019-05-07 20:31:38.152        0.05723  BATS   190132470  126607178
# 5  2019-05-07 20:31:39.830        0.04346  EDGX   136947635   86977615
# 6  2019-05-07 20:31:39.911        0.04140  BATY   165891929   84816806
# 7  2019-05-07 20:31:39.876        0.02721  IEXG   125519569   22730355
# 8  2019-05-07 20:31:20.684        0.02213  EDGA    88540625   36241995
# 9  2019-05-07 20:31:29.492        0.01898  XBOS    70222534   39354884
# 10 2019-05-07 20:29:49.955        0.01303  XCIS    50009154   29678270
# 11 2019-05-07 20:31:24.011        0.00803  XPHL    18399868   27414148
# 12 2019-05-07 20:14:57.051        0.00481  XCHI    12108510   19595843
# 13 2019-05-07 20:29:42.681        0.00331  XASE     8135366   13855176
#
#         tapeC tapeId      venueName      volume
# 0   907392466            TRF Volume  2735278962
# 1   694258064      Q         NASDAQ  1446370936
# 2    51471953      N           NYSE  1035580600
# 3   185859405      P      NYSE Arca   755848221
# 4   132769027      Z       BATS BZX   449508675
# 5   117419147      K           EDGX   341344397
# 6    74521476      Y       BATS BYX   325230211
# 7    65468302      V            IEX   213718226
# 8    49029969      J           EDGA   173812589
# 9    39494008      B      NASDAQ BX   149071426
# 10   22669202      C  NYSE National   102356626
# 11   17263713      X     NASDAQ PSX    63077729
# 12    6093800      M            CHX    37798153
# 13    4042741      A  NYSE American    26033283

# %% [markdown]
# ## News

# %%
c.news(symbol)[:5]
# Out:
# [{'datetime': 1560440040000,
#   'headline': "How to lock apps on your iPhone using Apple's 'Screen Time' feature for limiting app usage",
#   'source': 'Business Insider',
#   'url': 'https://cloud.iexapis.com/v1/news/article/f887d15a-1446-4293-a95e-684531fda4b8',
#   'summary': 'If you\'d like to limit the use of some or all apps on your iPhone , Apple\'s Screen Time function allows you to lock apps with a passcode-protected time limit. You can lock apps on your iPhone using Screen Time to prevent access to any apps containing sensitive information or provide privacy on shared devices. Visit Business Insider\'s homepage for more stories . Whether you\'re looking to spend some time away from your iPhone but can\'t seem to drag yourself away from the grasp of social media apps, or just need some quiet from work emails while on vacation, Apple\'s Screen Time feature is here to assist you. When Apple introduced iOS 12 last year , it also introduced Screen Time and its ability to limit certain iPhone apps to "make more informed decisions about how you use your devices." Using the Screen Time function, you can also essentially "lock" any iPhone apps that you\'re looking to prevent yourself or others from accessing. Here\'s how to do it. How to lock apps on an iPhone using Screen Time 1.',
#   'related': 'AAPL',
#   'image': 'https://cloud.iexapis.com/v1/news/image/f887d15a-1446-4293-a95e-684531fda4b8',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1560438291000,
#   'headline': 'How An Antitrust Ruling Could Help Apple Lower The Price Of Its Modem Chips And Patents',
#   'source': 'Seeking Alpha',
#   'url': 'https://cloud.iexapis.com/v1/news/article/1ff50ea7-da75-40be-ba40-3bc40dec6c14',
#   'summary': "Apple's dispute with Qualcomm looks to have been settled, but a court ruling may still shake things up in Apple's favor. Qualcomm used a two-pronged approach to",
#   'related': 'AAPL',
#   'image': 'https://cloud.iexapis.com/v1/news/image/1ff50ea7-da75-40be-ba40-3bc40dec6c14',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1560433177000,
#   'headline': 'Huawei is furiously working to get its new operating system off the ground, trademarking it across the world and shipping 1 million test devices',
#   'source': 'Business Insider',
#   'url': 'https://cloud.iexapis.com/v1/news/article/8388baac-9688-4581-92ad-3039dba28f18',
#   'summary': 'Huawei is working furiously to get its homemade operating system, Hongmeng, off the ground. Reuters reported that it has filed a trademark for the software in nine countries, as well as Europe. China Daily also said Huawei is shipping 1 million test devices. Huawei wants to release Hongmeng early next year after being blacklisted by the US government. Visit Business Insider\'s homepage for more stories. Huawei is working furiously to get its new operating system off the ground amid the serious threat that Google will sever all ties with the Chinese tech company. US President Donald Trump\'s administration blacklisted Huawei last month amid fears it is a proxy for Chinese surveillance. It meant Google took the decision to cut off Huawei \'s access to its Android operating system. In response, Huawei — the world\'s second-biggest phone maker — has been ramping up plans for its own operating system, which it wants to release by early 2020, according to Richard Yu, the CEO of Huawei\'s consumer division . "Today, Huawei, we are still committed to Microsoft Windows and Google Android.',
#   'related': 'AAPL',
#   'image': 'https://cloud.iexapis.com/v1/news/image/8388baac-9688-4581-92ad-3039dba28f18',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1560427200000,
#   'headline': "'Alexa, what ETF should I buy?' Asset managers like BlackRock and Invesco are testing out voice assistants — but it's too early to tell if customers will actually use them",
#   'source': 'Business Insider',
#   'url': 'https://cloud.iexapis.com/v1/news/article/342128d9-b46b-4c25-aac3-5b04798fd120',
#   'summary': "Asset managers' websites are difficult to navigate. Soon institutional and retail investors could ask questions and access their portfolios via voice assistants like Siri and Alexa. Some of the largest fund managers, including BlackRock, Invesco, JPMorgan, State Street, and T. Rowe Price, are laying the foundations for voice programs, which they could roll out as soon as next year. It's unclear how much investors will use these programs, and some advisers are worried about privacy and encouraging short-term behavior. Click here for more BI Prime stories . With just a few spoken words, you can schedule doctors' appointments on Alexa , order groceries on Google Home, and ask Siri for flight updates . Soon people will be able to interact just as easily with the companies that manage their investment and retirement accounts. Big asset managers such as BlackRock, Invesco, State Street, T. Rowe Price, and JPMorgan are preparing to roll out tools on platforms like Alexa and Siri as soon as next year, top digital and marketing executives told Business Insider.",
#   'related': 'AAPL',
#   'image': 'https://cloud.iexapis.com/v1/news/image/342128d9-b46b-4c25-aac3-5b04798fd120',
#   'lang': 'en',
#   'hasPaywall': False},
#  {'datetime': 1560423600000,
#   'headline': 'Apple And The New Chip Paradigm With Mark Hibben (Podcast)',
#   'source': 'Seeking Alpha',
#   'url': 'https://cloud.iexapis.com/v1/news/article/4e7f27a1-ccb4-4a94-9926-2588a96f31e9',
#   'summary': "On the latest Marketplace Roundtable podcast, Mark Hibben (of Rethink Technology) sits down with Seeking Alpha's Jonathan Liss to walk listeners through his uni",
#   'related': 'AAPL',
#   'image': 'https://cloud.iexapis.com/v1/news/image/4e7f27a1-ccb4-4a94-9926-2588a96f31e9',
#   'lang': 'en',
#   'hasPaywall': False}]

# %%
c.newsDF(symbol).head()
# Out:
#                      hasPaywall  \
# datetime
# 2019-06-13 15:34:00       False
# 2019-06-13 15:04:51       False
# 2019-06-13 13:39:37       False
# 2019-06-13 12:00:00       False
# 2019-06-13 11:00:00       False
#
#                                                               headline  \
# datetime
# 2019-06-13 15:34:00  How to lock apps on your iPhone using Apple's ...
# 2019-06-13 15:04:51  How An Antitrust Ruling Could Help Apple Lower...
# 2019-06-13 13:39:37  Huawei is furiously working to get its new ope...
# 2019-06-13 12:00:00  'Alexa, what ETF should I buy?' Asset managers...
# 2019-06-13 11:00:00  Apple And The New Chip Paradigm With Mark Hibb...
#
#                                                                  image lang  \
# datetime
# 2019-06-13 15:34:00  https://cloud.iexapis.com/v1/news/image/f887d1...   en
# 2019-06-13 15:04:51  https://cloud.iexapis.com/v1/news/image/1ff50e...   en
# 2019-06-13 13:39:37  https://cloud.iexapis.com/v1/news/image/8388ba...   en
# 2019-06-13 12:00:00  https://cloud.iexapis.com/v1/news/image/342128...   en
# 2019-06-13 11:00:00  https://cloud.iexapis.com/v1/news/image/4e7f27...   en
#
#                     related            source  \
# datetime
# 2019-06-13 15:34:00    AAPL  Business Insider
# 2019-06-13 15:04:51    AAPL     Seeking Alpha
# 2019-06-13 13:39:37    AAPL  Business Insider
# 2019-06-13 12:00:00    AAPL  Business Insider
# 2019-06-13 11:00:00    AAPL     Seeking Alpha
#
#                                                                summary  \
# datetime
# 2019-06-13 15:34:00  If you'd like to limit the use of some or all ...
# 2019-06-13 15:04:51  Apple's dispute with Qualcomm looks to have be...
# 2019-06-13 13:39:37  Huawei is working furiously to get its homemad...
# 2019-06-13 12:00:00  Asset managers' websites are difficult to navi...
# 2019-06-13 11:00:00  On the latest Marketplace Roundtable podcast, ...
#
#                                                                    url
# datetime
# 2019-06-13 15:34:00  https://cloud.iexapis.com/v1/news/article/f887...
# 2019-06-13 15:04:51  https://cloud.iexapis.com/v1/news/article/1ff5...
# 2019-06-13 13:39:37  https://cloud.iexapis.com/v1/news/article/8388...
# 2019-06-13 12:00:00  https://cloud.iexapis.com/v1/news/article/3421...
# 2019-06-13 11:00:00  https://cloud.iexapis.com/v1/news/article/4e7f...

# %%
c.marketNews()[:5]
# Out:
# []

# %%
c.marketNewsDF().head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## OHLC

# %%
c.ohlc(symbol)
# Out:
# {'open': {'price': 205.86, 'time': 1557235800311},
#  'close': {'price': 202.86, 'time': 1557259200243},
#  'high': 207.417,
#  'low': 200.825,
#  'symbol': 'AAPL'}

# %%
c.ohlcDF(symbol)
# Out:
#    close.price              close.time     high      low  open.price  \
# 0       202.86 2019-05-07 20:00:00.243  207.417  200.825      205.86
#
#        open.time symbol
# 0  1557235800311   AAPL

# %% [markdown]
# ## Open/Close Price

# %%
c.ohlc(symbol)
# Out:
# {'open': {'price': 205.86, 'time': 1557235800311},
#  'close': {'price': 202.86, 'time': 1557259200243},
#  'high': 207.417,
#  'low': 200.825,
#  'symbol': 'AAPL'}

# %%
c.ohlcDF(symbol)
# Out:
#    close.price              close.time     high      low  open.price  \
# 0       202.86 2019-05-07 20:00:00.243  207.417  200.825      205.86
#
#                 open.time symbol
# 0 2019-05-07 13:30:00.311   AAPL

# %% [markdown]
# ## Options

# %%
exps = c.optionExpirations(symbol)
exps
# Out:
# ['201905',
#  '201906',
#  '201907',
#  '201908',
#  '201909',
#  '201910',
#  '202001',
#  '202006',
#  '202009',
#  '202101',
#  '202106']

# %%
c.options(symbol, exps[0])[:5]
# Out:
# [{'symbol': 'AAPL',
#   'id': 'AAPL20190517C00210000',
#   'expirationDate': '20190517',
#   'contractSize': 100,
#   'strikePrice': 210,
#   'closingPrice': 3.72,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 6162,
#   'openInterest': 19277,
#   'bid': 3.65,
#   'ask': 3.75,
#   'lastUpdated': '2019-05-03'},
#  {'symbol': 'AAPL',
#   'id': 'AAPL20190517C00100000',
#   'expirationDate': '20190517',
#   'contractSize': 100,
#   'strikePrice': 100,
#   'closingPrice': 113.900002,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 0,
#   'openInterest': 18,
#   'bid': 111,
#   'ask': 112.25,
#   'lastUpdated': '2019-05-03'},
#  {'symbol': 'AAPL',
#   'id': 'AAPL20190517C00090000',
#   'expirationDate': '20190517',
#   'contractSize': 100,
#   'strikePrice': 90,
#   'closingPrice': 110.93,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 0,
#   'openInterest': 95,
#   'bid': 120.699997,
#   'ask': 122.550003,
#   'lastUpdated': '2019-05-03'},
#  {'symbol': 'AAPL',
#   'id': 'AAPL20190517C00160000',
#   'expirationDate': '20190517',
#   'contractSize': 100,
#   'strikePrice': 160,
#   'closingPrice': 50.880001,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 3,
#   'openInterest': 1458,
#   'bid': 51.5,
#   'ask': 52,
#   'lastUpdated': '2019-05-03'},
#  {'symbol': 'AAPL',
#   'id': 'AAPL20190517C00270000',
#   'expirationDate': '20190517',
#   'contractSize': 100,
#   'strikePrice': 270,
#   'closingPrice': 0.01,
#   'side': 'call',
#   'type': 'equity',
#   'volume': 0,
#   'openInterest': 261,
#   'bid': 0,
#   'ask': 0.01,
#   'lastUpdated': '2019-05-03'}]

# %%
c.optionsDF(symbol, exps[0]).head()
# Out:
#           ask         bid  closingPrice  contractSize expirationDate  \
# 0    3.750000    3.650000      3.720000           100     2019-05-17
# 1  112.250000  111.000000    113.900002           100     2019-05-17
# 2  122.550003  120.699997    110.930000           100     2019-05-17
# 3   52.000000   51.500000     50.880001           100     2019-05-17
# 4    0.010000    0.000000      0.010000           100     2019-05-17
#
#                       id lastUpdated  openInterest  side  strikePrice symbol  \
# 0  AAPL20190517C00210000  2019-05-03         19277  call        210.0   AAPL
# 1  AAPL20190517C00100000  2019-05-03            18  call        100.0   AAPL
# 2  AAPL20190517C00090000  2019-05-03            95  call         90.0   AAPL
# 3  AAPL20190517C00160000  2019-05-03          1458  call        160.0   AAPL
# 4  AAPL20190517C00270000  2019-05-03           261  call        270.0   AAPL
#
#      type  volume
# 0  equity    6162
# 1  equity       0
# 2  equity       0
# 3  equity       3
# 4  equity       0

# %% [markdown]
# ## Peers

# %%
c.peers(symbol)
# Out:
# ['MSFT', 'NOK', 'IBM', 'HPQ', 'GOOGL', 'BB']

# %%
c.peersDF(symbol)
# Out:
#          peer
# symbol
# MSFT     MSFT
# NOK       NOK
# IBM       IBM
# HPQ       HPQ
# GOOGL   GOOGL
# BB         BB

# %% [markdown]
# ## Previous Day Price

# %%
c.yesterday(symbol)
# Out:
# {'date': '2019-05-06',
#  'open': 204.29,
#  'close': 208.48,
#  'high': 208.84,
#  'low': 203.5,
#  'volume': 32443113,
#  'uOpen': 204.29,
#  'uClose': 208.48,
#  'uHigh': 208.84,
#  'uLow': 203.5,
#  'uVolume': 32443113,
#  'change': 0,
#  'changePercent': 0,
#  'changeOverTime': 0,
#  'symbol': 'AAPL'}

# %%
c.yesterdayDF(symbol)
# Out:
#         change  changeOverTime  changePercent   close       date    high  \
# symbol
# AAPL         0               0              0  208.48 2019-05-06  208.84
#
#           low    open  uClose   uHigh   uLow   uOpen   uVolume    volume
# symbol
# AAPL    203.5  204.29  208.48  208.84  203.5  204.29  32443113  32443113

# %%
c.marketYesterday()['A']
# Out:
# {'symbol': 'A',
#  'date': '2019-02-19',
#  'open': 78,
#  'high': 78.32,
#  'low': 77.41,
#  'close': 77.52,
#  'volume': 2967968,
#  'uOpen': 78,
#  'uHigh': 78.32,
#  'uLow': 77.41,
#  'uClose': 77.52,
#  'uVolume': 2967968,
#  'change': None,
#  'changePercent': None}

# %%
c.marketYesterdayDF().head()
# Out:
#        change changePercent  close       date   high    low  open  uClose  \
# symbol
# A        None          None  77.52 2019-02-19  78.32  77.41  78.0   77.52
# AAALF    None          None  31.70 2019-02-19   0.00   0.00   0.0   31.70
# AAALY    None          None  34.00 2016-06-13   0.00   0.00   0.0   34.00
# AAAG     None          None   0.42 2016-06-27   0.00   0.00   0.0    0.42
# AAADX    None          None  15.85 2019-02-19   0.00   0.00   0.0   15.85
#
#         uHigh   uLow  uOpen  uVolume   volume
# symbol
# A       78.32  77.41   78.0  2967968  2967968
# AAALF    0.00   0.00    0.0        0        0
# AAALY    0.00   0.00    0.0        0        0
# AAAG     0.00   0.00    0.0        0        0
# AAADX    0.00   0.00    0.0        0        0

# %% [markdown]
# ## Price

# %%
c.price(symbol)
# Out:
# 202.86

# %%
c.priceDF(symbol)
# Out:
#     price
# 0  202.86

# %% [markdown]
# ## Price Target

# %%
c.priceTarget(symbol)
# Out:
# {'symbol': 'AAPL',
#  'updatedDate': '2019-05-03',
#  'priceTargetAverage': 214.13,
#  'priceTargetHigh': 245,
#  'priceTargetLow': 150,
#  'numberOfAnalysts': 33}

# %%
c.priceTargetDF(symbol)
# Out:
#    numberOfAnalysts  priceTargetAverage  priceTargetHigh  priceTargetLow  \
# 0                33              214.13              245             150
#
#   symbol updatedDate
# 0   AAPL  2019-05-03

# %% [markdown]
# ## Quote

# %%
c.quote(symbol)
# Out:
# {'symbol': 'AAPL',
#  'companyName': 'Apple, Inc.',
#  'calculationPrice': 'close',
#  'open': 205.86,
#  'openTime': 1557235800311,
#  'close': 202.86,
#  'closeTime': 1557259200243,
#  'high': 207.417,
#  'low': 200.825,
#  'latestPrice': 202.86,
#  'latestSource': 'Close',
#  'latestTime': 'May 7, 2019',
#  'latestUpdate': 1557259200243,
#  'latestVolume': 38391956,
#  'iexRealtimePrice': 202.89,
#  'iexRealtimeSize': 100,
#  'iexLastUpdated': 1557259199899,
#  'delayedPrice': 203.08,
#  'delayedPriceTime': 1557260100013,
#  'extendedPrice': 203.035,
#  'extendedChange': 0.175,
#  'extendedChangePercent': 0.00086,
#  'extendedPriceTime': 1557260433062,
#  'previousClose': 208.48,
#  'change': -5.62,
#  'changePercent': -0.02696,
#  'iexMarketPercent': 0.022649614414019435,
#  'iexVolume': 869563,
#  'avgTotalVolume': 27470518,
#  'iexBidPrice': 0,
#  'iexBidSize': 0,
#  'iexAskPrice': 0,
#  'iexAskSize': 0,
#  'marketCap': 933375088800,
#  'peRatio': 16.92,
#  'week52High': 233.47,
#  'week52Low': 142,
#  'ytdChange': 0.293202}

# %%
c.quoteDF(symbol)
# Out:
#         avgTotalVolume calculationPrice  change  changePercent   close  \
# symbol
# AAPL          27470518            close   -5.62       -0.02696  202.86
#
#                      closeTime  companyName  delayedPrice  \
# symbol
# AAPL   2019-05-07 20:00:00.243  Apple, Inc.        203.08
#
#               delayedPriceTime  extendedChange  ...  latestVolume      low  \
# symbol                                          ...
# AAPL   2019-05-07 20:15:00.013           0.175  ...      38391956  200.825
#
#            marketCap    open                openTime  peRatio  previousClose  \
# symbol
# AAPL    933375088800  205.86 2019-05-07 13:30:00.311    16.92         208.48
#
#         week52High week52Low  ytdChange
# symbol
# AAPL        233.47       142   0.293202
#
# [1 rows x 37 columns]

# %% [markdown]
# # Recommendation Trends

# %% [markdown]
# # Sector Performance

# %%
c.sectorPerformance()
# Out:
# [{'type': 'sector',
#   'name': 'Utilities',
#   'performance': -0.0031,
#   'lastUpdated': 1557259200308},
#  {'type': 'sector',
#   'name': 'Energy',
#   'performance': -0.00871,
#   'lastUpdated': 1557259200354},
#  {'type': 'sector',
#   'name': 'Consumer Staples',
#   'performance': -0.00994,
#   'lastUpdated': 1557259200271},
#  {'type': 'sector',
#   'name': 'Consumer Discretionary',
#   'performance': -0.01516,
#   'lastUpdated': 1557259200279},
#  {'type': 'sector',
#   'name': 'Communication Services',
#   'performance': -0.0162,
#   'lastUpdated': 1557259200247},
#  {'type': 'sector',
#   'name': 'Financials',
#   'performance': -0.0165,
#   'lastUpdated': 1557259200339},
#  {'type': 'sector',
#   'name': 'Real Estate',
#   'performance': -0.01713,
#   'lastUpdated': 1557259200244},
#  {'type': 'sector',
#   'name': 'Materials',
#   'performance': -0.01754,
#   'lastUpdated': 1557259200264},
#  {'type': 'sector',
#   'name': 'Health Care',
#   'performance': -0.0192,
#   'lastUpdated': 1557259200331},
#  {'type': 'sector',
#   'name': 'Industrials',
#   'performance': -0.02022,
#   'lastUpdated': 1557259200022},
#  {'type': 'sector',
#   'name': 'Technology',
#   'performance': -0.02148,
#   'lastUpdated': 1557259200308}]

# %%
c.sectorPerformanceDF()
# Out:
#                                    lastUpdated  performance    type
# name
# Utilities              2019-05-07 20:00:00.308     -0.00310  sector
# Energy                 2019-05-07 20:00:00.354     -0.00871  sector
# Consumer Staples       2019-05-07 20:00:00.271     -0.00994  sector
# Consumer Discretionary 2019-05-07 20:00:00.279     -0.01516  sector
# Communication Services 2019-05-07 20:00:00.247     -0.01620  sector
# Financials             2019-05-07 20:00:00.339     -0.01650  sector
# Real Estate            2019-05-07 20:00:00.244     -0.01713  sector
# Materials              2019-05-07 20:00:00.264     -0.01754  sector
# Health Care            2019-05-07 20:00:00.331     -0.01920  sector
# Industrials            2019-05-07 20:00:00.022     -0.02022  sector
# Technology             2019-05-07 20:00:00.308     -0.02148  sector

# %% [markdown]
# ## Splits

# %%
c.splits(symbol)
# Out:
# []

# %%
c.splitsDF(symbol)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Upcoming Events

# %% [markdown]
# ## Volume By Venue

# %%
c.volumeByVenue(symbol)
# Out:
# [{'volume': 58855,
#   'venue': 'XASE',
#   'venueName': 'NYSE American',
#   'date': '2019-05-07',
#   'marketPercent': 0.001550432278327238,
#   'avgMarketPercent': 0.0013988667649070885},
#  {'volume': 128014,
#   'venue': 'XCIS',
#   'venueName': 'NYSE National',
#   'date': '2019-05-07',
#   'marketPercent': 0.003372305457102762,
#   'avgMarketPercent': 0.0027233833629648333},
#  {'volume': 104690,
#   'venue': 'XCHI',
#   'venueName': 'CHX',
#   'date': '2019-05-07',
#   'marketPercent': 0.0035884340065768876,
#   'avgMarketPercent': 0.019839707033233366},
#  {'volume': 274061,
#   'venue': 'XPHL',
#   'venueName': 'Nasdaq PSX',
#   'date': '2019-05-07',
#   'marketPercent': 0.007219658833245114,
#   'avgMarketPercent': 0.00758794843446839},
#  {'volume': 366666,
#   'venue': 'EDGA',
#   'venueName': 'Cboe EDGA',
#   'date': '2019-05-07',
#   'marketPercent': 0.009659175970862884,
#   'avgMarketPercent': 0.012147458463215965},
#  {'volume': 372534,
#   'venue': 'BATY',
#   'venueName': 'Cboe BYX',
#   'date': '2019-05-07',
#   'marketPercent': 0.009813758191731532,
#   'avgMarketPercent': 0.02030662022159324},
#  {'volume': 409110,
#   'venue': 'XBOS',
#   'venueName': 'Nasdaq BX',
#   'date': '2019-05-07',
#   'marketPercent': 0.010777289089906657,
#   'avgMarketPercent': 0.01684399071131908},
#  {'volume': 869563,
#   'venue': 'IEXG',
#   'venueName': 'IEX',
#   'date': '2019-05-07',
#   'marketPercent': 0.022907119925903798,
#   'avgMarketPercent': 0.02803983675894908},
#  {'volume': 1304584,
#   'venue': 'XNYS',
#   'venueName': 'NYSE',
#   'date': '2019-05-07',
#   'marketPercent': 0.03722274089130869,
#   'avgMarketPercent': 0.022422897396352538},
#  {'volume': 1576346,
#   'venue': 'EDGX',
#   'venueName': 'Cboe EDGX',
#   'date': '2019-05-07',
#   'marketPercent': 0.04107767067556842,
#   'avgMarketPercent': 0.03890235960676351},
#  {'volume': 2378623,
#   'venue': 'BATS',
#   'venueName': 'Cboe BZX',
#   'date': '2019-05-07',
#   'marketPercent': 0.06198421041385122,
#   'avgMarketPercent': 0.0683246566594053},
#  {'volume': 2782747,
#   'venue': 'ARCX',
#   'venueName': 'NYSE Arca',
#   'date': '2019-05-07',
#   'marketPercent': 0.07251343848555453,
#   'avgMarketPercent': 0.08024871602164509},
#  {'volume': 13039388,
#   'venue': 'XNGS',
#   'venueName': 'Nasdaq',
#   'date': '2019-05-07',
#   'marketPercent': 0.339789958255991,
#   'avgMarketPercent': 0.28313339012738925},
#  {'volume': 14710396,
#   'venue': 'TRF',
#   'venueName': 'Off Exchange',
#   'date': '2019-05-07',
#   'marketPercent': 0.38332673148336127,
#   'avgMarketPercent': 0.39808016843779326}]

# %%
c.volumeByVenueDF(symbol)
# Out:
#        avgMarketPercent       date  marketPercent      venueName    volume
# venue
# XASE           0.001399 2019-05-07       0.001550  NYSE American     58855
# XCIS           0.002723 2019-05-07       0.003372  NYSE National    128014
# XCHI           0.019840 2019-05-07       0.003588            CHX    104690
# XPHL           0.007588 2019-05-07       0.007220     Nasdaq PSX    274061
# EDGA           0.012147 2019-05-07       0.009659      Cboe EDGA    366666
# BATY           0.020307 2019-05-07       0.009814       Cboe BYX    372534
# XBOS           0.016844 2019-05-07       0.010777      Nasdaq BX    409110
# IEXG           0.028040 2019-05-07       0.022907            IEX    869563
# XNYS           0.022423 2019-05-07       0.037223           NYSE   1304584
# EDGX           0.038902 2019-05-07       0.041078      Cboe EDGX   1576346
# BATS           0.068325 2019-05-07       0.061984       Cboe BZX   2378623
# ARCX           0.080249 2019-05-07       0.072513      NYSE Arca   2782747
# XNGS           0.283133 2019-05-07       0.339790         Nasdaq  13039388
# TRF            0.398080 2019-05-07       0.383327   Off Exchange  14710396

# %% [markdown]
# # Alternative

# %% [markdown]
# ## crypto

# %%
# c.crypto()

# %%
# c.cryptoDF()

# %% [markdown]
# ## sentiment

# %%
c.sentiment(symbol)
# Out:
# {'sentiment': -0.03152100238663484,
#  'totalScores': 838,
#  'positive': 0.69,
#  'negative': 0.31}

# %%
c.sentimentDF(symbol)
# Out:
#    negative  positive  sentiment  totalScores
# 0      0.31      0.69  -0.031521          838

# %% [markdown]
# ## CEO Compensation

# %%
c.ceoCompensation(symbol)
# Out:
# {'symbol': 'AAPL',
#  'name': 'Tim Cook',
#  'companyName': '',
#  'location': 'Cupertino, CA',
#  'salary': 3057692,
#  'bonus': 0,
#  'stockAwards': 0,
#  'optionAwards': 0,
#  'nonEquityIncentives': 9327000,
#  'pensionAndDeferred': 0,
#  'otherComp': 440374,
#  'total': 12825066,
#  'year': '2017'}

# %%
c.ceoCompensationDF(symbol)
# Out:
#    bonus companyName       location      name  nonEquityIncentives  \
# 0      0              Cupertino, CA  Tim Cook              9327000
#
#    optionAwards  otherComp  pensionAndDeferred   salary  stockAwards symbol  \
# 0             0     440374                   0  3057692            0   AAPL
#
#       total  year
# 0  12825066  2017

# %% [markdown]
# # Forex

# %% [markdown]
# ## Exchange Rates

# %% [markdown]
# # IEX Data

# %% [markdown]
# ## TOPS

# %% [markdown]
# ## Last

# %% [markdown]
# ## DEEP

# %% [markdown]
# ## DEEP Auction

# %% [markdown]
# ## DEEP Book

# %% [markdown]
# ## DEEP Operational Halt Status

# %% [markdown]
# ## DEEP Official Price

# %% [markdown]
# ## DEEP Security Event

# %% [markdown]
# ## DEEP Short Sale Price Test Status

# %% [markdown]
# ## DEEP System Event

# %% [markdown]
# ## DEEP Trades

# %% [markdown]
# ## DEEP Trade Break

# %% [markdown]
# ## DEEP Trading Status

# %% [markdown]
# ## Listed Regulation SHO Threshold Securities List In Dev

# %% [markdown]
# ## Listed Short Interest List In Dev

# %% [markdown]
# ## Stats Historical Daily In Dev

# %% [markdown]
# ## Stats Historical Summary

# %% [markdown]
# ## Stats Intraday

# %% [markdown]
# ## Stats Recent

# %% [markdown]
# ## Stats Records

# %% [markdown]
# # API Metadata
